# %% [markdown]
# <a href="https://colab.research.google.com/github/abarb2022/Walmart-Recruiting---Store-Sales-Forecasting/blob/main/model_experiment_sarima.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
! mkdir ~/.kaggle

# %%
# !cp /content/drive/MyDrive/ColabNotebooks/kaggle_API_credentials/kaggle.json ~/.kaggle/kaggle.json

# %%
! chmod 600 ~/.kaggle/kaggle.json

# %%
! kaggle competitions download -c walmart-recruiting-store-sales-forecasting
# Out:
# Downloading walmart-recruiting-store-sales-forecasting.zip to /content
#   0% 0.00/2.70M [00:00<?, ?B/s]
# 100% 2.70M/2.70M [00:00<00:00, 773MB/s]

# %%
! unzip walmart-recruiting-store-sales-forecasting
# Out:
# Archive:  walmart-recruiting-store-sales-forecasting.zip
#   inflating: features.csv.zip
#   inflating: sampleSubmission.csv.zip
#   inflating: stores.csv
#   inflating: test.csv.zip
#   inflating: train.csv.zip

# %%
import pandas as pd
import numpy as np
from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import LabelEncoder # For Type encoding if not using category dtype directly
from sklearn.metrics import mean_absolute_error
import matplotlib.pyplot as plt
import seaborn as sns
import gc # For garbage collection
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
pd.set_option('display.expand_frame_repr', False)

# %%
stores = pd.read_csv('stores.csv')
train = pd.read_csv("train.csv.zip")
features = pd.read_csv('features.csv.zip')
sample = pd.read_csv('sampleSubmission.csv.zip')
test = pd.read_csv('test.csv.zip')

# %%
# Convert 'Date' columns to datetime objects for easier manipulation
train['Date'] = pd.to_datetime(train['Date'])
test['Date'] = pd.to_datetime(test['Date'])
features['Date'] = pd.to_datetime(features['Date'])

# Merge features with train and test data.
# Note: 'IsHoliday' is present in both train/test and features.csv.
# We'll merge on it to ensure consistency, but if there were discrepancies,
# we'd need a more careful merge strategy.
train_df = pd.merge(train, features, on=['Store', 'Date', 'IsHoliday'], how='left')
test_df = pd.merge(test, features, on=['Store', 'Date', 'IsHoliday'], how='left')

# Merge store information
train_df = pd.merge(train_df, stores, on='Store', how='left')
test_df = pd.merge(test_df, stores, on='Store', how='left')

print("\n--- Merged Train Data Head ---")
print(train_df.head())
print("\n--- Merged Test Data Head ---")
print(test_df.head())

print("\n--- Merged Train Data Info ---")
print(train_df.info())
print("\n--- Merged Test Data Info ---")
print(test_df.info())

# Free up memory
del train, test, features, stores
gc.collect()
# Out:
# --- Merged Train Data Head ---
#    Store  Dept       Date  Weekly_Sales  IsHoliday  Temperature  Fuel_Price  MarkDown1  MarkDown2  MarkDown3  MarkDown4  MarkDown5         CPI  Unemployment Type    Size
# 0      1     1 2010-02-05      24924.50      False        42.31       2.572        NaN        NaN        NaN        NaN        NaN  211.096358         8.106    A  151315
# 1      1     1 2010-02-12      46039.49       True        38.51       2.548        NaN        NaN        NaN        NaN        NaN  211.242170         8.106    A  151315
# 2      1     1 2010-02-19      41595.55      False        39.93       2.514        NaN        NaN        NaN        NaN        NaN  211.289143         8.106    A  151315
# 3      1     1 2010-02-26      19403.54      False        46.63       2.561        NaN        NaN        NaN        NaN        NaN  211.319643         8.106    A  151315
# 4      1     1 2010-03-05      21827.90      False        46.50       2.625        NaN        NaN        NaN        NaN        NaN  211.350143         8.106    A  151315
#
# --- Merged Test Data Head ---
#    Store  Dept       Date  IsHoliday  Temperature  Fuel_Price  MarkDown1  MarkDown2  MarkDown3  MarkDown4  MarkDown5         CPI  Unemployment Type    Size
# 0      1     1 2012-11-02      False        55.32       3.386    6766.44    5147.70      50.82    3639.90    2737.42  223.462779         6.573    A  151315
# 1      1     1 2012-11-09      False        61.24       3.314   11421.32    3370.89      40.28    4646.79    6154.16  223.481307         6.573    A  151315
# 2      1     1 2012-11-16      False        52.92       3.252    9696.28     292.10     103.78    1133.15    6612.69  223.512911         6.573    A  151315
# 3      1     1 2012-11-23       True        56.23       3.211     883.59       4.17   74910.32     209.91     303.32  223.561947         6.573    A  151315
# 4      1     1 2012-11-30      False        52.34       3.207    2460.03        NaN    3838.35     150.57    6966.34  223.610984         6.573    A  151315
#
# --- Merged Train Data Info ---
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 421570 entries, 0 to 421569
# Data columns (total 16 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   Store         421570 non-null  int64
#  1   Dept          421570 non-null  int64
#  2   Date          421570 non-null  datetime64[ns]
#  3   Weekly_Sales  421570 non-null  float64
#  4   IsHoliday     421570 non-null  bool
#  5   Temperature   421570 non-null  float64
#  6   Fuel_Price    421570 non-null  float64
#  7   MarkDown1     150681 non-null  float64
#  8   MarkDown2     111248 non-null  float64
#  9   MarkDown3     137091 non-null  float64
#  10  MarkDown4     134967 non-null  float64
#  11  MarkDown5     151432 non-null  float64
#  12  CPI           421570 non-null  float64
#  13  Unemployment  421570 non-null  float64
#  14  Type          421570 non-null  object
#  15  Size          421570 non-null  int64
# dtypes: bool(1), datetime64[ns](1), float64(10), int64(3), object(1)
# memory usage: 48.6+ MB
# None
#
# --- Merged Test Data Info ---
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 115064 entries, 0 to 115063
# Data columns (total 15 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   Store         115064 non-null  int64
#  1   Dept          115064 non-null  int64
#  2   Date          115064 non-null  datetime64[ns]
#  3   IsHoliday     115064 non-null  bool
#  4   Temperature   115064 non-null  float64
#  5   Fuel_Price    115064 non-null  float64
#  6   MarkDown1     114915 non-null  float64
#  7   MarkDown2     86437 non-null   float64
#  8   MarkDown3     105235 non-null  float64
#  9   MarkDown4     102176 non-null  float64
#  10  MarkDown5     115064 non-null  float64
#  11  CPI           76902 non-null   float64
#  12  Unemployment  76902 non-null   float64
#  13  Type          115064 non-null  object
#  14  Size          115064 non-null  int64
# dtypes: bool(1), datetime64[ns](1), float64(9), int64(3), object(1)
# memory usage: 12.4+ MB
# None
# 0

# %% [markdown]
# ## **DATA CLEANING**

# %%
class MissingValueImputer(BaseEstimator, TransformerMixin):
    """
    Custom Transformer to handle missing values for specific columns.
    - MarkDown columns: fill with 0.
    - Other specified numerical columns: fill with ffill then bfill, fallback to mean.
    """
    def __init__(self, markdown_cols=None, numerical_cols_to_impute=None):
        self.markdown_cols = markdown_cols if markdown_cols is not None else [f'MarkDown{i}' for i in range(1, 6)]
        self.numerical_cols_to_impute = numerical_cols_to_impute if numerical_cols_to_impute is not None else ['Temperature', 'Fuel_Price', 'CPI', 'Unemployment']
        self.means = {} # To store means for fallback imputation during transform

    def fit(self, X, y=None):
        # Calculate means for fallback imputation from the training data
        for col in self.numerical_cols_to_impute:
            if col in X.columns:
                self.means[col] = X[col].mean()
        return self

    def transform(self, X):
        X_copy = X.copy()


        for col in self.markdown_cols:
          if col in X_copy.columns:
            X_copy[f"{col}_was_missing"] = X_copy[col].isna().astype(int)
            X_copy[col] = X_copy[col].fillna(0)


        # Impute other numerical columns with ffill then bfill, fallback to mean
        for col in self.numerical_cols_to_impute:
            if col in X_copy.columns:
                X_copy[col] = X_copy[col].ffill().bfill() # Use ffill and bfill directly
                # Fallback to mean if NaNs still exist (e.g., if all values were NaN in a column)
                if X_copy[col].isnull().any() and col in self.means:
                    X_copy[col] = X_copy[col].fillna(self.means[col])
        return X_copy

# %%
class FastWalmartHolidayFeatureExtractor(BaseEstimator, TransformerMixin):
    def __init__(self, date_column='Date', verbose=False):
        self.date_column = date_column
        self.verbose = verbose
        self.holiday_dates = {
            'super_bowl': pd.to_datetime(['2010-02-12', '2011-02-11', '2012-02-10', '2013-02-08']),
            'labor_day': pd.to_datetime(['2010-09-10', '2011-09-09', '2012-09-07', '2013-09-06']),
            'thanksgiving': pd.to_datetime(['2010-11-26', '2011-11-25', '2012-11-23', '2013-11-29']),
            'christmas': pd.to_datetime(['2010-12-31', '2011-12-30', '2012-12-28', '2013-12-27'])
        }

    def _get_holiday_features_vectorized(self, dates):
        features = pd.DataFrame(index=dates.index)
        for holiday in self.holiday_dates.keys():
            features[f'is_{holiday}'] = 0
            features[f'days_until_{holiday}'] = 999
            features[f'days_since_{holiday}'] = 999
        features['holiday_week_flag'] = 0

        for holiday_name, holiday_list in self.holiday_dates.items():
            is_holiday = dates.isin(holiday_list)
            features[f'is_{holiday_name}'] = is_holiday.astype(int)
            for holiday_date in holiday_list:
                days_diff = (holiday_date - dates).dt.days
                future_mask = days_diff > 0
                current_until = features[f'days_until_{holiday_name}']
                features[f'days_until_{holiday_name}'] = np.where(future_mask & (days_diff < current_until), days_diff, current_until)
                past_mask = days_diff <= 0
                days_since = -days_diff
                current_since = features[f'days_since_{holiday_name}']
                features[f'days_since_{holiday_name}'] = np.where(past_mask & (days_since < current_since), days_since, current_since)
        holiday_cols = [f'is_{holiday}' for holiday in self.holiday_dates.keys()]
        features['holiday_week_flag'] = features[holiday_cols].sum(axis=1).clip(0, 1)
        return features

    def fit(self, X, y=None):
        return self

    def transform(self, X):
        X_copy = X.copy()
        dates = pd.to_datetime(X_copy[self.date_column])
        try:
            X_copy['week_of_year'] = dates.dt.isocalendar().week.astype(int)
        except:
            X_copy['week_of_year'] = dates.dt.week.astype(int)
        X_copy['day_of_week'] = dates.dt.dayofweek.astype(int)
        holiday_features = self._get_holiday_features_vectorized(dates)
        X_copy = pd.concat([X_copy, holiday_features], axis=1)
        X_copy['black_friday_week'] = ((X_copy['is_thanksgiving'] == 1) | (X_copy['days_since_thanksgiving'] <= 7)).astype(int)
        X_copy['christmas_buildup'] = ((X_copy['days_until_christmas'] <= 21) & (X_copy['days_until_christmas'] > 0)).astype(int)
        X_copy['post_super_bowl'] = ((X_copy['days_since_super_bowl'] <= 14) & (X_copy['days_since_super_bowl'] > 0)).astype(int)
        X_copy['seasonal_sin'] = np.sin(2 * np.pi * X_copy['week_of_year'] / 52)
        X_copy['seasonal_cos'] = np.cos(2 * np.pi * X_copy['week_of_year'] / 52)
        if 'CPI' in X_copy.columns and 'Fuel_Price' in X_copy.columns:
            X_copy['holiday_economic_index'] = (X_copy['CPI'] * X_copy['holiday_week_flag'] + X_copy['Fuel_Price'] * X_copy['holiday_week_flag'])
        return X_copy

# %%
class CategoricalFeatureConverter(BaseEstimator, TransformerMixin):
    """
    Custom Transformer to convert specified columns to 'category' dtype
    for LightGBM to handle them efficiently.
    """
    def __init__(self, categorical_cols=None):
        self.categorical_cols = categorical_cols if categorical_cols is not None else ['Store', 'Dept', 'Type']

    def fit(self, X, y=None):
        return self

    def transform(self, X):
        X_copy = X.copy()
        for col in self.categorical_cols:
            if col in X_copy.columns:
                X_copy[col] = X_copy[col].astype('category')
        return X_copy

# Ensure Date column is preserved through transformations for SARIMAX indexing
class KeepDateImputer(MissingValueImputer):
    def transform(self, X):
        X_copy = super().transform(X)
        if 'Date' not in X_copy.columns and 'Date' in X.columns:
            X_copy['Date'] = X['Date'].copy()
        return X_copy

class KeepDateFeatureExtractor(FastWalmartHolidayFeatureExtractor):
    def transform(self, X):
        X_copy = super().transform(X)
        # Ensure Date is kept or recreated after feature extraction
        if 'Date' not in X_copy.columns and self.date_column in X.columns:
            X_copy['Date'] = X[self.date_column].copy()
        return X_copy

# %%
y_train = train_df['Weekly_Sales']
X_train = train_df.drop(columns=['Weekly_Sales', 'Id'], errors='ignore')

temp_train_df = X_train.copy()
temp_train_df['Date'] = pd.to_datetime(train_df['Date']) # Get original dates back for sorting
temp_train_df['Weekly_Sales'] = y_train

temp_train_df = temp_train_df.sort_values(by='Date').reset_index(drop=True)

# Define a cutoff date for validation
validation_cutoff_date = pd.to_datetime('2012-09-01')

X_train_split = temp_train_df[temp_train_df['Date'] < validation_cutoff_date]
y_train_split = temp_train_df[temp_train_df['Date'] < validation_cutoff_date]['Weekly_Sales']

X_val_split = temp_train_df[temp_train_df['Date'] >= validation_cutoff_date]
y_val_split = temp_train_df[temp_train_df['Date'] >= validation_cutoff_date]['Weekly_Sales']

def weighted_mean_absolute_error(y_true, y_pred, weights):
    return np.sum(weights * np.abs(y_true - y_pred)) / np.sum(weights)

val_weights_raw = X_val_split['IsHoliday'].apply(lambda x: 5 if x else 1)

# %%
import pandas as pd
import numpy as np
import gc
from sklearn.pipeline import Pipeline
import warnings
from statsmodels.tsa.arima.model import ARIMA  # SARIMA without exogenous variables

# Suppress warnings from statsmodels
warnings.filterwarnings("ignore", category=UserWarning, module="statsmodels")
warnings.filterwarnings("ignore", category=RuntimeWarning, module="statsmodels")
warnings.filterwarnings("ignore", category=FutureWarning, module="statsmodels")
warnings.filterwarnings('ignore', category=DeprecationWarning)
# Define preprocessing pipeline
preprocessing_with_date = Pipeline(steps=[
    ('imputer', MissingValueImputer()),
    ('categorical_converter', CategoricalFeatureConverter())
])

# Apply preprocessing
print("\n--- Applying Preprocessing Pipeline ---")
X_train_processed = preprocessing_with_date.fit_transform(X_train_split)
X_val_processed = preprocessing_with_date.transform(X_val_split)
print("Preprocessing complete.")

print(f"\n--- Data Dimensions After Preprocessing ---")
print(f"X_train_processed shape: {X_train_processed.shape}")
print(f"X_val_processed shape: {X_val_processed.shape}")

# SARIMA Parameters
sarima_order = (1, 0, 2)
sarima_seasonal_order = (0, 0, 0, 52)

def weighted_mean_absolute_error(y_true, y_pred, weights):
    return np.sum(weights * np.abs(y_true - y_pred)) / np.sum(weights)

# Model storage
fitted_models = {}
all_individual_predictions = []
overall_results_summary = []

# Unique Store-Dept combinations
unique_store_depts_df = X_train_split[['Store', 'Dept']].drop_duplicates().sort_values(by=['Store', 'Dept']).reset_index(drop=True)
unique_store_depts = unique_store_depts_df.values

print(f"\n--- Starting SARIMA Modeling for {len(unique_store_depts)} Store-Department Combinations ---")

models_processed_count = 0
min_obs_required = 2 * sarima_seasonal_order[3] + sum(sarima_order) + sum(sarima_seasonal_order[:3]) + 1

for store_id, dept_id in unique_store_depts:
    models_processed_count += 1
    print(f"\n--- Processing Store: {int(store_id)}, Department: {int(dept_id)} ({models_processed_count}/{len(unique_store_depts)}) ---")

    train_idx_combo = (X_train_split['Store'] == store_id) & (X_train_split['Dept'] == dept_id)
    val_idx_combo = (X_val_split['Store'] == store_id) & (X_val_split['Dept'] == dept_id)

    single_train_X = X_train_processed.loc[train_idx_combo]
    single_train_y = y_train_split.loc[train_idx_combo]
    single_val_X = X_val_processed.loc[val_idx_combo]
    single_val_y = y_val_split.loc[val_idx_combo]

    if len(single_train_X) < min_obs_required:
        print(f"  Skipping (Store {int(store_id)}, Dept {int(dept_id)}): Not enough training data points.")
        overall_results_summary.append({
            'Store': int(store_id), 'Dept': int(dept_id), 'WMAE': np.nan, 'Status': 'Skipped (Too few train data)',
            'Train_Points': len(single_train_X), 'Val_Points': len(single_val_X)
        })
        gc.collect()
        continue

    if len(single_val_X) == 0:
        print(f"  Skipping (Store {int(store_id)}, Dept {int(dept_id)}): No validation data points.")
        overall_results_summary.append({
            'Store': int(store_id), 'Dept': int(dept_id), 'WMAE': np.nan, 'Status': 'Skipped (No val data)',
            'Train_Points': len(single_train_X), 'Val_Points': len(single_val_X)
        })
        gc.collect()
        continue

    try:
        y_train_series = single_train_y.set_axis(single_train_X['Date']).sort_index()
        y_val_series = single_val_y.set_axis(single_val_X['Date']).sort_index()
        val_weights = val_weights_raw.loc[val_idx_combo].set_axis(single_val_X['Date']).sort_index()

        if y_train_series.nunique() == 1:
            predicted_value = y_train_series.iloc[0]
            print(f"  Constant training series (value: {predicted_value:.2f}). Predicting constant value.")
            predictions = pd.Series(predicted_value, index=y_val_series.index)
            predictions_for_overall = pd.Series(predictions.values, index=single_val_X.index, name='Weekly_Sales_Pred')
            all_individual_predictions.append(predictions_for_overall)

            wmae = weighted_mean_absolute_error(y_val_series, predictions, val_weights)
            overall_results_summary.append({
                'Store': int(store_id), 'Dept': int(dept_id), 'WMAE': wmae,
                'Status': 'Success (Constant Series Prediction)',
                'Train_Points': len(single_train_X), 'Val_Points': len(single_val_X)
            })
            gc.collect()
            continue

        sarima_model = ARIMA(
            y_train_series,
            order=sarima_order,
            seasonal_order=sarima_seasonal_order,
            enforce_stationarity=False,
            enforce_invertibility=False
        )
        sarima_results = sarima_model.fit()

        fitted_models[(int(store_id), int(dept_id))] = sarima_results

        predictions = sarima_results.predict(
            start=y_val_series.index[0],
            end=y_val_series.index[-1]
        )
        predictions[predictions < 0] = 0

        predictions_for_overall = pd.Series(predictions.values, index=single_val_X.index, name='Weekly_Sales_Pred')
        all_individual_predictions.append(predictions_for_overall)

        wmae = weighted_mean_absolute_error(y_val_series, predictions, val_weights)
        status = 'Success'

        print(f"  WMAE: {wmae:.2f}")
        overall_results_summary.append({
            'Store': int(store_id), 'Dept': int(dept_id), 'WMAE': wmae, 'Status': status,
            'Train_Points': len(single_train_X), 'Val_Points': len(single_val_X)
        })

    except Exception as e:
        print(f"  Error fitting/predicting (Store {int(store_id)}, Dept {int(dept_id)}): {e}")
        overall_results_summary.append({
            'Store': int(store_id), 'Dept': int(dept_id), 'WMAE': np.nan, 'Status': f'Failed: {type(e).__name__}',
            'Train_Points': len(single_train_X), 'Val_Points': len(single_val_X)
        })
    finally:
        gc.collect()

print("\n--- All SARIMA Modeling Attempts Complete ---")

# Combine all individual predictions for overall WMAE
print("\n--- Combining all individual predictions for overall WMAE ---")

if all_individual_predictions:
    combined_predictions = pd.concat(all_individual_predictions).sort_index()
    y_true_overall = y_val_split.copy()
    y_pred_overall = combined_predictions.reindex(y_val_split.index)
    weights_overall = val_weights_raw.copy()

    overall_df = pd.DataFrame({
        'y_true': y_true_overall,
        'y_pred': y_pred_overall,
        'weights': weights_overall
    }).dropna(subset=['y_true', 'y_pred', 'weights'])

    if not overall_df.empty and overall_df['weights'].sum() > 0:
        overall_wmae = (overall_df['weights'] * np.abs(overall_df['y_true'] - overall_df['y_pred'])).sum() / overall_df['weights'].sum()
        print(f"\n--- Overall Weighted Mean Absolute Error (WMAE) on Validation Set: {overall_wmae:.2f} ---")
    else:
        print("\n--- Cannot calculate overall WMAE: No valid predictions or weights available. ---")
else:
    print("\n--- No individual predictions were generated. Overall WMAE cannot be calculated. ---")

results_df = pd.DataFrame(overall_results_summary)
print("\n--- Summary of Individual Store-Dept Model Results ---")
print(results_df.head(15))

successful_models_summary = results_df.dropna(subset=['WMAE'])
if not successful_models_summary.empty:
    print(f"\nTotal successful models fitted: {len(successful_models_summary)} (out of {len(unique_store_depts)})")
    print(f"Total failed/skipped models: {len(results_df) - len(successful_models_summary)}")
    print(f"Average WMAE for successfully fitted models (individual series): {successful_models_summary['WMAE'].mean():.2f}")
else:
    print("\nNo successful SARIMA models were fitted or predicted.")

print("\n--- Number of fitted models stored: ", len(fitted_models))
# Out:
# --- Applying Preprocessing Pipeline ---
# Preprocessing complete.
#
# --- Data Dimensions After Preprocessing ---
# X_train_processed shape: (397841, 21)
# X_val_processed shape: (23729, 21)
# /usr/local/lib/python3.11/dist-packages/sklearn/pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# Streaming output truncated to the last 5000 lines.
# --- Processing Store: 22, Department: 83 (1670/3326) ---
#   WMAE: 106.59
#
# --- Processing Store: 22, Department: 85 (1671/3326) ---
#   WMAE: 288.34
#
# --- Processing Store: 22, Department: 87 (1672/3326) ---
#   WMAE: 2828.16
#
# --- Processing Store: 22, Department: 90 (1673/3326) ---
#   WMAE: 1995.79
#
# --- Processing Store: 22, Department: 91 (1674/3326) ---
#   WMAE: 1336.71
#
# --- Processing Store: 22, Department: 92 (1675/3326) ---
#   WMAE: 5384.35
#
# --- Processing Store: 22, Department: 93 (1676/3326) ---
#   WMAE: 467.61
#
# --- Processing Store: 22, Department: 94 (1677/3326) ---
#   Error fitting/predicting (Store 22, Dept 94): 'The `start` argument could not be matched to a location related to the index of the data.'
#
# --- Processing Store: 22, Department: 95 (1678/3326) ---
#   WMAE: 3651.32
#
# --- Processing Store: 22, Department: 96 (1679/3326) ---
#   Skipping (Store 22, Dept 96): Not enough training data points.
#
# --- Processing Store: 22, Department: 97 (1680/3326) ---
#   WMAE: 430.46
#
# --- Processing Store: 22, Department: 98 (1681/3326) ---
#   Error fitting/predicting (Store 22, Dept 98): 'The `start` argument could not be matched to a location related to the index of the data.'
#
# --- Processing Store: 22, Department: 99 (1682/3326) ---
#   Skipping (Store 22, Dept 99): Not enough training data points.
#
# --- Processing Store: 23, Department: 1 (1683/3326) ---
#   WMAE: 5998.26
#
# --- Processing Store: 23, Department: 2 (1684/3326) ---
#   WMAE: 3878.10
#
# --- Processing Store: 23, Department: 3 (1685/3326) ---
#   WMAE: 20216.03
#
# --- Processing Store: 23, Department: 4 (1686/3326) ---
#   WMAE: 2681.14
#
# --- Processing Store: 23, Department: 5 (1687/3326) ---
#   WMAE: 7239.32
#
# --- Processing Store: 23, Department: 6 (1688/3326) ---
#   WMAE: 1638.83
#
# --- Processing Store: 23, Department: 7 (1689/3326) ---
#   WMAE: 8316.77
#
# --- Processing Store: 23, Department: 8 (1690/3326) ---
#   WMAE: 4022.45
#
# --- Processing Store: 23, Department: 9 (1691/3326) ---
#   WMAE: 3128.06
#
# --- Processing Store: 23, Department: 10 (1692/3326) ---
#   WMAE: 1096.77
#
# --- Processing Store: 23, Department: 11 (1693/3326) ---
#   WMAE: 6538.64
#
# --- Processing Store: 23, Department: 12 (1694/3326) ---
#   WMAE: 1033.87
#
# --- Processing Store: 23, Department: 13 (1695/3326) ---
#   WMAE: 4555.97
#
# --- Processing Store: 23, Department: 14 (1696/3326) ---
#   WMAE: 3211.21
#
# --- Processing Store: 23, Department: 16 (1697/3326) ---
#   WMAE: 5416.82
#
# --- Processing Store: 23, Department: 17 (1698/3326) ---
#   WMAE: 2729.36
#
# --- Processing Store: 23, Department: 18 (1699/3326) ---
#   Error fitting/predicting (Store 23, Dept 18): 'The `start` argument could not be matched to a location related to the index of the data.'
#
# --- Processing Store: 23, Department: 19 (1700/3326) ---
#   WMAE: 233.81
#
# --- Processing Store: 23, Department: 20 (1701/3326) ---
#   WMAE: 2737.49
#
# --- Processing Store: 23, Department: 21 (1702/3326) ---
#   WMAE: 547.17
#
# --- Processing Store: 23, Department: 22 (1703/3326) ---
#   WMAE: 1160.19
#
# --- Processing Store: 23, Department: 23 (1704/3326) ---
#   WMAE: 5375.76
#
# --- Processing Store: 23, Department: 24 (1705/3326) ---
#   WMAE: 4142.01
#
# --- Processing Store: 23, Department: 25 (1706/3326) ---
#   WMAE: 1821.82
#
# --- Processing Store: 23, Department: 26 (1707/3326) ---
#   WMAE: 3634.38
#
# --- Processing Store: 23, Department: 27 (1708/3326) ---
#   WMAE: 1114.03
#
# --- Processing Store: 23, Department: 28 (1709/3326) ---
#   WMAE: 328.94
#
# --- Processing Store: 23, Department: 29 (1710/3326) ---
#   WMAE: 1076.93
#
# --- Processing Store: 23, Department: 30 (1711/3326) ---
#   WMAE: 2094.97
#
# --- Processing Store: 23, Department: 31 (1712/3326) ---
#   WMAE: 2119.42
#
# --- Processing Store: 23, Department: 32 (1713/3326) ---
#   WMAE: 1856.98
#
# --- Processing Store: 23, Department: 33 (1714/3326) ---
#   WMAE: 3370.97
#
# --- Processing Store: 23, Department: 34 (1715/3326) ---
#   WMAE: 2798.62
#
# --- Processing Store: 23, Department: 35 (1716/3326) ---
#   WMAE: 374.89
#
# --- Processing Store: 23, Department: 36 (1717/3326) ---
#   WMAE: 539.35
#
# --- Processing Store: 23, Department: 38 (1718/3326) ---
#   WMAE: 3597.50
#
# --- Processing Store: 23, Department: 40 (1719/3326) ---
#   WMAE: 1934.94
#
# --- Processing Store: 23, Department: 41 (1720/3326) ---
#   WMAE: 675.43
#
# --- Processing Store: 23, Department: 42 (1721/3326) ---
#   WMAE: 856.83
#
# --- Processing Store: 23, Department: 44 (1722/3326) ---
#   WMAE: 700.40
#
# --- Processing Store: 23, Department: 45 (1723/3326) ---
#   Error fitting/predicting (Store 23, Dept 45): 'The `start` argument could not be matched to a location related to the index of the data.'
#
# --- Processing Store: 23, Department: 46 (1724/3326) ---
#   WMAE: 4300.53
#
# --- Processing Store: 23, Department: 47 (1725/3326) ---
#   Skipping (Store 23, Dept 47): Not enough training data points.
#
# --- Processing Store: 23, Department: 48 (1726/3326) ---
#   Skipping (Store 23, Dept 48): Not enough training data points.
#
# --- Processing Store: 23, Department: 49 (1727/3326) ---
#   WMAE: 4306.02
#
# --- Processing Store: 23, Department: 50 (1728/3326) ---
#   WMAE: 1056.15
#
# --- Processing Store: 23, Department: 51 (1729/3326) ---
#   Skipping (Store 23, Dept 51): Not enough training data points.
#
# --- Processing Store: 23, Department: 52 (1730/3326) ---
#   WMAE: 265.93
#
# --- Processing Store: 23, Department: 54 (1731/3326) ---
#   WMAE: 49.12
#
# --- Processing Store: 23, Department: 55 (1732/3326) ---
#   WMAE: 2829.17
#
# --- Processing Store: 23, Department: 56 (1733/3326) ---
#   WMAE: 2616.69
#
# --- Processing Store: 23, Department: 58 (1734/3326) ---
#   Error fitting/predicting (Store 23, Dept 58): 'The `start` argument could not be matched to a location related to the index of the data.'
#
# --- Processing Store: 23, Department: 59 (1735/3326) ---
#   WMAE: 638.42
#
# --- Processing Store: 23, Department: 60 (1736/3326) ---
#   Skipping (Store 23, Dept 60): Not enough training data points.
#
# --- Processing Store: 23, Department: 67 (1737/3326) ---
#   WMAE: 932.32
#
# --- Processing Store: 23, Department: 71 (1738/3326) ---
#   WMAE: 3872.52
#
# --- Processing Store: 23, Department: 72 (1739/3326) ---
#   WMAE: 10162.11
#
# --- Processing Store: 23, Department: 74 (1740/3326) ---
#   WMAE: 8316.90
#
# --- Processing Store: 23, Department: 77 (1741/3326) ---
#   Skipping (Store 23, Dept 77): Not enough training data points.
#
# --- Processing Store: 23, Department: 78 (1742/3326) ---
#   Skipping (Store 23, Dept 78): Not enough training data points.
#
# --- Processing Store: 23, Department: 79 (1743/3326) ---
#   WMAE: 2587.27
#
# --- Processing Store: 23, Department: 80 (1744/3326) ---
#   Error fitting/predicting (Store 23, Dept 80): 'The `start` argument could not be matched to a location related to the index of the data.'
#
# --- Processing Store: 23, Department: 81 (1745/3326) ---
#   WMAE: 424.23
#
# --- Processing Store: 23, Department: 82 (1746/3326) ---
#   WMAE: 1658.51
#
# --- Processing Store: 23, Department: 83 (1747/3326) ---
#   Error fitting/predicting (Store 23, Dept 83): 'The `start` argument could not be matched to a location related to the index of the data.'
#
# --- Processing Store: 23, Department: 85 (1748/3326) ---
#   WMAE: 1135.03
#
# --- Processing Store: 23, Department: 87 (1749/3326) ---
#   WMAE: 2340.88
#
# --- Processing Store: 23, Department: 90 (1750/3326) ---
#   WMAE: 3022.61
#
# --- Processing Store: 23, Department: 91 (1751/3326) ---
#   WMAE: 3167.96
#
# --- Processing Store: 23, Department: 92 (1752/3326) ---
#   WMAE: 5308.55
#
# --- Processing Store: 23, Department: 93 (1753/3326) ---
#   Error fitting/predicting (Store 23, Dept 93): 'The `start` argument could not be matched to a location related to the index of the data.'
#
# --- Processing Store: 23, Department: 94 (1754/3326) ---
#   Skipping (Store 23, Dept 94): Not enough training data points.
#
# --- Processing Store: 23, Department: 95 (1755/3326) ---
#   WMAE: 4302.61
#
# --- Processing Store: 23, Department: 96 (1756/3326) ---
#   WMAE: 1090.43
#
# --- Processing Store: 23, Department: 97 (1757/3326) ---
#   WMAE: 556.43
#
# --- Processing Store: 23, Department: 98 (1758/3326) ---
#   Error fitting/predicting (Store 23, Dept 98): 'The `start` argument could not be matched to a location related to the index of the data.'
#
# --- Processing Store: 23, Department: 99 (1759/3326) ---
#   Skipping (Store 23, Dept 99): Not enough training data points.
#
# --- Processing Store: 24, Department: 1 (1760/3326) ---
#   WMAE: 2542.70
#
# --- Processing Store: 24, Department: 2 (1761/3326) ---
#   WMAE: 3025.08
#
# --- Processing Store: 24, Department: 3 (1762/3326) ---
#   WMAE: 11561.48
#
# --- Processing Store: 24, Department: 4 (1763/3326) ---
#   WMAE: 1603.50
#
# --- Processing Store: 24, Department: 5 (1764/3326) ---
#   WMAE: 4972.21
#
# --- Processing Store: 24, Department: 6 (1765/3326) ---
#   WMAE: 1407.53
#
# --- Processing Store: 24, Department: 7 (1766/3326) ---
#   WMAE: 3987.14
#
# --- Processing Store: 24, Department: 8 (1767/3326) ---
#   WMAE: 4919.72
#
# --- Processing Store: 24, Department: 9 (1768/3326) ---
#   WMAE: 3425.33
#
# --- Processing Store: 24, Department: 10 (1769/3326) ---
#   WMAE: 1293.33
#
# --- Processing Store: 24, Department: 11 (1770/3326) ---
#   WMAE: 2677.17
#
# --- Processing Store: 24, Department: 12 (1771/3326) ---
#   WMAE: 564.39
#
# --- Processing Store: 24, Department: 13 (1772/3326) ---
#   WMAE: 1952.04
#
# --- Processing Store: 24, Department: 14 (1773/3326) ---
#   WMAE: 1627.01
#
# --- Processing Store: 24, Department: 16 (1774/3326) ---
#   WMAE: 7214.41
#
# --- Processing Store: 24, Department: 17 (1775/3326) ---
#   WMAE: 861.79
#
# --- Processing Store: 24, Department: 18 (1776/3326) ---
#   Error fitting/predicting (Store 24, Dept 18): 'The `start` argument could not be matched to a location related to the index of the data.'
#
# --- Processing Store: 24, Department: 19 (1777/3326) ---
#   WMAE: 25.99
#
# --- Processing Store: 24, Department: 20 (1778/3326) ---
#   WMAE: 1216.43
#
# --- Processing Store: 24, Department: 21 (1779/3326) ---
#   WMAE: 471.66
#
# --- Processing Store: 24, Department: 22 (1780/3326) ---
#   WMAE: 1093.26
#
# --- Processing Store: 24, Department: 23 (1781/3326) ---
#   WMAE: 3530.22
#
# --- Processing Store: 24, Department: 24 (1782/3326) ---
#   WMAE: 2792.99
#
# --- Processing Store: 24, Department: 25 (1783/3326) ---
#   WMAE: 1869.78
#
# --- Processing Store: 24, Department: 26 (1784/3326) ---
#   WMAE: 1198.09
#
# --- Processing Store: 24, Department: 27 (1785/3326) ---
#   WMAE: 380.94
#
# --- Processing Store: 24, Department: 28 (1786/3326) ---
#   WMAE: 127.39
#
# --- Processing Store: 24, Department: 29 (1787/3326) ---
#   WMAE: 930.98
#
# --- Processing Store: 24, Department: 30 (1788/3326) ---
#   WMAE: 723.47
#
# --- Processing Store: 24, Department: 31 (1789/3326) ---
#   WMAE: 1357.16
#
# --- Processing Store: 24, Department: 32 (1790/3326) ---
#   WMAE: 2240.14
#
# --- Processing Store: 24, Department: 33 (1791/3326) ---
#   WMAE: 1638.37
#
# --- Processing Store: 24, Department: 34 (1792/3326) ---
#   WMAE: 1387.48
#
# --- Processing Store: 24, Department: 35 (1793/3326) ---
#   WMAE: 363.79
#
# --- Processing Store: 24, Department: 36 (1794/3326) ---
#   WMAE: 524.12
#
# --- Processing Store: 24, Department: 37 (1795/3326) ---
#   WMAE: 313.10
#
# --- Processing Store: 24, Department: 38 (1796/3326) ---
#   WMAE: 3412.21
#
# --- Processing Store: 24, Department: 40 (1797/3326) ---
#   WMAE: 1460.93
#
# --- Processing Store: 24, Department: 41 (1798/3326) ---
#   WMAE: 371.90
#
# --- Processing Store: 24, Department: 42 (1799/3326) ---
#   WMAE: 515.19
#
# --- Processing Store: 24, Department: 44 (1800/3326) ---
#   WMAE: 291.62
#
# --- Processing Store: 24, Department: 45 (1801/3326) ---
#   Skipping (Store 24, Dept 45): Not enough training data points.
#
# --- Processing Store: 24, Department: 46 (1802/3326) ---
#   WMAE: 1961.18
#
# --- Processing Store: 24, Department: 47 (1803/3326) ---
#   Skipping (Store 24, Dept 47): Not enough training data points.
#
# --- Processing Store: 24, Department: 49 (1804/3326) ---
#   WMAE: 1169.26
#
# --- Processing Store: 24, Department: 50 (1805/3326) ---
#   WMAE: 252.73
#
# --- Processing Store: 24, Department: 51 (1806/3326) ---
#   Skipping (Store 24, Dept 51): Not enough training data points.
#
# --- Processing Store: 24, Department: 52 (1807/3326) ---
#   WMAE: 165.75
#
# --- Processing Store: 24, Department: 54 (1808/3326) ---
#   Error fitting/predicting (Store 24, Dept 54): 'The `start` argument could not be matched to a location related to the index of the data.'
#
# --- Processing Store: 24, Department: 55 (1809/3326) ---
#   WMAE: 4363.66
#
# --- Processing Store: 24, Department: 56 (1810/3326) ---
#   WMAE: 1667.80
#
# --- Processing Store: 24, Department: 58 (1811/3326) ---
#   Error fitting/predicting (Store 24, Dept 58): 'The `start` argument could not be matched to a location related to the index of the data.'
#
# --- Processing Store: 24, Department: 59 (1812/3326) ---
#   WMAE: 278.50
#
# --- Processing Store: 24, Department: 60 (1813/3326) ---
#   Skipping (Store 24, Dept 60): Not enough training data points.
#
# --- Processing Store: 24, Department: 67 (1814/3326) ---
#   WMAE: 1569.76
#
# --- Processing Store: 24, Department: 71 (1815/3326) ---
#   WMAE: 840.43
#
# --- Processing Store: 24, Department: 72 (1816/3326) ---
#   WMAE: 6077.26
#
# --- Processing Store: 24, Department: 74 (1817/3326) ---
#   WMAE: 1474.12
#
# --- Processing Store: 24, Department: 77 (1818/3326) ---
#   Skipping (Store 24, Dept 77): Not enough training data points.
#
# --- Processing Store: 24, Department: 78 (1819/3326) ---
#   Skipping (Store 24, Dept 78): Not enough training data points.
#
# --- Processing Store: 24, Department: 79 (1820/3326) ---
#   WMAE: 1690.93
#
# --- Processing Store: 24, Department: 80 (1821/3326) ---
#   WMAE: 2050.29
#
# --- Processing Store: 24, Department: 81 (1822/3326) ---
#   WMAE: 1632.88
#
# --- Processing Store: 24, Department: 82 (1823/3326) ---
#   WMAE: 1045.05
#
# --- Processing Store: 24, Department: 83 (1824/3326) ---
#   WMAE: 619.38
#
# --- Processing Store: 24, Department: 85 (1825/3326) ---
#   WMAE: 171.51
#
# --- Processing Store: 24, Department: 87 (1826/3326) ---
#   WMAE: 2507.70
#
# --- Processing Store: 24, Department: 90 (1827/3326) ---
#   WMAE: 7584.56
#
# --- Processing Store: 24, Department: 91 (1828/3326) ---
#   WMAE: 5571.88
#
# --- Processing Store: 24, Department: 92 (1829/3326) ---
#   WMAE: 18060.42
#
# --- Processing Store: 24, Department: 93 (1830/3326) ---
#   WMAE: 6755.75
#
# --- Processing Store: 24, Department: 94 (1831/3326) ---
#   WMAE: 3170.54
#
# --- Processing Store: 24, Department: 95 (1832/3326) ---
#   WMAE: 9410.52
#
# --- Processing Store: 24, Department: 96 (1833/3326) ---
#   WMAE: 2481.73
#
# --- Processing Store: 24, Department: 97 (1834/3326) ---
#   WMAE: 2814.47
#
# --- Processing Store: 24, Department: 98 (1835/3326) ---
#   WMAE: 935.63
#
# --- Processing Store: 24, Department: 99 (1836/3326) ---
#   Skipping (Store 24, Dept 99): Not enough training data points.
#
# --- Processing Store: 25, Department: 1 (1837/3326) ---
#   WMAE: 3602.66
#
# --- Processing Store: 25, Department: 2 (1838/3326) ---
#   WMAE: 2211.87
#
# --- Processing Store: 25, Department: 3 (1839/3326) ---
#   WMAE: 14757.89
#
# --- Processing Store: 25, Department: 4 (1840/3326) ---
#   WMAE: 899.67
#
# --- Processing Store: 25, Department: 5 (1841/3326) ---
#   WMAE: 2213.22
#
# --- Processing Store: 25, Department: 6 (1842/3326) ---
#   WMAE: 1043.15
#
# --- Processing Store: 25, Department: 7 (1843/3326) ---
#   WMAE: 1832.92
#
# --- Processing Store: 25, Department: 8 (1844/3326) ---
#   WMAE: 1238.11
#
# --- Processing Store: 25, Department: 9 (1845/3326) ---
#   WMAE: 1407.44
#
# --- Processing Store: 25, Department: 10 (1846/3326) ---
#   WMAE: 2508.66
#
# --- Processing Store: 25, Department: 11 (1847/3326) ---
#   WMAE: 1017.82
#
# --- Processing Store: 25, Department: 12 (1848/3326) ---
#   WMAE: 355.01
#
# --- Processing Store: 25, Department: 13 (1849/3326) ---
#   WMAE: 1363.89
#
# --- Processing Store: 25, Department: 14 (1850/3326) ---
#   WMAE: 1054.78
#
# --- Processing Store: 25, Department: 16 (1851/3326) ---
#   WMAE: 6266.19
#
# --- Processing Store: 25, Department: 17 (1852/3326) ---
#   WMAE: 847.75
#
# --- Processing Store: 25, Department: 18 (1853/3326) ---
#   Error fitting/predicting (Store 25, Dept 18): 'The `start` argument could not be matched to a location related to the index of the data.'
#
# --- Processing Store: 25, Department: 19 (1854/3326) ---
#   Skipping (Store 25, Dept 19): Not enough training data points.
#
# --- Processing Store: 25, Department: 20 (1855/3326) ---
#   WMAE: 873.90
#
# --- Processing Store: 25, Department: 21 (1856/3326) ---
#   WMAE: 480.81
#
# --- Processing Store: 25, Department: 22 (1857/3326) ---
#   WMAE: 726.32
#
# --- Processing Store: 25, Department: 23 (1858/3326) ---
#   WMAE: 1210.94
#
# --- Processing Store: 25, Department: 24 (1859/3326) ---
#   WMAE: 728.01
#
# --- Processing Store: 25, Department: 25 (1860/3326) ---
#   WMAE: 667.57
#
# --- Processing Store: 25, Department: 26 (1861/3326) ---
#   WMAE: 682.90
#
# --- Processing Store: 25, Department: 27 (1862/3326) ---
#   WMAE: 182.15
#
# --- Processing Store: 25, Department: 28 (1863/3326) ---
#   WMAE: 184.32
#
# --- Processing Store: 25, Department: 29 (1864/3326) ---
#   WMAE: 479.17
#
# --- Processing Store: 25, Department: 30 (1865/3326) ---
#   WMAE: 894.98
#
# --- Processing Store: 25, Department: 31 (1866/3326) ---
#   WMAE: 192.63
#
# --- Processing Store: 25, Department: 32 (1867/3326) ---
#   WMAE: 821.63
#
# --- Processing Store: 25, Department: 33 (1868/3326) ---
#   WMAE: 379.01
#
# --- Processing Store: 25, Department: 34 (1869/3326) ---
#   WMAE: 955.13
#
# --- Processing Store: 25, Department: 35 (1870/3326) ---
#   WMAE: 258.17
#
# --- Processing Store: 25, Department: 36 (1871/3326) ---
#   WMAE: 208.14
#
# --- Processing Store: 25, Department: 37 (1872/3326) ---
#   WMAE: 324.80
#
# --- Processing Store: 25, Department: 38 (1873/3326) ---
#   WMAE: 2513.77
#
# --- Processing Store: 25, Department: 40 (1874/3326) ---
#   WMAE: 1042.19
#
# --- Processing Store: 25, Department: 41 (1875/3326) ---
#   WMAE: 1002.14
#
# --- Processing Store: 25, Department: 42 (1876/3326) ---
#   WMAE: 391.75
#
# --- Processing Store: 25, Department: 44 (1877/3326) ---
#   WMAE: 348.74
#
# --- Processing Store: 25, Department: 45 (1878/3326) ---
#   Skipping (Store 25, Dept 45): Not enough training data points.
#
# --- Processing Store: 25, Department: 46 (1879/3326) ---
#   WMAE: 1732.73
#
# --- Processing Store: 25, Department: 47 (1880/3326) ---
#   Skipping (Store 25, Dept 47): Not enough training data points.
#
# --- Processing Store: 25, Department: 48 (1881/3326) ---
#   Skipping (Store 25, Dept 48): Not enough training data points.
#
# --- Processing Store: 25, Department: 49 (1882/3326) ---
#   WMAE: 1953.27
#
# --- Processing Store: 25, Department: 50 (1883/3326) ---
#   WMAE: 323.99
#
# --- Processing Store: 25, Department: 51 (1884/3326) ---
#   Skipping (Store 25, Dept 51): Not enough training data points.
#
# --- Processing Store: 25, Department: 52 (1885/3326) ---
#   WMAE: 264.56
#
# --- Processing Store: 25, Department: 54 (1886/3326) ---
#   Skipping (Store 25, Dept 54): Not enough training data points.
#
# --- Processing Store: 25, Department: 55 (1887/3326) ---
#   WMAE: 1366.51
#
# --- Processing Store: 25, Department: 56 (1888/3326) ---
#   WMAE: 775.49
#
# --- Processing Store: 25, Department: 58 (1889/3326) ---
#   Error fitting/predicting (Store 25, Dept 58): 'The `start` argument could not be matched to a location related to the index of the data.'
#
# --- Processing Store: 25, Department: 59 (1890/3326) ---
#   WMAE: 232.17
#
# --- Processing Store: 25, Department: 60 (1891/3326) ---
#   Skipping (Store 25, Dept 60): Not enough training data points.
#
# --- Processing Store: 25, Department: 67 (1892/3326) ---
#   WMAE: 1010.00
#
# --- Processing Store: 25, Department: 71 (1893/3326) ---
#   WMAE: 205.83
#
# --- Processing Store: 25, Department: 72 (1894/3326) ---
#   WMAE: 4168.20
#
# --- Processing Store: 25, Department: 74 (1895/3326) ---
#   WMAE: 816.77
#
# --- Processing Store: 25, Department: 77 (1896/3326) ---
#   Skipping (Store 25, Dept 77): Not enough training data points.
#
# --- Processing Store: 25, Department: 78 (1897/3326) ---
#   Skipping (Store 25, Dept 78): Not enough training data points.
#
# --- Processing Store: 25, Department: 79 (1898/3326) ---
#   WMAE: 568.00
#
# --- Processing Store: 25, Department: 80 (1899/3326) ---
#   Error fitting/predicting (Store 25, Dept 80): 'The `start` argument could not be matched to a location related to the index of the data.'
#
# --- Processing Store: 25, Department: 81 (1900/3326) ---
#   WMAE: 556.62
#
# --- Processing Store: 25, Department: 82 (1901/3326) ---
#   WMAE: 437.88
#
# --- Processing Store: 25, Department: 83 (1902/3326) ---
#   WMAE: 49.17
#
# --- Processing Store: 25, Department: 85 (1903/3326) ---
#   WMAE: 508.51
#
# --- Processing Store: 25, Department: 87 (1904/3326) ---
#   WMAE: 742.37
#
# --- Processing Store: 25, Department: 90 (1905/3326) ---
#   WMAE: 904.82
#
# --- Processing Store: 25, Department: 91 (1906/3326) ---
#   WMAE: 673.94
#
# --- Processing Store: 25, Department: 92 (1907/3326) ---
#   WMAE: 2231.33
#
# --- Processing Store: 25, Department: 93 (1908/3326) ---
#   WMAE: 180.52
#
# --- Processing Store: 25, Department: 94 (1909/3326) ---
#   Error fitting/predicting (Store 25, Dept 94): 'The `start` argument could not be matched to a location related to the index of the data.'
#
# --- Processing Store: 25, Department: 95 (1910/3326) ---
#   WMAE: 2395.89
#
# --- Processing Store: 25, Department: 97 (1911/3326) ---
#   WMAE: 256.83
#
# --- Processing Store: 25, Department: 98 (1912/3326) ---
#   Error fitting/predicting (Store 25, Dept 98): 'The `start` argument could not be matched to a location related to the index of the data.'
#
# --- Processing Store: 26, Department: 1 (1913/3326) ---
#   WMAE: 1475.01
#
# --- Processing Store: 26, Department: 2 (1914/3326) ---
#   WMAE: 941.82
#
# --- Processing Store: 26, Department: 3 (1915/3326) ---
#   WMAE: 6090.87
#
# --- Processing Store: 26, Department: 4 (1916/3326) ---
#   WMAE: 1282.14
#
# --- Processing Store: 26, Department: 5 (1917/3326) ---
#   WMAE: 2601.89
#
# --- Processing Store: 26, Department: 6 (1918/3326) ---
#   WMAE: 878.43
#
# --- Processing Store: 26, Department: 7 (1919/3326) ---
#   WMAE: 2901.67
#
# --- Processing Store: 26, Department: 8 (1920/3326) ---
#   WMAE: 2822.36
#
# --- Processing Store: 26, Department: 9 (1921/3326) ---
#   WMAE: 1802.27
#
# --- Processing Store: 26, Department: 10 (1922/3326) ---
#   WMAE: 1208.05
#
# --- Processing Store: 26, Department: 11 (1923/3326) ---
#   WMAE: 649.78
#
# --- Processing Store: 26, Department: 12 (1924/3326) ---
#   WMAE: 814.33
#
# --- Processing Store: 26, Department: 13 (1925/3326) ---
#   WMAE: 938.09
#
# --- Processing Store: 26, Department: 14 (1926/3326) ---
#   WMAE: 449.00
#
# --- Processing Store: 26, Department: 16 (1927/3326) ---
#   WMAE: 3275.46
#
# --- Processing Store: 26, Department: 17 (1928/3326) ---
#   WMAE: 759.82
#
# --- Processing Store: 26, Department: 18 (1929/3326) ---
#   Error fitting/predicting (Store 26, Dept 18): 'The `start` argument could not be matched to a location related to the index of the data.'
#
# --- Processing Store: 26, Department: 19 (1930/3326) ---
#   WMAE: 316.01
#
# --- Processing Store: 26, Department: 20 (1931/3326) ---
#   WMAE: 316.28
#
# --- Processing Store: 26, Department: 21 (1932/3326) ---
#   WMAE: 289.82
#
# --- Processing Store: 26, Department: 22 (1933/3326) ---
#   WMAE: 571.28
#
# --- Processing Store: 26, Department: 23 (1934/3326) ---
#   WMAE: 1180.82
#
# --- Processing Store: 26, Department: 24 (1935/3326) ---
#   WMAE: 956.89
#
# --- Processing Store: 26, Department: 25 (1936/3326) ---
#   WMAE: 460.05
#
# --- Processing Store: 26, Department: 26 (1937/3326) ---
#   WMAE: 454.40
#
# --- Processing Store: 26, Department: 27 (1938/3326) ---
#   WMAE: 205.23
#
# --- Processing Store: 26, Department: 28 (1939/3326) ---
#   WMAE: 121.84
#
# --- Processing Store: 26, Department: 29 (1940/3326) ---
#   WMAE: 397.75
#
# --- Processing Store: 26, Department: 30 (1941/3326) ---
#   WMAE: 377.76
#
# --- Processing Store: 26, Department: 31 (1942/3326) ---
#   WMAE: 175.80
#
# --- Processing Store: 26, Department: 32 (1943/3326) ---
#   WMAE: 798.87
#
# --- Processing Store: 26, Department: 33 (1944/3326) ---
#   WMAE: 905.21
#
# --- Processing Store: 26, Department: 34 (1945/3326) ---
#   WMAE: 737.03
#
# --- Processing Store: 26, Department: 35 (1946/3326) ---
#   WMAE: 252.66
#
# --- Processing Store: 26, Department: 36 (1947/3326) ---
#   WMAE: 157.24
#
# --- Processing Store: 26, Department: 38 (1948/3326) ---
#   WMAE: 9906.21
#
# --- Processing Store: 26, Department: 40 (1949/3326) ---
#   WMAE: 1332.21
#
# --- Processing Store: 26, Department: 41 (1950/3326) ---
#   WMAE: 549.35
#
# --- Processing Store: 26, Department: 42 (1951/3326) ---
#   WMAE: 435.35
#
# --- Processing Store: 26, Department: 44 (1952/3326) ---
#   WMAE: 656.37
#
# --- Processing Store: 26, Department: 45 (1953/3326) ---
#   Skipping (Store 26, Dept 45): Not enough training data points.
#
# --- Processing Store: 26, Department: 46 (1954/3326) ---
#   WMAE: 769.39
#
# --- Processing Store: 26, Department: 47 (1955/3326) ---
#   Skipping (Store 26, Dept 47): Not enough training data points.
#
# --- Processing Store: 26, Department: 48 (1956/3326) ---
#   Skipping (Store 26, Dept 48): Not enough training data points.
#
# --- Processing Store: 26, Department: 49 (1957/3326) ---
#   WMAE: 537.80
#
# --- Processing Store: 26, Department: 50 (1958/3326) ---
#   Skipping (Store 26, Dept 50): Not enough training data points.
#
# --- Processing Store: 26, Department: 51 (1959/3326) ---
#   Skipping (Store 26, Dept 51): Not enough training data points.
#
# --- Processing Store: 26, Department: 52 (1960/3326) ---
#   WMAE: 246.82
#
# --- Processing Store: 26, Department: 54 (1961/3326) ---
#   Error fitting/predicting (Store 26, Dept 54): 'The `start` argument could not be matched to a location related to the index of the data.'
#
# --- Processing Store: 26, Department: 55 (1962/3326) ---
#   WMAE: 1344.42
#
# --- Processing Store: 26, Department: 56 (1963/3326) ---
#   WMAE: 1131.54
#
# --- Processing Store: 26, Department: 59 (1964/3326) ---
#   WMAE: 157.03
#
# --- Processing Store: 26, Department: 60 (1965/3326) ---
#   Skipping (Store 26, Dept 60): Not enough training data points.
#
# --- Processing Store: 26, Department: 67 (1966/3326) ---
#   WMAE: 913.15
#
# --- Processing Store: 26, Department: 71 (1967/3326) ---
#   WMAE: 422.60
#
# --- Processing Store: 26, Department: 72 (1968/3326) ---
#   WMAE: 4405.04
#
# --- Processing Store: 26, Department: 74 (1969/3326) ---
#   WMAE: 621.77
#
# --- Processing Store: 26, Department: 77 (1970/3326) ---
#   Skipping (Store 26, Dept 77): Not enough training data points.
#
# --- Processing Store: 26, Department: 78 (1971/3326) ---
#   Skipping (Store 26, Dept 78): Not enough training data points.
#
# --- Processing Store: 26, Department: 79 (1972/3326) ---
#   WMAE: 892.74
#
# --- Processing Store: 26, Department: 80 (1973/3326) ---
#   WMAE: 906.78
#
# --- Processing Store: 26, Department: 81 (1974/3326) ---
#   WMAE: 880.97
#
# --- Processing Store: 26, Department: 82 (1975/3326) ---
#   WMAE: 535.38
#
# --- Processing Store: 26, Department: 83 (1976/3326) ---
#   WMAE: 352.06
#
# --- Processing Store: 26, Department: 85 (1977/3326) ---
#   WMAE: 419.79
#
# --- Processing Store: 26, Department: 87 (1978/3326) ---
#   WMAE: 2331.83
#
# --- Processing Store: 26, Department: 90 (1979/3326) ---
#   WMAE: 4488.88
#
# --- Processing Store: 26, Department: 91 (1980/3326) ---
#   WMAE: 4739.87
#
# --- Processing Store: 26, Department: 92 (1981/3326) ---
#   WMAE: 8279.76
#
# --- Processing Store: 26, Department: 93 (1982/3326) ---
#   WMAE: 4330.17
#
# --- Processing Store: 26, Department: 94 (1983/3326) ---
#   WMAE: 2801.83
#
# --- Processing Store: 26, Department: 95 (1984/3326) ---
#   WMAE: 6467.10
#
# --- Processing Store: 26, Department: 96 (1985/3326) ---
#   WMAE: 2987.77
#
# --- Processing Store: 26, Department: 97 (1986/3326) ---
#   WMAE: 1544.11
#
# --- Processing Store: 26, Department: 98 (1987/3326) ---
#   WMAE: 462.99
#
# --- Processing Store: 26, Department: 99 (1988/3326) ---
#   Skipping (Store 26, Dept 99): Not enough training data points.
#
# --- Processing Store: 27, Department: 1 (1989/3326) ---
#   WMAE: 6261.01
#
# --- Processing Store: 27, Department: 2 (1990/3326) ---
#   WMAE: 5618.26
#
# --- Processing Store: 27, Department: 3 (1991/3326) ---
#   WMAE: 24372.79
#
# --- Processing Store: 27, Department: 4 (1992/3326) ---
#   WMAE: 3973.79
#
# --- Processing Store: 27, Department: 5 (1993/3326) ---
#   WMAE: 4856.36
#
# --- Processing Store: 27, Department: 6 (1994/3326) ---
#   WMAE: 2794.44
#
# --- Processing Store: 27, Department: 7 (1995/3326) ---
#   WMAE: 9399.14
#
# --- Processing Store: 27, Department: 8 (1996/3326) ---
#   WMAE: 1928.36
#
# --- Processing Store: 27, Department: 9 (1997/3326) ---
#   WMAE: 2805.20
#
# --- Processing Store: 27, Department: 10 (1998/3326) ---
#   WMAE: 3139.54
#
# --- Processing Store: 27, Department: 11 (1999/3326) ---
#   WMAE: 3651.59
#
# --- Processing Store: 27, Department: 12 (2000/3326) ---
#   WMAE: 436.57
#
# --- Processing Store: 27, Department: 13 (2001/3326) ---
#   WMAE: 3727.79
#
# --- Processing Store: 27, Department: 14 (2002/3326) ---
#   WMAE: 3279.86
#
# --- Processing Store: 27, Department: 16 (2003/3326) ---
#   WMAE: 13486.98
#
# --- Processing Store: 27, Department: 17 (2004/3326) ---
#   WMAE: 1131.93
#
# --- Processing Store: 27, Department: 18 (2005/3326) ---
#   Error fitting/predicting (Store 27, Dept 18): 'The `start` argument could not be matched to a location related to the index of the data.'
#
# --- Processing Store: 27, Department: 19 (2006/3326) ---
#   WMAE: 349.13
#
# --- Processing Store: 27, Department: 20 (2007/3326) ---
#   WMAE: 1962.92
#
# --- Processing Store: 27, Department: 21 (2008/3326) ---
#   WMAE: 984.34
#
# --- Processing Store: 27, Department: 22 (2009/3326) ---
#   WMAE: 1062.31
#
# --- Processing Store: 27, Department: 23 (2010/3326) ---
#   WMAE: 2523.53
#
# --- Processing Store: 27, Department: 24 (2011/3326) ---
#   WMAE: 3767.24
#
# --- Processing Store: 27, Department: 25 (2012/3326) ---
#   WMAE: 1820.37
#
# --- Processing Store: 27, Department: 26 (2013/3326) ---
#   WMAE: 1865.76
#
# --- Processing Store: 27, Department: 27 (2014/3326) ---
#   WMAE: 267.46
#
# --- Processing Store: 27, Department: 28 (2015/3326) ---
#   WMAE: 270.56
#
# --- Processing Store: 27, Department: 29 (2016/3326) ---
#   WMAE: 606.95
#
# --- Processing Store: 27, Department: 30 (2017/3326) ---
#   WMAE: 1099.81
#
# --- Processing Store: 27, Department: 31 (2018/3326) ---
#   WMAE: 1661.36
#
# --- Processing Store: 27, Department: 32 (2019/3326) ---
#   WMAE: 1358.80
#
# --- Processing Store: 27, Department: 33 (2020/3326) ---
#   WMAE: 2750.54
#
# --- Processing Store: 27, Department: 34 (2021/3326) ---
#   WMAE: 1460.14
#
# --- Processing Store: 27, Department: 35 (2022/3326) ---
#   WMAE: 326.67
#
# --- Processing Store: 27, Department: 36 (2023/3326) ---
#   WMAE: 1060.40
#
# --- Processing Store: 27, Department: 37 (2024/3326) ---
#   WMAE: 238.87
#
# --- Processing Store: 27, Department: 38 (2025/3326) ---
#   WMAE: 3343.88
#
# --- Processing Store: 27, Department: 39 (2026/3326) ---
#   Skipping (Store 27, Dept 39): Not enough training data points.
#
# --- Processing Store: 27, Department: 40 (2027/3326) ---
#   WMAE: 2510.46
#
# --- Processing Store: 27, Department: 41 (2028/3326) ---
#   WMAE: 207.32
#
# --- Processing Store: 27, Department: 42 (2029/3326) ---
#   WMAE: 806.26
#
# --- Processing Store: 27, Department: 44 (2030/3326) ---
#   WMAE: 652.78
#
# --- Processing Store: 27, Department: 45 (2031/3326) ---
#   Skipping (Store 27, Dept 45): Not enough training data points.
#
# --- Processing Store: 27, Department: 46 (2032/3326) ---
#   WMAE: 3551.80
#
# --- Processing Store: 27, Department: 47 (2033/3326) ---
#   Skipping (Store 27, Dept 47): Not enough training data points.
#
# --- Processing Store: 27, Department: 49 (2034/3326) ---
#   WMAE: 1476.43
#
# --- Processing Store: 27, Department: 50 (2035/3326) ---
#   WMAE: 316.94
#
# --- Processing Store: 27, Department: 51 (2036/3326) ---
#   Skipping (Store 27, Dept 51): Not enough training data points.
#
# --- Processing Store: 27, Department: 52 (2037/3326) ---
#   WMAE: 217.91
#
# --- Processing Store: 27, Department: 54 (2038/3326) ---
#   Error fitting/predicting (Store 27, Dept 54): 'The `start` argument could not be matched to a location related to the index of the data.'
#
# --- Processing Store: 27, Department: 55 (2039/3326) ---
#   WMAE: 4703.89
#
# --- Processing Store: 27, Department: 56 (2040/3326) ---
#   WMAE: 1175.78
#
# --- Processing Store: 27, Department: 58 (2041/3326) ---
#   Error fitting/predicting (Store 27, Dept 58): 'The `start` argument could not be matched to a location related to the index of the data.'
#
# --- Processing Store: 27, Department: 59 (2042/3326) ---
#   WMAE: 597.27
#
# --- Processing Store: 27, Department: 60 (2043/3326) ---
#   Error fitting/predicting (Store 27, Dept 60): 'The `start` argument could not be matched to a location related to the index of the data.'
#
# --- Processing Store: 27, Department: 67 (2044/3326) ---
#   WMAE: 3008.51
#
# --- Processing Store: 27, Department: 71 (2045/3326) ---
#   WMAE: 1814.74
#
# --- Processing Store: 27, Department: 72 (2046/3326) ---
#   WMAE: 9285.00
#
# --- Processing Store: 27, Department: 74 (2047/3326) ---
#   WMAE: 5163.63
#
# --- Processing Store: 27, Department: 77 (2048/3326) ---
#   Skipping (Store 27, Dept 77): Not enough training data points.
#
# --- Processing Store: 27, Department: 78 (2049/3326) ---
#   Skipping (Store 27, Dept 78): Not enough training data points.
#
# --- Processing Store: 27, Department: 79 (2050/3326) ---
#   WMAE: 3586.48
#
# --- Processing Store: 27, Department: 80 (2051/3326) ---
#   WMAE: 1322.49
#
# --- Processing Store: 27, Department: 81 (2052/3326) ---
#   WMAE: 2706.31
#
# --- Processing Store: 27, Department: 82 (2053/3326) ---
#   WMAE: 3221.38
#
# --- Processing Store: 27, Department: 83 (2054/3326) ---
#   WMAE: 1330.21
#
# --- Processing Store: 27, Department: 85 (2055/3326) ---
#   WMAE: 1112.19
#
# --- Processing Store: 27, Department: 87 (2056/3326) ---
#   WMAE: 1235.89
#
# --- Processing Store: 27, Department: 90 (2057/3326) ---
#   WMAE: 5143.39
#
# --- Processing Store: 27, Department: 91 (2058/3326) ---
#   WMAE: 5086.24
#
# --- Processing Store: 27, Department: 92 (2059/3326) ---
#   WMAE: 10219.35
#
# --- Processing Store: 27, Department: 93 (2060/3326) ---
#   WMAE: 5078.90
#
# --- Processing Store: 27, Department: 94 (2061/3326) ---
#   WMAE: 4472.45
#
# --- Processing Store: 27, Department: 95 (2062/3326) ---
#   WMAE: 11840.14
#
# --- Processing Store: 27, Department: 96 (2063/3326) ---
#   WMAE: 3760.80
#
# --- Processing Store: 27, Department: 97 (2064/3326) ---
#   WMAE: 1846.35
#
# --- Processing Store: 27, Department: 98 (2065/3326) ---
#   WMAE: 826.74
#
# --- Processing Store: 27, Department: 99 (2066/3326) ---
#   Skipping (Store 27, Dept 99): Not enough training data points.
#
# --- Processing Store: 28, Department: 1 (2067/3326) ---
#   WMAE: 2555.73
#
# --- Processing Store: 28, Department: 2 (2068/3326) ---
#   WMAE: 4246.06
#
# --- Processing Store: 28, Department: 3 (2069/3326) ---
#   WMAE: 22052.81
#
# --- Processing Store: 28, Department: 4 (2070/3326) ---
#   WMAE: 2736.93
#
# --- Processing Store: 28, Department: 5 (2071/3326) ---
#   WMAE: 3412.44
#
# --- Processing Store: 28, Department: 6 (2072/3326) ---
#   WMAE: 1768.21
#
# --- Processing Store: 28, Department: 7 (2073/3326) ---
#   WMAE: 4330.99
#
# --- Processing Store: 28, Department: 8 (2074/3326) ---
#   WMAE: 1194.88
#
# --- Processing Store: 28, Department: 9 (2075/3326) ---
#   WMAE: 1340.57
#
# --- Processing Store: 28, Department: 10 (2076/3326) ---
#   WMAE: 1138.71
#
# --- Processing Store: 28, Department: 11 (2077/3326) ---
#   WMAE: 2300.74
#
# --- Processing Store: 28, Department: 12 (2078/3326) ---
#   WMAE: 235.83
#
# --- Processing Store: 28, Department: 13 (2079/3326) ---
#   WMAE: 3000.56
#
# --- Processing Store: 28, Department: 14 (2080/3326) ---
#   WMAE: 1994.35
#
# --- Processing Store: 28, Department: 16 (2081/3326) ---
#   WMAE: 2156.39
#
# --- Processing Store: 28, Department: 17 (2082/3326) ---
#   WMAE: 1056.68
#
# --- Processing Store: 28, Department: 18 (2083/3326) ---
#   Skipping (Store 28, Dept 18): Not enough training data points.
#
# --- Processing Store: 28, Department: 19 (2084/3326) ---
#   WMAE: 321.04
#
# --- Processing Store: 28, Department: 20 (2085/3326) ---
#   WMAE: 855.22
#
# --- Processing Store: 28, Department: 21 (2086/3326) ---
#   WMAE: 456.50
#
# --- Processing Store: 28, Department: 22 (2087/3326) ---
#   WMAE: 782.01
#
# --- Processing Store: 28, Department: 23 (2088/3326) ---
#   WMAE: 7810.64
#
# --- Processing Store: 28, Department: 24 (2089/3326) ---
#   WMAE: 4161.58
#
# --- Processing Store: 28, Department: 25 (2090/3326) ---
#   WMAE: 2315.96
#
# --- Processing Store: 28, Department: 26 (2091/3326) ---
#   WMAE: 758.71
#
# --- Processing Store: 28, Department: 27 (2092/3326) ---
#   WMAE: 387.91
#
# --- Processing Store: 28, Department: 28 (2093/3326) ---
#   WMAE: 44.06
#
# --- Processing Store: 28, Department: 29 (2094/3326) ---
#   WMAE: 751.60
#
# --- Processing Store: 28, Department: 30 (2095/3326) ---
#   WMAE: 969.04
#
# --- Processing Store: 28, Department: 31 (2096/3326) ---
#   WMAE: 2285.81
#
# --- Processing Store: 28, Department: 32 (2097/3326) ---
#   WMAE: 1824.59
#
# --- Processing Store: 28, Department: 33 (2098/3326) ---
#   WMAE: 3758.45
#
# --- Processing Store: 28, Department: 34 (2099/3326) ---
#   WMAE: 3027.47
#
# --- Processing Store: 28, Department: 35 (2100/3326) ---
#   WMAE: 495.11
#
# --- Processing Store: 28, Department: 36 (2101/3326) ---
#   WMAE: 679.40
#
# --- Processing Store: 28, Department: 37 (2102/3326) ---
#   WMAE: 203.41
#
# --- Processing Store: 28, Department: 38 (2103/3326) ---
#   WMAE: 5267.80
#
# --- Processing Store: 28, Department: 40 (2104/3326) ---
#   WMAE: 2168.65
#
# --- Processing Store: 28, Department: 41 (2105/3326) ---
#   WMAE: 233.22
#
# --- Processing Store: 28, Department: 42 (2106/3326) ---
#   WMAE: 553.00
#
# --- Processing Store: 28, Department: 43 (2107/3326) ---
#   Skipping (Store 28, Dept 43): Not enough training data points.
#
# --- Processing Store: 28, Department: 44 (2108/3326) ---
#   WMAE: 629.10
#
# --- Processing Store: 28, Department: 45 (2109/3326) ---
#   Skipping (Store 28, Dept 45): Not enough training data points.
#
# --- Processing Store: 28, Department: 46 (2110/3326) ---
#   WMAE: 1564.81
#
# --- Processing Store: 28, Department: 47 (2111/3326) ---
#   Skipping (Store 28, Dept 47): Not enough training data points.
#
# --- Processing Store: 28, Department: 49 (2112/3326) ---
#   WMAE: 690.82
#
# --- Processing Store: 28, Department: 51 (2113/3326) ---
#   Skipping (Store 28, Dept 51): Not enough training data points.
#
# --- Processing Store: 28, Department: 52 (2114/3326) ---
#   WMAE: 361.14
#
# --- Processing Store: 28, Department: 54 (2115/3326) ---
#   Error fitting/predicting (Store 28, Dept 54): 'The `start` argument could not be matched to a location related to the index of the data.'
#
# --- Processing Store: 28, Department: 55 (2116/3326) ---
#   WMAE: 3602.00
#
# --- Processing Store: 28, Department: 56 (2117/3326) ---
#   Error fitting/predicting (Store 28, Dept 56): 'The `start` argument could not be matched to a location related to the index of the data.'
#
# --- Processing Store: 28, Department: 58 (2118/3326) ---
#   WMAE: 4206.14
#
# --- Processing Store: 28, Department: 59 (2119/3326) ---
#   WMAE: 503.42
#
# --- Processing Store: 28, Department: 60 (2120/3326) ---
#   WMAE: 94.49
#
# --- Processing Store: 28, Department: 67 (2121/3326) ---
#   WMAE: 853.84
#
# --- Processing Store: 28, Department: 71 (2122/3326) ---
#   WMAE: 1366.64
#
# --- Processing Store: 28, Department: 72 (2123/3326) ---
#   WMAE: 9867.39
#
# --- Processing Store: 28, Department: 74 (2124/3326) ---
#   WMAE: 1378.95
#
# --- Processing Store: 28, Department: 77 (2125/3326) ---
#   Skipping (Store 28, Dept 77): Not enough training data points.
#
# --- Processing Store: 28, Department: 78 (2126/3326) ---
#   Skipping (Store 28, Dept 78): Not enough training data points.
#
# --- Processing Store: 28, Department: 79 (2127/3326) ---
#   WMAE: 3188.54
#
# --- Processing Store: 28, Department: 80 (2128/3326) ---
#   WMAE: 1525.02
#
# --- Processing Store: 28, Department: 81 (2129/3326) ---
#   WMAE: 3013.01
#
# --- Processing Store: 28, Department: 82 (2130/3326) ---
#   WMAE: 1811.36
#
# --- Processing Store: 28, Department: 83 (2131/3326) ---
#   WMAE: 3814.02
#
# --- Processing Store: 28, Department: 85 (2132/3326) ---
#   WMAE: 336.50
#
# --- Processing Store: 28, Department: 87 (2133/3326) ---
#   WMAE: 1379.04
#
# --- Processing Store: 28, Department: 90 (2134/3326) ---
#   WMAE: 12760.06
#
# --- Processing Store: 28, Department: 91 (2135/3326) ---
#   WMAE: 12700.56
#
# --- Processing Store: 28, Department: 92 (2136/3326) ---
#   WMAE: 30884.35
#
# --- Processing Store: 28, Department: 93 (2137/3326) ---
#   WMAE: 20366.53
#
# --- Processing Store: 28, Department: 94 (2138/3326) ---
#   WMAE: 5723.99
#
# --- Processing Store: 28, Department: 95 (2139/3326) ---
#   WMAE: 18504.06
#
# --- Processing Store: 28, Department: 96 (2140/3326) ---
#   WMAE: 1285.23
#
# --- Processing Store: 28, Department: 97 (2141/3326) ---
#   WMAE: 6756.83
#
# --- Processing Store: 28, Department: 98 (2142/3326) ---
#   WMAE: 1017.98
#
# --- Processing Store: 28, Department: 99 (2143/3326) ---
#   Skipping (Store 28, Dept 99): Not enough training data points.
#
# --- Processing Store: 29, Department: 1 (2144/3326) ---
#   WMAE: 2168.08
#
# --- Processing Store: 29, Department: 2 (2145/3326) ---
#   WMAE: 835.29
#
# --- Processing Store: 29, Department: 3 (2146/3326) ---
#   WMAE: 8384.70
#
# --- Processing Store: 29, Department: 4 (2147/3326) ---
#   WMAE: 657.67
#
# --- Processing Store: 29, Department: 5 (2148/3326) ---
#   WMAE: 2334.03
#
# --- Processing Store: 29, Department: 6 (2149/3326) ---
#   WMAE: 1555.98
#
# --- Processing Store: 29, Department: 7 (2150/3326) ---
#   WMAE: 2192.99
#
# --- Processing Store: 29, Department: 8 (2151/3326) ---
#   WMAE: 1591.66
#
# --- Processing Store: 29, Department: 9 (2152/3326) ---
#   WMAE: 2042.45
#
# --- Processing Store: 29, Department: 10 (2153/3326) ---
#   WMAE: 796.75
#
# --- Processing Store: 29, Department: 11 (2154/3326) ---
#   WMAE: 1155.83
#
# --- Processing Store: 29, Department: 12 (2155/3326) ---
#   WMAE: 293.70
#
# --- Processing Store: 29, Department: 13 (2156/3326) ---
#   WMAE: 754.60
#
# --- Processing Store: 29, Department: 14 (2157/3326) ---
#   WMAE: 1263.67
#
# --- Processing Store: 29, Department: 16 (2158/3326) ---
#   WMAE: 2518.04
#
# --- Processing Store: 29, Department: 17 (2159/3326) ---
#   WMAE: 725.95
#
# --- Processing Store: 29, Department: 18 (2160/3326) ---
#   Skipping (Store 29, Dept 18): Not enough training data points.
#
# --- Processing Store: 29, Department: 19 (2161/3326) ---
#   Skipping (Store 29, Dept 19): Not enough training data points.
#
# --- Processing Store: 29, Department: 20 (2162/3326) ---
#   WMAE: 429.42
#
# --- Processing Store: 29, Department: 21 (2163/3326) ---
#   WMAE: 329.86
#
# --- Processing Store: 29, Department: 22 (2164/3326) ---
#   WMAE: 534.77
#
# --- Processing Store: 29, Department: 23 (2165/3326) ---
#   WMAE: 2117.57
#
# --- Processing Store: 29, Department: 24 (2166/3326) ---
#   WMAE: 1277.53
#
# --- Processing Store: 29, Department: 25 (2167/3326) ---
#   WMAE: 502.01
#
# --- Processing Store: 29, Department: 26 (2168/3326) ---
#   WMAE: 684.79
#
# --- Processing Store: 29, Department: 27 (2169/3326) ---
#   WMAE: 260.78
#
# --- Processing Store: 29, Department: 28 (2170/3326) ---
#   WMAE: 174.26
#
# --- Processing Store: 29, Department: 29 (2171/3326) ---
#   WMAE: 668.73
#
# --- Processing Store: 29, Department: 30 (2172/3326) ---
#   WMAE: 574.90
#
# --- Processing Store: 29, Department: 31 (2173/3326) ---
#   WMAE: 560.93
#
# --- Processing Store: 29, Department: 32 (2174/3326) ---
#   WMAE: 911.47
#
# --- Processing Store: 29, Department: 33 (2175/3326) ---
#   WMAE: 933.47
#
# --- Processing Store: 29, Department: 34 (2176/3326) ---
#   WMAE: 693.62
#
# --- Processing Store: 29, Department: 35 (2177/3326) ---
#   WMAE: 219.86
#
# --- Processing Store: 29, Department: 36 (2178/3326) ---
#   WMAE: 267.03
#
# --- Processing Store: 29, Department: 38 (2179/3326) ---
#   WMAE: 2461.98
#
# --- Processing Store: 29, Department: 40 (2180/3326) ---
#   WMAE: 851.22
#
# --- Processing Store: 29, Department: 41 (2181/3326) ---
#   WMAE: 275.46
#
# --- Processing Store: 29, Department: 42 (2182/3326) ---
#   WMAE: 354.00
#
# --- Processing Store: 29, Department: 43 (2183/3326) ---
#   Skipping (Store 29, Dept 43): Not enough training data points.
#
# --- Processing Store: 29, Department: 44 (2184/3326) ---
#   WMAE: 332.34
#
# --- Processing Store: 29, Department: 45 (2185/3326) ---
#   Skipping (Store 29, Dept 45): Not enough training data points.
#
# --- Processing Store: 29, Department: 46 (2186/3326) ---
#   WMAE: 1190.00
#
# --- Processing Store: 29, Department: 47 (2187/3326) ---
#   Skipping (Store 29, Dept 47): Not enough training data points.
#
# --- Processing Store: 29, Department: 48 (2188/3326) ---
#   Skipping (Store 29, Dept 48): Not enough training data points.
#
# --- Processing Store: 29, Department: 49 (2189/3326) ---
#   Skipping (Store 29, Dept 49): Not enough training data points.
#
# --- Processing Store: 29, Department: 51 (2190/3326) ---
#   Skipping (Store 29, Dept 51): Not enough training data points.
#
# --- Processing Store: 29, Department: 52 (2191/3326) ---
#   WMAE: 213.27
#
# --- Processing Store: 29, Department: 54 (2192/3326) ---
#   Skipping (Store 29, Dept 54): Not enough training data points.
#
# --- Processing Store: 29, Department: 55 (2193/3326) ---
#   WMAE: 1707.66
#
# --- Processing Store: 29, Department: 56 (2194/3326) ---
#   WMAE: 604.43
#
# --- Processing Store: 29, Department: 58 (2195/3326) ---
#   Skipping (Store 29, Dept 58): Not enough training data points.
#
# --- Processing Store: 29, Department: 59 (2196/3326) ---
#   WMAE: 187.61
#
# --- Processing Store: 29, Department: 60 (2197/3326) ---
#   Skipping (Store 29, Dept 60): Not enough training data points.
#
# --- Processing Store: 29, Department: 67 (2198/3326) ---
#   WMAE: 951.78
#
# --- Processing Store: 29, Department: 71 (2199/3326) ---
#   WMAE: 743.71
#
# --- Processing Store: 29, Department: 72 (2200/3326) ---
#   WMAE: 4955.64
#
# --- Processing Store: 29, Department: 74 (2201/3326) ---
#   WMAE: 688.44
#
# --- Processing Store: 29, Department: 77 (2202/3326) ---
#   Skipping (Store 29, Dept 77): Not enough training data points.
#
# --- Processing Store: 29, Department: 78 (2203/3326) ---
#   Skipping (Store 29, Dept 78): Not enough training data points.
#
# --- Processing Store: 29, Department: 79 (2204/3326) ---
#   WMAE: 403.63
#
# --- Processing Store: 29, Department: 80 (2205/3326) ---
#   Error fitting/predicting (Store 29, Dept 80): 'The `start` argument could not be matched to a location related to the index of the data.'
#
# --- Processing Store: 29, Department: 81 (2206/3326) ---
#   WMAE: 263.30
#
# --- Processing Store: 29, Department: 82 (2207/3326) ---
#   WMAE: 952.96
#
# --- Processing Store: 29, Department: 83 (2208/3326) ---
#   WMAE: 46.58
#
# --- Processing Store: 29, Department: 85 (2209/3326) ---
#   WMAE: 596.24
#
# --- Processing Store: 29, Department: 87 (2210/3326) ---
#   WMAE: 753.12
#
# --- Processing Store: 29, Department: 90 (2211/3326) ---
#   WMAE: 766.58
#
# --- Processing Store: 29, Department: 91 (2212/3326) ---
#   WMAE: 526.27
#
# --- Processing Store: 29, Department: 92 (2213/3326) ---
#   WMAE: 3132.02
#
# --- Processing Store: 29, Department: 93 (2214/3326) ---
#   WMAE: 443.03
#
# --- Processing Store: 29, Department: 94 (2215/3326) ---
#   Skipping (Store 29, Dept 94): Not enough training data points.
#
# --- Processing Store: 29, Department: 95 (2216/3326) ---
#   WMAE: 1601.20
#
# --- Processing Store: 29, Department: 96 (2217/3326) ---
#   Skipping (Store 29, Dept 96): Not enough training data points.
#
# --- Processing Store: 29, Department: 97 (2218/3326) ---
#   WMAE: 262.95
#
# --- Processing Store: 29, Department: 98 (2219/3326) ---
#   Error fitting/predicting (Store 29, Dept 98): 'The `start` argument could not be matched to a location related to the index of the data.'
#
# --- Processing Store: 29, Department: 99 (2220/3326) ---
#   Skipping (Store 29, Dept 99): Not enough training data points.
#
# --- Processing Store: 30, Department: 1 (2221/3326) ---
#   WMAE: 811.45
#
# --- Processing Store: 30, Department: 2 (2222/3326) ---
#   WMAE: 262.19
#
# --- Processing Store: 30, Department: 3 (2223/3326) ---
#   WMAE: 552.40
#
# --- Processing Store: 30, Department: 4 (2224/3326) ---
#   WMAE: 140.87
#
# --- Processing Store: 30, Department: 5 (2225/3326) ---
#   WMAE: 78.48
#
# ...
#
# --- Processing Store: 43, Department: 67 (3170/3326) ---
#   WMAE: 198.36
#
# --- Processing Store: 43, Department: 71 (3171/3326) ---
#   Skipping (Store 43, Dept 71): Not enough training data points.
#
# --- Processing Store: 43, Department: 72 (3172/3326) ---
#   Error fitting/predicting (Store 43, Dept 72): 'The `start` argument could not be matched to a location related to the index of the data.'
#
# --- Processing Store: 43, Department: 74 (3173/3326) ---
#   WMAE: 141.43
#
# --- Processing Store: 43, Department: 79 (3174/3326) ---
#   WMAE: 2568.74
#
# --- Processing Store: 43, Department: 80 (3175/3326) ---
#   WMAE: 575.95
#
# --- Processing Store: 43, Department: 81 (3176/3326) ---
#   WMAE: 730.53
#
# --- Processing Store: 43, Department: 82 (3177/3326) ---
#   WMAE: 671.61
#
# --- Processing Store: 43, Department: 83 (3178/3326) ---
#   WMAE: 610.40
#
# --- Processing Store: 43, Department: 85 (3179/3326) ---
#   Skipping (Store 43, Dept 85): Not enough training data points.
#
# --- Processing Store: 43, Department: 87 (3180/3326) ---
#   Error fitting/predicting (Store 43, Dept 87): 'The `start` argument could not be matched to a location related to the index of the data.'
#
# --- Processing Store: 43, Department: 90 (3181/3326) ---
#   WMAE: 3816.96
#
# --- Processing Store: 43, Department: 91 (3182/3326) ---
#   WMAE: 3083.86
#
# --- Processing Store: 43, Department: 92 (3183/3326) ---
#   WMAE: 5058.49
#
# --- Processing Store: 43, Department: 93 (3184/3326) ---
#   WMAE: 2703.47
#
# --- Processing Store: 43, Department: 94 (3185/3326) ---
#   WMAE: 2949.44
#
# --- Processing Store: 43, Department: 95 (3186/3326) ---
#   WMAE: 4816.53
#
# --- Processing Store: 43, Department: 96 (3187/3326) ---
#   WMAE: 3169.51
#
# --- Processing Store: 43, Department: 97 (3188/3326) ---
#   WMAE: 1758.53
#
# --- Processing Store: 43, Department: 98 (3189/3326) ---
#   WMAE: 535.30
#
# --- Processing Store: 43, Department: 99 (3190/3326) ---
#   Skipping (Store 43, Dept 99): Not enough training data points.
#
# --- Processing Store: 44, Department: 1 (3191/3326) ---
#   WMAE: 1262.13
#
# --- Processing Store: 44, Department: 2 (3192/3326) ---
#   WMAE: 498.49
#
# --- Processing Store: 44, Department: 3 (3193/3326) ---
#   WMAE: 663.12
#
# --- Processing Store: 44, Department: 4 (3194/3326) ---
#   WMAE: 323.20
#
# --- Processing Store: 44, Department: 5 (3195/3326) ---
#   WMAE: 106.22
#
# --- Processing Store: 44, Department: 6 (3196/3326) ---
#   Error fitting/predicting (Store 44, Dept 6): 'The `start` argument could not be matched to a location related to the index of the data.'
#
# --- Processing Store: 44, Department: 7 (3197/3326) ---
#   WMAE: 209.32
#
# --- Processing Store: 44, Department: 8 (3198/3326) ---
#   WMAE: 673.13
#
# --- Processing Store: 44, Department: 9 (3199/3326) ---
#   WMAE: 48.61
#
# --- Processing Store: 44, Department: 10 (3200/3326) ---
#   WMAE: 39.84
#
# --- Processing Store: 44, Department: 11 (3201/3326) ---
#   WMAE: 79.00
#
# --- Processing Store: 44, Department: 12 (3202/3326) ---
#   WMAE: 30.06
#
# --- Processing Store: 44, Department: 13 (3203/3326) ---
#   WMAE: 478.70
#
# --- Processing Store: 44, Department: 14 (3204/3326) ---
#   WMAE: 37.26
#
# --- Processing Store: 44, Department: 16 (3205/3326) ---
#   WMAE: 230.40
#
# --- Processing Store: 44, Department: 17 (3206/3326) ---
#   WMAE: 41.29
#
# --- Processing Store: 44, Department: 18 (3207/3326) ---
#   Skipping (Store 44, Dept 18): Not enough training data points.
#
# --- Processing Store: 44, Department: 20 (3208/3326) ---
#   Skipping (Store 44, Dept 20): Not enough training data points.
#
# --- Processing Store: 44, Department: 21 (3209/3326) ---
#   WMAE: 84.58
#
# --- Processing Store: 44, Department: 22 (3210/3326) ---
#   Skipping (Store 44, Dept 22): Not enough training data points.
#
# --- Processing Store: 44, Department: 23 (3211/3326) ---
#   Skipping (Store 44, Dept 23): Not enough training data points.
#
# --- Processing Store: 44, Department: 24 (3212/3326) ---
#   Skipping (Store 44, Dept 24): Not enough training data points.
#
# --- Processing Store: 44, Department: 25 (3213/3326) ---
#   WMAE: 10.07
#
# --- Processing Store: 44, Department: 26 (3214/3326) ---
#   Skipping (Store 44, Dept 26): Not enough training data points.
#
# --- Processing Store: 44, Department: 27 (3215/3326) ---
#   Skipping (Store 44, Dept 27): Not enough training data points.
#
# --- Processing Store: 44, Department: 28 (3216/3326) ---
#   WMAE: 26.06
#
# --- Processing Store: 44, Department: 31 (3217/3326) ---
#   Skipping (Store 44, Dept 31): Not enough training data points.
#
# --- Processing Store: 44, Department: 32 (3218/3326) ---
#   Error fitting/predicting (Store 44, Dept 32): 'The `start` argument could not be matched to a location related to the index of the data.'
#
# --- Processing Store: 44, Department: 33 (3219/3326) ---
#   Skipping (Store 44, Dept 33): Not enough training data points.
#
# --- Processing Store: 44, Department: 34 (3220/3326) ---
#   Skipping (Store 44, Dept 34): Not enough training data points.
#
# --- Processing Store: 44, Department: 38 (3221/3326) ---
#   WMAE: 5045.61
#
# --- Processing Store: 44, Department: 40 (3222/3326) ---
#   WMAE: 1076.69
#
# --- Processing Store: 44, Department: 42 (3223/3326) ---
#   Error fitting/predicting (Store 44, Dept 42): 'The `start` argument could not be matched to a location related to the index of the data.'
#
# --- Processing Store: 44, Department: 44 (3224/3326) ---
#   Skipping (Store 44, Dept 44): Not enough training data points.
#
# --- Processing Store: 44, Department: 46 (3225/3326) ---
#   WMAE: 220.97
#
# --- Processing Store: 44, Department: 49 (3226/3326) ---
#   Skipping (Store 44, Dept 49): Not enough training data points.
#
# --- Processing Store: 44, Department: 52 (3227/3326) ---
#   WMAE: 8.59
#
# --- Processing Store: 44, Department: 55 (3228/3326) ---
#   Skipping (Store 44, Dept 55): Not enough training data points.
#
# --- Processing Store: 44, Department: 56 (3229/3326) ---
#   Skipping (Store 44, Dept 56): Not enough training data points.
#
# --- Processing Store: 44, Department: 59 (3230/3326) ---
#   Error fitting/predicting (Store 44, Dept 59): 'The `start` argument could not be matched to a location related to the index of the data.'
#
# --- Processing Store: 44, Department: 60 (3231/3326) ---
#   WMAE: 43.42
#
# --- Processing Store: 44, Department: 67 (3232/3326) ---
#   WMAE: 73.49
#
# --- Processing Store: 44, Department: 71 (3233/3326) ---
#   Skipping (Store 44, Dept 71): Not enough training data points.
#
# --- Processing Store: 44, Department: 72 (3234/3326) ---
#   WMAE: 116.06
#
# --- Processing Store: 44, Department: 74 (3235/3326) ---
#   WMAE: 164.00
#
# --- Processing Store: 44, Department: 79 (3236/3326) ---
#   WMAE: 358.81
#
# --- Processing Store: 44, Department: 80 (3237/3326) ---
#   WMAE: 276.34
#
# --- Processing Store: 44, Department: 81 (3238/3326) ---
#   WMAE: 259.82
#
# --- Processing Store: 44, Department: 82 (3239/3326) ---
#   WMAE: 466.10
#
# --- Processing Store: 44, Department: 83 (3240/3326) ---
#   WMAE: 109.20
#
# --- Processing Store: 44, Department: 85 (3241/3326) ---
#   Error fitting/predicting (Store 44, Dept 85): 'The `start` argument could not be matched to a location related to the index of the data.'
#
# --- Processing Store: 44, Department: 87 (3242/3326) ---
#   WMAE: 79.45
#
# --- Processing Store: 44, Department: 90 (3243/3326) ---
#   WMAE: 1949.43
#
# --- Processing Store: 44, Department: 91 (3244/3326) ---
#   WMAE: 517.07
#
# --- Processing Store: 44, Department: 92 (3245/3326) ---
#   WMAE: 2585.26
#
# --- Processing Store: 44, Department: 93 (3246/3326) ---
#   WMAE: 848.73
#
# --- Processing Store: 44, Department: 94 (3247/3326) ---
#   WMAE: 1107.29
#
# --- Processing Store: 44, Department: 95 (3248/3326) ---
#   WMAE: 1454.25
#
# --- Processing Store: 44, Department: 96 (3249/3326) ---
#   WMAE: 217.90
#
# --- Processing Store: 44, Department: 97 (3250/3326) ---
#   WMAE: 177.58
#
# --- Processing Store: 44, Department: 98 (3251/3326) ---
#   WMAE: 309.67
#
# --- Processing Store: 44, Department: 99 (3252/3326) ---
#   Skipping (Store 44, Dept 99): Not enough training data points.
#
# --- Processing Store: 45, Department: 1 (3253/3326) ---
#   WMAE: 3531.73
#
# --- Processing Store: 45, Department: 2 (3254/3326) ---
#   WMAE: 1625.26
#
# --- Processing Store: 45, Department: 3 (3255/3326) ---
#   WMAE: 8146.18
#
# --- Processing Store: 45, Department: 4 (3256/3326) ---
#   WMAE: 1278.41
#
# --- Processing Store: 45, Department: 5 (3257/3326) ---
#   WMAE: 2730.25
#
# --- Processing Store: 45, Department: 6 (3258/3326) ---
#   WMAE: 1234.26
#
# --- Processing Store: 45, Department: 7 (3259/3326) ---
#   WMAE: 5326.99
#
# --- Processing Store: 45, Department: 8 (3260/3326) ---
#   WMAE: 1457.34
#
# --- Processing Store: 45, Department: 9 (3261/3326) ---
#   WMAE: 1812.55
#
# --- Processing Store: 45, Department: 10 (3262/3326) ---
#   WMAE: 1625.22
#
# --- Processing Store: 45, Department: 11 (3263/3326) ---
#   WMAE: 2927.64
#
# --- Processing Store: 45, Department: 12 (3264/3326) ---
#   WMAE: 250.69
#
# --- Processing Store: 45, Department: 13 (3265/3326) ---
#   WMAE: 1009.82
#
# --- Processing Store: 45, Department: 14 (3266/3326) ---
#   WMAE: 1442.53
#
# --- Processing Store: 45, Department: 16 (3267/3326) ---
#   WMAE: 5912.75
#
# --- Processing Store: 45, Department: 17 (3268/3326) ---
#   WMAE: 693.63
#
# --- Processing Store: 45, Department: 18 (3269/3326) ---
#   Error fitting/predicting (Store 45, Dept 18): 'The `start` argument could not be matched to a location related to the index of the data.'
#
# --- Processing Store: 45, Department: 19 (3270/3326) ---
#   WMAE: 177.00
#
# --- Processing Store: 45, Department: 20 (3271/3326) ---
#   WMAE: 1492.96
#
# --- Processing Store: 45, Department: 21 (3272/3326) ---
#   WMAE: 498.07
#
# --- Processing Store: 45, Department: 22 (3273/3326) ---
#   WMAE: 336.07
#
# --- Processing Store: 45, Department: 23 (3274/3326) ---
#   WMAE: 2930.40
#
# --- Processing Store: 45, Department: 24 (3275/3326) ---
#   WMAE: 865.47
#
# --- Processing Store: 45, Department: 25 (3276/3326) ---
#   WMAE: 558.76
#
# --- Processing Store: 45, Department: 26 (3277/3326) ---
#   WMAE: 1323.23
#
# --- Processing Store: 45, Department: 27 (3278/3326) ---
#   WMAE: 156.14
#
# --- Processing Store: 45, Department: 28 (3279/3326) ---
#   WMAE: 135.90
#
# --- Processing Store: 45, Department: 29 (3280/3326) ---
#   WMAE: 568.73
#
# --- Processing Store: 45, Department: 30 (3281/3326) ---
#   WMAE: 433.57
#
# --- Processing Store: 45, Department: 31 (3282/3326) ---
#   WMAE: 1063.88
#
# --- Processing Store: 45, Department: 32 (3283/3326) ---
#   WMAE: 1367.39
#
# --- Processing Store: 45, Department: 33 (3284/3326) ---
#   WMAE: 848.80
#
# --- Processing Store: 45, Department: 34 (3285/3326) ---
#   WMAE: 1107.06
#
# --- Processing Store: 45, Department: 35 (3286/3326) ---
#   WMAE: 337.15
#
# --- Processing Store: 45, Department: 36 (3287/3326) ---
#   WMAE: 389.68
#
# --- Processing Store: 45, Department: 38 (3288/3326) ---
#   WMAE: 1835.40
#
# --- Processing Store: 45, Department: 40 (3289/3326) ---
#   WMAE: 873.63
#
# --- Processing Store: 45, Department: 41 (3290/3326) ---
#   WMAE: 386.74
#
# --- Processing Store: 45, Department: 42 (3291/3326) ---
#   WMAE: 200.61
#
# --- Processing Store: 45, Department: 44 (3292/3326) ---
#   WMAE: 253.22
#
# --- Processing Store: 45, Department: 45 (3293/3326) ---
#   Skipping (Store 45, Dept 45): Not enough training data points.
#
# --- Processing Store: 45, Department: 46 (3294/3326) ---
#   WMAE: 2166.83
#
# --- Processing Store: 45, Department: 47 (3295/3326) ---
#   Skipping (Store 45, Dept 47): Not enough training data points.
#
# --- Processing Store: 45, Department: 49 (3296/3326) ---
#   Skipping (Store 45, Dept 49): Not enough training data points.
#
# --- Processing Store: 45, Department: 51 (3297/3326) ---
#   Skipping (Store 45, Dept 51): Not enough training data points.
#
# --- Processing Store: 45, Department: 52 (3298/3326) ---
#   WMAE: 235.50
#
# --- Processing Store: 45, Department: 54 (3299/3326) ---
#   Error fitting/predicting (Store 45, Dept 54): 'The `start` argument could not be matched to a location related to the index of the data.'
#
# --- Processing Store: 45, Department: 55 (3300/3326) ---
#   WMAE: 1770.97
#
# --- Processing Store: 45, Department: 56 (3301/3326) ---
#   WMAE: 587.58
#
# --- Processing Store: 45, Department: 58 (3302/3326) ---
#   Error fitting/predicting (Store 45, Dept 58): 'The `start` argument could not be matched to a location related to the index of the data.'
#
# --- Processing Store: 45, Department: 59 (3303/3326) ---
#   WMAE: 311.19
#
# --- Processing Store: 45, Department: 60 (3304/3326) ---
#   WMAE: 53.74
#
# --- Processing Store: 45, Department: 67 (3305/3326) ---
#   WMAE: 1427.65
#
# --- Processing Store: 45, Department: 71 (3306/3326) ---
#   WMAE: 1041.14
#
# --- Processing Store: 45, Department: 72 (3307/3326) ---
#   WMAE: 4106.41
#
# --- Processing Store: 45, Department: 74 (3308/3326) ---
#   WMAE: 1045.33
#
# --- Processing Store: 45, Department: 77 (3309/3326) ---
#   Skipping (Store 45, Dept 77): Not enough training data points.
#
# --- Processing Store: 45, Department: 78 (3310/3326) ---
#   Skipping (Store 45, Dept 78): Not enough training data points.
#
# --- Processing Store: 45, Department: 79 (3311/3326) ---
#   WMAE: 920.00
#
# --- Processing Store: 45, Department: 80 (3312/3326) ---
#   Error fitting/predicting (Store 45, Dept 80): 'The `start` argument could not be matched to a location related to the index of the data.'
#
# --- Processing Store: 45, Department: 81 (3313/3326) ---
#   WMAE: 370.68
#
# --- Processing Store: 45, Department: 82 (3314/3326) ---
#   WMAE: 936.63
#
# --- Processing Store: 45, Department: 83 (3315/3326) ---
#   WMAE: 59.44
#
# --- Processing Store: 45, Department: 85 (3316/3326) ---
#   WMAE: 388.93
#
# --- Processing Store: 45, Department: 87 (3317/3326) ---
#   WMAE: 721.08
#
# --- Processing Store: 45, Department: 90 (3318/3326) ---
#   WMAE: 771.80
#
# --- Processing Store: 45, Department: 91 (3319/3326) ---
#   WMAE: 295.21
#
# --- Processing Store: 45, Department: 92 (3320/3326) ---
#   WMAE: 4077.75
#
# --- Processing Store: 45, Department: 93 (3321/3326) ---
#   WMAE: 471.95
#
# --- Processing Store: 45, Department: 94 (3322/3326) ---
#   Error fitting/predicting (Store 45, Dept 94): 'The `start` argument could not be matched to a location related to the index of the data.'
#
# --- Processing Store: 45, Department: 95 (3323/3326) ---
#   WMAE: 1613.66
#
# --- Processing Store: 45, Department: 96 (3324/3326) ---
#   Skipping (Store 45, Dept 96): Not enough training data points.
#
# --- Processing Store: 45, Department: 97 (3325/3326) ---
#   WMAE: 583.07
#
# --- Processing Store: 45, Department: 98 (3326/3326) ---
#   Error fitting/predicting (Store 45, Dept 98): 'The `start` argument could not be matched to a location related to the index of the data.'
#
# --- All SARIMA Modeling Attempts Complete ---
#
# --- Combining all individual predictions for overall WMAE ---
#
# --- Overall Weighted Mean Absolute Error (WMAE) on Validation Set: 2105.90 ---
#
# --- Summary of Individual Store-Dept Model Results ---
#     Store  Dept          WMAE   Status  Train_Points  Val_Points
# 0       1     1   2089.598771  Success           135           8
# 1       1     2   1820.923942  Success           135           8
# 2       1     3  22549.924423  Success           135           8
# 3       1     4   1972.628220  Success           135           8
# 4       1     5   2530.783730  Success           135           8
# 5       1     6    942.697235  Success           135           8
# 6       1     7   3041.270766  Success           135           8
# 7       1     8   2161.706427  Success           135           8
# 8       1     9   8225.945051  Success           135           8
# 9       1    10   1999.702598  Success           135           8
# 10      1    11   2956.432961  Success           135           8
# 11      1    12   1290.872714  Success           135           8
# 12      1    13   2532.369927  Success           135           8
# 13      1    14   1640.651899  Success           135           8
# 14      1    16   5345.098658  Success           135           8
#
# Total successful models fitted: 2670 (out of 3326)
# Total failed/skipped models: 656
# Average WMAE for successfully fitted models (individual series): 2105.90
#
# --- Number of fitted models stored:  2831

# %%
import pandas as pd
import numpy as np
from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
import gc
from statsmodels.tsa.statespace.sarimax import SARIMAX # Import SARIMAX
import warnings

# Suppress specific warnings from statsmodels that can be noisy during loops
warnings.filterwarnings("ignore", category=UserWarning, module="statsmodels")
warnings.filterwarnings("ignore", category=RuntimeWarning, module="statsmodels")
warnings.filterwarnings("ignore", category=FutureWarning, module="statsmodels")
warnings.filterwarnings("ignore", category=np.VisibleDeprecationWarning, module="statsmodels") # Often appears with older numpy/statsmodels versions
preprocessing_with_date = Pipeline(steps=[
    ('imputer', KeepDateImputer()),
    ('feature_extractor', KeepDateFeatureExtractor(verbose=False)),
    ('categorical_converter', CategoricalFeatureConverter())
])



print("\n--- Applying Preprocessing Pipeline ---")
X_train_processed = preprocessing_with_date.fit_transform(X_train_split)
X_val_processed = preprocessing_with_date.transform(X_val_split)
print("Preprocessing complete.")

print(f"\n--- Data Dimensions After Preprocessing ---")
print(f"X_train_processed shape: {X_train_processed.shape}")
print(f"X_val_processed shape: {X_val_processed.shape}")

# Prepare common exogenous variable columns
numeric_exog_cols = [
    'Temperature', 'Fuel_Price', 'CPI', 'Unemployment',
    'week_of_year', 'day_of_week', 'is_super_bowl', 'is_labor_day',
    'is_thanksgiving', 'is_christmas', 'days_until_super_bowl',
    'days_since_super_bowl', 'days_until_labor_day', 'days_since_labor_day',
    'days_until_thanksgiving', 'days_since_thanksgiving',
    'days_until_christmas', 'days_since_christmas', 'holiday_week_flag',
    'black_friday_week', 'christmas_buildup', 'post_super_bowl',
    'seasonal_sin', 'seasonal_cos', 'holiday_economic_index'
]
# Filter to only include columns that actually exist and are numeric after preprocessing
final_exog_cols = [col for col in numeric_exog_cols if col in X_train_processed.columns and pd.api.types.is_numeric_dtype(X_train_processed[col])]
print(f"Final exogenous columns used ({len(final_exog_cols)}): {final_exog_cols}")

# SARIMA Model Parameters (can be tuned, these are just examples)
sarima_order = (1, 0, 0)
sarima_seasonal_order = (0, 0, 0, 52) # 52 for weekly seasonality

# Define weighted_mean_absolute_error function
def weighted_mean_absolute_error(y_true, y_pred, weights):
    # Ensure all inputs are pandas Series for consistent indexing
    if not isinstance(y_true, pd.Series):
        y_true = pd.Series(y_true)
    if not isinstance(y_pred, pd.Series):
        y_pred = pd.Series(y_pred)
    if not isinstance(weights, pd.Series):
        weights = pd.Series(weights)

    # Align all series based on their DatetimeIndex (or original index if Dates are not unique identifiers)
    # Since y_true, y_pred, weights might come from different filtering operations,
    # it's best to align them by their *original* index if they represent different parts of the same validation set.
    # However, if they are already series of the *same* validation period, direct alignment is fine.
    # For overall WMAE, we will concatenate based on the original index of X_val_split.

    # This function is used for *per-series* WMAE calculation first, then for overall
    # For per-series: they should already be aligned by date if you indexed them by date.
    # For overall: use the index of y_val_split.

    # If y_true, y_pred, weights are from a single (Store,Dept) combination
    # and have already been indexed by date, this alignment ensures integrity.
    aligned_df = pd.DataFrame({
        'y_true': y_true,
        'y_pred': y_pred.reindex(y_true.index), # Reindex y_pred to y_true's index
        'weights': weights.reindex(y_true.index) # Reindex weights to y_true's index
    }).dropna() # Drop rows where any of the three are missing after alignment

    if aligned_df.empty:
        return np.nan

    aligned_df['weights'] = aligned_df['weights'].replace([np.inf, -np.inf], np.nan).fillna(0)

    if aligned_df['weights'].sum() == 0:
        return np.nan # Avoid division by zero if all weights are zero or NaN

    return (aligned_df['weights'] * np.abs(aligned_df['y_true'] - aligned_df['y_pred'])).sum() / aligned_df['weights'].sum()


# --- Store Models and Predictions ---
fitted_models = {} # Dictionary to store SARIMA results objects: {(Store, Dept): sarima_results}
all_individual_predictions = [] # List to collect predictions for later overall WMAE calculation
overall_results_summary = [] # List to store WMAE per series and status


# --- Loop through all unique Store-Department combinations ---
# Create a DataFrame of unique Store-Dept combinations to iterate
unique_store_depts_df = X_train_split[['Store', 'Dept']].drop_duplicates().sort_values(by=['Store', 'Dept']).reset_index(drop=True)
unique_store_depts = unique_store_depts_df.values

print(f"\n--- Starting SARIMA Modeling for {len(unique_store_depts)} Store-Department Combinations ---")

models_processed_count = 0

# No max_combinations_to_run limit, as per your request to process all.
# Be aware: This WILL take a very long time and consume significant memory.

for store_id, dept_id in unique_store_depts:
    models_processed_count += 1
    print(f"\n--- Processing Store: {int(store_id)}, Department: {int(dept_id)} ({models_processed_count}/{len(unique_store_depts)}) ---")

    # Filter processed data for the specific store and department using boolean indexing
    train_idx_combo = (X_train_split['Store'] == store_id) & (X_train_split['Dept'] == dept_id)
    val_idx_combo = (X_val_split['Store'] == store_id) & (X_val_split['Dept'] == dept_id)

    single_train_X = X_train_processed.loc[train_idx_combo]
    single_train_y = y_train_split.loc[train_idx_combo]

    single_val_X = X_val_processed.loc[val_idx_combo]
    single_val_y = y_val_split.loc[val_idx_combo]

    # Check if there's enough data for this combination
    min_obs_required = 2 * sarima_seasonal_order[3] + sum(sarima_order) + sum(sarima_seasonal_order[:3]) + len(final_exog_cols) + 1

    if len(single_train_X) < min_obs_required:
        print(f"  Skipping (Store {int(store_id)}, Dept {int(dept_id)}): Not enough training data points ({len(single_train_X)} < {min_obs_required} required).")
        overall_results_summary.append({
            'Store': int(store_id), 'Dept': int(dept_id), 'WMAE': np.nan, 'Status': 'Skipped (Too few train data)',
            'Train_Points': len(single_train_X), 'Val_Points': len(single_val_X)
        })
        gc.collect()
        continue
    if len(single_val_X) == 0:
        print(f"  Skipping (Store {int(store_id)}, Dept {int(dept_id)}): No validation data points.")
        overall_results_summary.append({
            'Store': int(store_id), 'Dept': int(dept_id), 'WMAE': np.nan, 'Status': 'Skipped (No val data)',
            'Train_Points': len(single_train_X), 'Val_Points': len(single_val_X)
        })
        gc.collect()
        continue

    try:
        # Set 'Date' as index for SARIMAX for the single series
        y_train_sarimax_single = single_train_y.set_axis(single_train_X['Date']).sort_index()
        y_val_sarimax_single = single_val_y.set_axis(single_val_X['Date']).sort_index()

        # Prepare weights for the single validation series, also indexed by Date
        single_val_weights = val_weights_raw.loc[val_idx_combo].set_axis(single_val_X['Date']).sort_index()

        # Prepare exogenous variables for the single series
        exog_train_single = single_train_X[final_exog_cols].set_index(single_train_X['Date']).sort_index()
        exog_val_single = single_val_X[final_exog_cols].set_index(single_val_X['Date']).sort_index()

        # Check for constant series (SARIMA often struggles with constant data)
        if y_train_sarimax_single.nunique() == 1:
            predicted_value = y_train_sarimax_single.iloc[0]
            print(f"  Training series is constant (Sales: {predicted_value:.2f}). Predicting constant value.")
            predictions_sarima_single = pd.Series(predicted_value, index=y_val_sarimax_single.index)

            # Store prediction with its original index for later concatenation
            predictions_for_overall_wmae = pd.Series(predictions_sarima_single.values, index=single_val_X.index, name='Weekly_Sales_Pred')
            all_individual_predictions.append(predictions_for_overall_wmae)

            wmae = weighted_mean_absolute_error(y_val_sarimax_single, predictions_sarima_single, single_val_weights)
            print(f"  WMAE: {wmae:.2f}")
            overall_results_summary.append({
                'Store': int(store_id), 'Dept': int(dept_id), 'WMAE': wmae, 'Status': 'Success (Constant Series Prediction)',
                'Train_Points': len(single_train_X), 'Val_Points': len(single_val_X)
            })
            gc.collect()
            continue

        # Fit SARIMAX model
        sarima_model = SARIMAX(
            y_train_sarimax_single,
            exog=exog_train_single,
            order=sarima_order,
            seasonal_order=sarima_seasonal_order,
            enforce_stationarity=False,
            enforce_invertibility=False
        )
        sarima_results = sarima_model.fit(disp=False, maxiter=500)

        # Store the fitted model
        fitted_models[(int(store_id), int(dept_id))] = sarima_results

        # Make predictions
        exog_val_aligned_single = exog_val_single.reindex(y_val_sarimax_single.index)

        if exog_val_aligned_single.empty:
            print(f"  Warning: exog_val_aligned_single is empty for (Store {int(store_id)}, Dept {int(dept_id)}). Cannot predict.")
            wmae = np.nan
            status = 'Failed: Empty exog_val for prediction'
        else:
            predictions_sarima_single = sarima_results.predict(
                start=y_val_sarimax_single.index[0],
                end=y_val_sarimax_single.index[-1],
                exog=exog_val_aligned_single
            )
            predictions_sarima_single[predictions_sarima_single < 0] = 0 # Ensure non-negative sales

            # Store prediction with its original index for later concatenation
            predictions_for_overall_wmae = pd.Series(predictions_sarima_single.values, index=single_val_X.index, name='Weekly_Sales_Pred')
            all_individual_predictions.append(predictions_for_overall_wmae)

            wmae = weighted_mean_absolute_error(y_val_sarimax_single, predictions_sarima_single, single_val_weights)
            status = 'Success'

        print(f"  WMAE: {wmae:.2f}")
        overall_results_summary.append({
            'Store': int(store_id), 'Dept': int(dept_id), 'WMAE': wmae, 'Status': status,
            'Train_Points': len(single_train_X), 'Val_Points': len(single_val_X)
        })

    except Exception as e:
        print(f"  Error fitting/predicting (Store {int(store_id)}, Dept {int(dept_id)}): {e}")
        overall_results_summary.append({
            'Store': int(store_id), 'Dept': int(dept_id), 'WMAE': np.nan, 'Status': f'Failed: {type(e).__name__}',
            'Train_Points': len(single_train_X), 'Val_Points': len(single_val_X)
        })
    finally:
        gc.collect()

print("\n--- All SARIMA Modeling Attempts Complete ---")

# --- Combine all predictions for overall WMAE ---
print("\n--- Combining all individual predictions for overall WMAE ---")

if all_individual_predictions:
    # Concatenate all predictions. Use pd.concat and then reindex to the original X_val_split index
    # to ensure all original validation points are covered, and missing ones are NaNs.
    combined_predictions = pd.concat(all_individual_predictions).sort_index()

    # Reindex y_val_split and val_weights_raw to ensure they align perfectly with the predictions
    # based on the original X_val_split index.
    y_true_overall = y_val_split.copy()
    y_pred_overall = combined_predictions.reindex(y_val_split.index) # Align predictions to true values' index
    weights_overall = val_weights_raw.copy()

    # Create a DataFrame to handle missing predictions gracefully for overall WMAE calculation
    overall_df = pd.DataFrame({
        'y_true': y_true_overall,
        'y_pred': y_pred_overall,
        'weights': weights_overall
    }).dropna(subset=['y_true', 'y_pred', 'weights']) # Only consider points where we have all three

    if not overall_df.empty and overall_df['weights'].sum() > 0:
        overall_wmae = (overall_df['weights'] * np.abs(overall_df['y_true'] - overall_df['y_pred'])).sum() / overall_df['weights'].sum()
        print(f"\n--- Overall Weighted Mean Absolute Error (WMAE) on Validation Set: {overall_wmae:.2f} ---")
    else:
        print("\n--- Cannot calculate overall WMAE: No valid predictions or weights available. ---")
else:
    print("\n--- No individual predictions were generated. Overall WMAE cannot be calculated. ---")


results_df = pd.DataFrame(overall_results_summary)
print("\n--- Summary of Individual Store-Dept Model Results ---")
print(results_df.head(15)) # Print first 15 results

successful_models_summary = results_df.dropna(subset=['WMAE'])
if not successful_models_summary.empty:
    print(f"\nTotal successful models fitted: {len(successful_models_summary)} (out of {len(unique_store_depts)})")
    print(f"Total failed/skipped models: {len(results_df) - len(successful_models_summary)}")
    print(f"Average WMAE for successfully fitted models (individual series): {successful_models_summary['WMAE'].mean():.2f}")
else:
    print("\nNo successful SARIMA models were fitted or predicted.")

print("\n--- Number of fitted models stored: ", len(fitted_models))
# Out:
# --- Applying Preprocessing Pipeline ---
# Preprocessing complete.
#
# --- Data Dimensions After Preprocessing ---
# X_train_processed shape: (397841, 42)
# X_val_processed shape: (23729, 42)
# Final exogenous columns used (25): ['Temperature', 'Fuel_Price', 'CPI', 'Unemployment', 'week_of_year', 'day_of_week', 'is_super_bowl', 'is_labor_day', 'is_thanksgiving', 'is_christmas', 'days_until_super_bowl', 'days_since_super_bowl', 'days_until_labor_day', 'days_since_labor_day', 'days_until_thanksgiving', 'days_since_thanksgiving', 'days_until_christmas', 'days_since_christmas', 'holiday_week_flag', 'black_friday_week', 'christmas_buildup', 'post_super_bowl', 'seasonal_sin', 'seasonal_cos', 'holiday_economic_index']
#
# --- Starting SARIMA Modeling for 3326 Store-Department Combinations ---
#
# --- Processing Store: 1, Department: 1 (1/3326) ---
#   WMAE: 6001.46
#
# --- Processing Store: 1, Department: 2 (2/3326) ---
#   WMAE: 1692.87
#
# --- Processing Store: 1, Department: 3 (3/3326) ---
#   WMAE: 9365.77
#
# --- Processing Store: 1, Department: 4 (4/3326) ---
#   WMAE: 1485.48
#
# --- Processing Store: 1, Department: 5 (5/3326) ---
#   WMAE: 4210.59
#
# --- Processing Store: 1, Department: 6 (6/3326) ---
#   WMAE: 1608.28
#
# --- Processing Store: 1, Department: 7 (7/3326) ---
#   WMAE: 9132.05
#
# --- Processing Store: 1, Department: 8 (8/3326) ---
#   WMAE: 2660.13
#
# --- Processing Store: 1, Department: 9 (9/3326) ---
#   WMAE: 1452.42
#
# --- Processing Store: 1, Department: 10 (10/3326) ---
#   WMAE: 2117.08
#
# --- Processing Store: 1, Department: 11 (11/3326) ---
#   WMAE: 5718.42
#
# --- Processing Store: 1, Department: 12 (12/3326) ---
#   WMAE: 920.60
#
# --- Processing Store: 1, Department: 13 (13/3326) ---
#   WMAE: 1585.10
#
# --- Processing Store: 1, Department: 14 (14/3326) ---
#   WMAE: 981.50
#
# --- Processing Store: 1, Department: 16 (15/3326) ---
#   WMAE: 11848.99
#
# --- Processing Store: 1, Department: 17 (16/3326) ---
#   WMAE: 1124.24
#
# --- Processing Store: 1, Department: 18 (17/3326) ---
#   Skipping (Store 1, Dept 18): Not enough training data points (105 < 131 required).
#
# --- Processing Store: 1, Department: 19 (18/3326) ---
#   WMAE: 365.76
#
# --- Processing Store: 1, Department: 20 (19/3326) ---
#   WMAE: 706.08
#
# --- Processing Store: 1, Department: 21 (20/3326) ---
#   WMAE: 202.80
#
# --- Processing Store: 1, Department: 22 (21/3326) ---
#   WMAE: 1560.49
#
# --- Processing Store: 1, Department: 23 (22/3326) ---
#   WMAE: 2096.96
#
# --- Processing Store: 1, Department: 24 (23/3326) ---
#   WMAE: 3200.75
#
# --- Processing Store: 1, Department: 25 (24/3326) ---
#   WMAE: 1822.43
#
# --- Processing Store: 1, Department: 26 (25/3326) ---
#   WMAE: 1061.64
#
# --- Processing Store: 1, Department: 27 (26/3326) ---
#   WMAE: 154.98
#
# --- Processing Store: 1, Department: 28 (27/3326) ---
#   WMAE: 95.67
#
# --- Processing Store: 1, Department: 29 (28/3326) ---
#   WMAE: 650.42
#
# --- Processing Store: 1, Department: 30 (29/3326) ---
#   WMAE: 178.21
#
# --- Processing Store: 1, Department: 31 (30/3326) ---
#   WMAE: 511.31
#
# --- Processing Store: 1, Department: 32 (31/3326) ---
#   WMAE: 1913.24
#
# --- Processing Store: 1, Department: 33 (32/3326) ---
#   WMAE: 2216.50
#
# --- Processing Store: 1, Department: 34 (33/3326) ---
#   WMAE: 636.90
#
# --- Processing Store: 1, Department: 35 (34/3326) ---
#   WMAE: 836.21
#
# --- Processing Store: 1, Department: 36 (35/3326) ---
#   WMAE: 863.10
#
# --- Processing Store: 1, Department: 37 (36/3326) ---
#   WMAE: 185.74
#
# --- Processing Store: 1, Department: 38 (37/3326) ---
#   WMAE: 11095.45
#
# --- Processing Store: 1, Department: 40 (38/3326) ---
#   WMAE: 1925.34
#
# --- Processing Store: 1, Department: 41 (39/3326) ---
#   WMAE: 504.79
#
# --- Processing Store: 1, Department: 42 (40/3326) ---
#   WMAE: 1555.14
#
# --- Processing Store: 1, Department: 44 (41/3326) ---
#   WMAE: 949.44
#
# --- Processing Store: 1, Department: 45 (42/3326) ---
#   Skipping (Store 1, Dept 45): Not enough training data points (66 < 131 required).
#
# --- Processing Store: 1, Department: 46 (43/3326) ---
#   WMAE: 1547.61
#
# --- Processing Store: 1, Department: 47 (44/3326) ---
#   Skipping (Store 1, Dept 47): Not enough training data points (21 < 131 required).
#
# --- Processing Store: 1, Department: 48 (45/3326) ---
#   Skipping (Store 1, Dept 48): Not enough training data points (117 < 131 required).
#
# --- Processing Store: 1, Department: 49 (46/3326) ---
#   WMAE: 852.13
#
# --- Processing Store: 1, Department: 51 (47/3326) ---
#   Skipping (Store 1, Dept 51): Not enough training data points (33 < 131 required).
#
# --- Processing Store: 1, Department: 52 (48/3326) ---
#   WMAE: 561.84
#
# --- Processing Store: 1, Department: 54 (49/3326) ---
#   Skipping (Store 1, Dept 54): Not enough training data points (126 < 131 required).
#
# --- Processing Store: 1, Department: 55 (50/3326) ---
#   WMAE: 2695.52
#
# --- Processing Store: 1, Department: 56 (51/3326) ---
#   WMAE: 4265.80
#
# --- Processing Store: 1, Department: 58 (52/3326) ---
#   WMAE: 4127.41
#
# --- Processing Store: 1, Department: 59 (53/3326) ---
#   WMAE: 352.01
#
# --- Processing Store: 1, Department: 60 (54/3326) ---
#   WMAE: 149.02
#
# --- Processing Store: 1, Department: 67 (55/3326) ---
#   WMAE: 1234.84
#
# --- Processing Store: 1, Department: 71 (56/3326) ---
#   WMAE: 1366.54
#
# --- Processing Store: 1, Department: 72 (57/3326) ---
#   WMAE: 12663.01
#
# --- Processing Store: 1, Department: 74 (58/3326) ---
#   WMAE: 881.78
#
# --- Processing Store: 1, Department: 77 (59/3326) ---
#   Skipping (Store 1, Dept 77): Not enough training data points (3 < 131 required).
#
# --- Processing Store: 1, Department: 78 (60/3326) ---
#   Skipping (Store 1, Dept 78): Not enough training data points (4 < 131 required).
#
# --- Processing Store: 1, Department: 79 (61/3326) ---
#   WMAE: 6072.31
#
# --- Processing Store: 1, Department: 80 (62/3326) ---
#   WMAE: 1922.02
#
# --- Processing Store: 1, Department: 81 (63/3326) ---
#   WMAE: 1090.76
#
# --- Processing Store: 1, Department: 82 (64/3326) ---
#   WMAE: 3490.87
#
# --- Processing Store: 1, Department: 83 (65/3326) ---
#   WMAE: 793.18
#
# --- Processing Store: 1, Department: 85 (66/3326) ---
#   WMAE: 586.16
#
# --- Processing Store: 1, Department: 87 (67/3326) ---
#   WMAE: 3327.37
#
# --- Processing Store: 1, Department: 90 (68/3326) ---
#   WMAE: 3144.28
#
# --- Processing Store: 1, Department: 91 (69/3326) ---
#   WMAE: 4394.93
#
# --- Processing Store: 1, Department: 92 (70/3326) ---
#   WMAE: 10199.62
#
# --- Processing Store: 1, Department: 93 (71/3326) ---
#   WMAE: 6781.74
#
# --- Processing Store: 1, Department: 94 (72/3326) ---
#   WMAE: 1525.76
#
# --- Processing Store: 1, Department: 95 (73/3326) ---
#   WMAE: 4025.13
#
# --- Processing Store: 1, Department: 96 (74/3326) ---
#   Skipping (Store 1, Dept 96): Not enough training data points (114 < 131 required).
#
# --- Processing Store: 1, Department: 97 (75/3326) ---
#   WMAE: 3026.85
#
# --- Processing Store: 1, Department: 98 (76/3326) ---
#   WMAE: 1862.50
#
# --- Processing Store: 1, Department: 99 (77/3326) ---
#   Skipping (Store 1, Dept 99): Not enough training data points (33 < 131 required).
#
# --- Processing Store: 2, Department: 1 (78/3326) ---
#   WMAE: 5170.74
#
# --- Processing Store: 2, Department: 2 (79/3326) ---
#   WMAE: 2288.68
#
# --- Processing Store: 2, Department: 3 (80/3326) ---
#   WMAE: 8214.81
#
# --- Processing Store: 2, Department: 4 (81/3326) ---
#   WMAE: 1162.40
#
# --- Processing Store: 2, Department: 5 (82/3326) ---
#   WMAE: 6205.27
#
# --- Processing Store: 2, Department: 6 (83/3326) ---
#   WMAE: 1136.37
#
# --- Processing Store: 2, Department: 7 (84/3326) ---
#   WMAE: 11235.13
#
# --- Processing Store: 2, Department: 8 (85/3326) ---
#   WMAE: 7558.64
#
# --- Processing Store: 2, Department: 9 (86/3326) ---
#   WMAE: 7703.34
#
# --- Processing Store: 2, Department: 10 (87/3326) ---
#   WMAE: 3256.25
#
# --- Processing Store: 2, Department: 11 (88/3326) ---
#   WMAE: 5835.32
#
# --- Processing Store: 2, Department: 12 (89/3326) ---
#   WMAE: 285.67
#
# --- Processing Store: 2, Department: 13 (90/3326) ---
#   WMAE: 1884.62
#
# --- Processing Store: 2, Department: 14 (91/3326) ---
#   WMAE: 3112.87
#
# --- Processing Store: 2, Department: 16 (92/3326) ---
#   WMAE: 5541.03
#
# --- Processing Store: 2, Department: 17 (93/3326) ---
#   WMAE: 965.07
#
# --- Processing Store: 2, Department: 18 (94/3326) ---
#   Skipping (Store 2, Dept 18): Not enough training data points (105 < 131 required).
#
# --- Processing Store: 2, Department: 19 (95/3326) ---
#   WMAE: 282.49
#
# --- Processing Store: 2, Department: 20 (96/3326) ---
#   WMAE: 747.95
#
# --- Processing Store: 2, Department: 21 (97/3326) ---
#   WMAE: 972.06
#
# --- Processing Store: 2, Department: 22 (98/3326) ---
#   WMAE: 1312.53
#
# --- Processing Store: 2, Department: 23 (99/3326) ---
#   WMAE: 3248.76
#
# --- Processing Store: 2, Department: 24 (100/3326) ---
#   WMAE: 817.00
#
# --- Processing Store: 2, Department: 25 (101/3326) ---
#   WMAE: 1589.22
#
# --- Processing Store: 2, Department: 26 (102/3326) ---
#   WMAE: 991.36
#
# --- Processing Store: 2, Department: 27 (103/3326) ---
#   WMAE: 382.95
#
# --- Processing Store: 2, Department: 28 (104/3326) ---
#   WMAE: 81.75
#
# --- Processing Store: 2, Department: 29 (105/3326) ---
#   WMAE: 796.68
#
# --- Processing Store: 2, Department: 30 (106/3326) ---
#   WMAE: 488.46
#
# --- Processing Store: 2, Department: 31 (107/3326) ---
#   WMAE: 778.40
#
# --- Processing Store: 2, Department: 32 (108/3326) ---
#   WMAE: 941.02
#
# --- Processing Store: 2, Department: 33 (109/3326) ---
#   WMAE: 727.32
#
# --- Processing Store: 2, Department: 34 (110/3326) ---
#   WMAE: 3897.67
#
# --- Processing Store: 2, Department: 35 (111/3326) ---
#   WMAE: 1021.34
#
# --- Processing Store: 2, Department: 36 (112/3326) ---
#   WMAE: 741.16
#
# --- Processing Store: 2, Department: 37 (113/3326) ---
#   WMAE: 582.08
#
# --- Processing Store: 2, Department: 38 (114/3326) ---
#   WMAE: 5550.46
#
# --- Processing Store: 2, Department: 39 (115/3326) ---
#   Skipping (Store 2, Dept 39): Not enough training data points (4 < 131 required).
#
# --- Processing Store: 2, Department: 40 (116/3326) ---
#   WMAE: 5777.83
#
# --- Processing Store: 2, Department: 41 (117/3326) ---
#   WMAE: 478.96
#
# --- Processing Store: 2, Department: 42 (118/3326) ---
#   WMAE: 1088.41
#
# --- Processing Store: 2, Department: 44 (119/3326) ---
#   WMAE: 1062.63
#
# --- Processing Store: 2, Department: 45 (120/3326) ---
#   Skipping (Store 2, Dept 45): Not enough training data points (64 < 131 required).
#
# --- Processing Store: 2, Department: 46 (121/3326) ---
#   WMAE: 2363.27
#
# --- Processing Store: 2, Department: 47 (122/3326) ---
#   Skipping (Store 2, Dept 47): Not enough training data points (22 < 131 required).
#
# --- Processing Store: 2, Department: 48 (123/3326) ---
#   Error fitting/predicting (Store 2, Dept 48): 'The `start` argument could not be matched to a location related to the index of the data.'
#
# --- Processing Store: 2, Department: 49 (124/3326) ---
#   WMAE: 2479.50
#
# --- Processing Store: 2, Department: 51 (125/3326) ---
#   Skipping (Store 2, Dept 51): Not enough training data points (12 < 131 required).
#
# --- Processing Store: 2, Department: 52 (126/3326) ---
#   WMAE: 869.26
#
# --- Processing Store: 2, Department: 54 (127/3326) ---
#   Skipping (Store 2, Dept 54): Not enough training data points (129 < 131 required).
#
# --- Processing Store: 2, Department: 55 (128/3326) ---
#   WMAE: 1590.26
#
# --- Processing Store: 2, Department: 56 (129/3326) ---
#   WMAE: 5309.89
#
# --- Processing Store: 2, Department: 58 (130/3326) ---
#   WMAE: 5703.46
#
# --- Processing Store: 2, Department: 59 (131/3326) ---
#   WMAE: 252.17
#
# --- Processing Store: 2, Department: 60 (132/3326) ---
#   Skipping (Store 2, Dept 60): Not enough training data points (103 < 131 required).
#
# --- Processing Store: 2, Department: 67 (133/3326) ---
#   WMAE: 2601.36
#
# --- Processing Store: 2, Department: 71 (134/3326) ---
#   WMAE: 1047.95
#
# --- Processing Store: 2, Department: 72 (135/3326) ---
#   WMAE: 14222.52
#
# --- Processing Store: 2, Department: 74 (136/3326) ---
#   WMAE: 1019.03
#
# --- Processing Store: 2, Department: 77 (137/3326) ---
#   Skipping (Store 2, Dept 77): Not enough training data points (2 < 131 required).
#
# --- Processing Store: 2, Department: 78 (138/3326) ---
#   Skipping (Store 2, Dept 78): Not enough training data points (10 < 131 required).
#
# --- Processing Store: 2, Department: 79 (139/3326) ---
#   WMAE: 5949.86
#
# --- Processing Store: 2, Department: 80 (140/3326) ---
#   WMAE: 652.75
#
# --- Processing Store: 2, Department: 81 (141/3326) ---
#   WMAE: 2301.80
#
# --- Processing Store: 2, Department: 82 (142/3326) ---
#   WMAE: 4875.08
#
# --- Processing Store: 2, Department: 83 (143/3326) ---
#   WMAE: 382.16
#
# --- Processing Store: 2, Department: 85 (144/3326) ---
#   WMAE: 894.55
#
# --- Processing Store: 2, Department: 87 (145/3326) ---
#   WMAE: 3000.41
#
# --- Processing Store: 2, Department: 90 (146/3326) ---
#   WMAE: 3338.29
#
# --- Processing Store: 2, Department: 91 (147/3326) ---
#   WMAE: 3011.43
#
# --- Processing Store: 2, Department: 92 (148/3326) ---
#   WMAE: 12337.81
#
# --- Processing Store: 2, Department: 93 (149/3326) ---
#   WMAE: 6696.56
#
# --- Processing Store: 2, Department: 94 (150/3326) ---
#   WMAE: 4864.50
#
# --- Processing Store: 2, Department: 95 (151/3326) ---
#   WMAE: 6764.91
#
# --- Processing Store: 2, Department: 96 (152/3326) ---
#   WMAE: 5706.95
#
# --- Processing Store: 2, Department: 97 (153/3326) ---
#   WMAE: 3092.51
#
# --- Processing Store: 2, Department: 98 (154/3326) ---
#   WMAE: 1106.30
#
# --- Processing Store: 2, Department: 99 (155/3326) ---
#   Skipping (Store 2, Dept 99): Not enough training data points (38 < 131 required).
#
# --- Processing Store: 3, Department: 1 (156/3326) ---
#   WMAE: 978.51
#
# --- Processing Store: 3, Department: 2 (157/3326) ---
#   WMAE: 668.00
#
# --- Processing Store: 3, Department: 3 (158/3326) ---
#   WMAE: 3201.87
#
# --- Processing Store: 3, Department: 4 (159/3326) ---
#   WMAE: 791.68
#
# --- Processing Store: 3, Department: 5 (160/3326) ---
#   WMAE: 1336.48
#
# --- Processing Store: 3, Department: 6 (161/3326) ---
#   WMAE: 713.25
#
# --- Processing Store: 3, Department: 7 (162/3326) ---
#   WMAE: 3227.97
#
# --- Processing Store: 3, Department: 8 (163/3326) ---
#   WMAE: 158.18
#
# --- Processing Store: 3, Department: 9 (164/3326) ---
#   WMAE: 2439.22
#
# --- Processing Store: 3, Department: 10 (165/3326) ---
#   WMAE: 938.29
#
# --- Processing Store: 3, Department: 11 (166/3326) ---
#   WMAE: 3442.51
#
# --- Processing Store: 3, Department: 12 (167/3326) ---
#   WMAE: 340.18
#
# --- Processing Store: 3, Department: 13 (168/3326) ---
#   WMAE: 1250.08
#
# --- Processing Store: 3, Department: 14 (169/3326) ---
#   WMAE: 584.05
#
# --- Processing Store: 3, Department: 16 (170/3326) ---
#   WMAE: 827.50
#
# --- Processing Store: 3, Department: 17 (171/3326) ---
#   WMAE: 230.32
#
# --- Processing Store: 3, Department: 18 (172/3326) ---
#   Skipping (Store 3, Dept 18): Not enough training data points (107 < 131 required).
#
# --- Processing Store: 3, Department: 19 (173/3326) ---
#   WMAE: 490.61
#
# --- Processing Store: 3, Department: 20 (174/3326) ---
#   WMAE: 165.65
#
# --- Processing Store: 3, Department: 21 (175/3326) ---
#   WMAE: 269.48
#
# --- Processing Store: 3, Department: 22 (176/3326) ---
#   WMAE: 354.45
#
# --- Processing Store: 3, Department: 23 (177/3326) ---
#   WMAE: 2300.79
#
# --- Processing Store: 3, Department: 24 (178/3326) ---
#   WMAE: 1272.50
#
# --- Processing Store: 3, Department: 25 (179/3326) ---
#   WMAE: 636.74
#
# --- Processing Store: 3, Department: 26 (180/3326) ---
#   WMAE: 331.06
#
# --- Processing Store: 3, Department: 27 (181/3326) ---
#   WMAE: 103.48
#
# --- Processing Store: 3, Department: 28 (182/3326) ---
#   WMAE: 42.72
#
# --- Processing Store: 3, Department: 29 (183/3326) ---
#   WMAE: 312.76
#
# --- Processing Store: 3, Department: 30 (184/3326) ---
#   WMAE: 463.54
#
# --- Processing Store: 3, Department: 31 (185/3326) ---
#   WMAE: 322.41
#
# --- Processing Store: 3, Department: 32 (186/3326) ---
#   WMAE: 2096.83
#
# --- Processing Store: 3, Department: 33 (187/3326) ---
#   WMAE: 577.23
#
# --- Processing Store: 3, Department: 34 (188/3326) ---
#   WMAE: 741.04
#
# --- Processing Store: 3, Department: 35 (189/3326) ---
#   WMAE: 462.71
#
# --- Processing Store: 3, Department: 36 (190/3326) ---
#   WMAE: 223.67
#
# --- Processing Store: 3, Department: 38 (191/3326) ---
#   WMAE: 3700.99
#
# --- Processing Store: 3, Department: 40 (192/3326) ---
#   WMAE: 611.79
#
# --- Processing Store: 3, Department: 41 (193/3326) ---
#   WMAE: 172.20
#
# --- Processing Store: 3, Department: 42 (194/3326) ---
#   WMAE: 1368.69
#
# --- Processing Store: 3, Department: 44 (195/3326) ---
#   WMAE: 355.89
#
# --- Processing Store: 3, Department: 45 (196/3326) ---
#   Skipping (Store 3, Dept 45): Not enough training data points (12 < 131 required).
#
# --- Processing Store: 3, Department: 46 (197/3326) ---
#   WMAE: 389.07
#
# --- Processing Store: 3, Department: 47 (198/3326) ---
#   Skipping (Store 3, Dept 47): Not enough training data points (8 < 131 required).
#
# --- Processing Store: 3, Department: 49 (199/3326) ---
#   Skipping (Store 3, Dept 49): Not enough training data points (46 < 131 required).
#
# --- Processing Store: 3, Department: 51 (200/3326) ---
#   Skipping (Store 3, Dept 51): Not enough training data points (61 < 131 required).
#
# --- Processing Store: 3, Department: 52 (201/3326) ---
#   WMAE: 139.95
#
# --- Processing Store: 3, Department: 54 (202/3326) ---
#   Skipping (Store 3, Dept 54): Not enough training data points (105 < 131 required).
#
# --- Processing Store: 3, Department: 55 (203/3326) ---
#   WMAE: 1151.85
#
# --- Processing Store: 3, Department: 56 (204/3326) ---
#   WMAE: 955.45
#
# --- Processing Store: 3, Department: 59 (205/3326) ---
#   Skipping (Store 3, Dept 59): Not enough training data points (117 < 131 required).
#
# --- Processing Store: 3, Department: 60 (206/3326) ---
#   WMAE: 19.38
#
# --- Processing Store: 3, Department: 67 (207/3326) ---
#   WMAE: 376.98
#
# --- Processing Store: 3, Department: 71 (208/3326) ---
#   WMAE: 226.13
#
# --- Processing Store: 3, Department: 72 (209/3326) ---
#   WMAE: 3082.68
#
# --- Processing Store: 3, Department: 74 (210/3326) ---
#   WMAE: 525.61
#
# --- Processing Store: 3, Department: 77 (211/3326) ---
#   Skipping (Store 3, Dept 77): Not enough training data points (3 < 131 required).
#
# --- Processing Store: 3, Department: 78 (212/3326) ---
#   Skipping (Store 3, Dept 78): Not enough training data points (1 < 131 required).
#
# --- Processing Store: 3, Department: 79 (213/3326) ---
#   WMAE: 501.58
#
# --- Processing Store: 3, Department: 80 (214/3326) ---
#   Skipping (Store 3, Dept 80): Not enough training data points (20 < 131 required).
#
# --- Processing Store: 3, Department: 81 (215/3326) ---
#   WMAE: 86.80
#
# --- Processing Store: 3, Department: 82 (216/3326) ---
#   WMAE: 725.87
#
# --- Processing Store: 3, Department: 83 (217/3326) ---
#   Skipping (Store 3, Dept 83): Not enough training data points (1 < 131 required).
#
# --- Processing Store: 3, Department: 85 (218/3326) ---
#   WMAE: 168.33
#
# --- Processing Store: 3, Department: 87 (219/3326) ---
#   WMAE: 383.34
#
# --- Processing Store: 3, Department: 90 (220/3326) ---
#   WMAE: 95.22
#
# --- Processing Store: 3, Department: 91 (221/3326) ---
#   WMAE: 72.48
#
# --- Processing Store: 3, Department: 92 (222/3326) ---
#   WMAE: 413.82
#
# --- Processing Store: 3, Department: 94 (223/3326) ---
#   Skipping (Store 3, Dept 94): Not enough training data points (47 < 131 required).
#
# --- Processing Store: 3, Department: 95 (224/3326) ---
#   WMAE: 1145.94
#
# --- Processing Store: 3, Department: 96 (225/3326) ---
#   WMAE: 952.57
#
# --- Processing Store: 3, Department: 97 (226/3326) ---
#   Error fitting/predicting (Store 3, Dept 97): 'The `start` argument could not be matched to a location related to the index of the data.'
#
# --- Processing Store: 3, Department: 98 (227/3326) ---
#   Skipping (Store 3, Dept 98): Not enough training data points (36 < 131 required).
#
# --- Processing Store: 4, Department: 1 (228/3326) ---
#   WMAE: 6193.77
#
# --- Processing Store: 4, Department: 2 (229/3326) ---
#   WMAE: 3768.26
#
# --- Processing Store: 4, Department: 3 (230/3326) ---
#   WMAE: 6216.61
#
# --- Processing Store: 4, Department: 4 (231/3326) ---
#   WMAE: 2423.00
#
# --- Processing Store: 4, Department: 5 (232/3326) ---
#   WMAE: 2386.73
#
# --- Processing Store: 4, Department: 6 (233/3326) ---
#   WMAE: 677.80
#
# --- Processing Store: 4, Department: 7 (234/3326) ---
#   WMAE: 11511.62
#
# --- Processing Store: 4, Department: 8 (235/3326) ---
#   WMAE: 929.47
#
# --- Processing Store: 4, Department: 9 (236/3326) ---
#   WMAE: 3428.39
#
# --- Processing Store: 4, Department: 10 (237/3326) ---
#   WMAE: 3067.68
#
# --- Processing Store: 4, Department: 11 (238/3326) ---
#   WMAE: 4945.92
#
# --- Processing Store: 4, Department: 12 (239/3326) ---
#   WMAE: 1083.14
#
# --- Processing Store: 4, Department: 13 (240/3326) ---
#   WMAE: 3050.85
#
# --- Processing Store: 4, Department: 14 (241/3326) ---
#   WMAE: 2388.54
#
# --- Processing Store: 4, Department: 16 (242/3326) ---
#   WMAE: 2450.87
#
# --- Processing Store: 4, Department: 17 (243/3326) ---
#   WMAE: 1879.55
#
# --- Processing Store: 4, Department: 18 (244/3326) ---
#   Skipping (Store 4, Dept 18): Not enough training data points (116 < 131 required).
#
# --- Processing Store: 4, Department: 19 (245/3326) ---
#   WMAE: 564.32
#
# --- Processing Store: 4, Department: 20 (246/3326) ---
#   WMAE: 865.13
#
# --- Processing Store: 4, Department: 21 (247/3326) ---
#   WMAE: 1054.59
#
# --- Processing Store: 4, Department: 22 (248/3326) ---
#   WMAE: 1869.94
#
# --- Processing Store: 4, Department: 23 (249/3326) ---
#   WMAE: 3584.69
#
# --- Processing Store: 4, Department: 24 (250/3326) ---
#   WMAE: 1665.05
#
# --- Processing Store: 4, Department: 25 (251/3326) ---
#   WMAE: 1503.96
#
# --- Processing Store: 4, Department: 26 (252/3326) ---
#   WMAE: 2727.96
#
# --- Processing Store: 4, Department: 27 (253/3326) ---
#   WMAE: 264.37
#
# --- Processing Store: 4, Department: 28 (254/3326) ---
#   WMAE: 150.59
#
# --- Processing Store: 4, Department: 29 (255/3326) ---
#   WMAE: 661.79
#
# --- Processing Store: 4, Department: 30 (256/3326) ---
#   WMAE: 1388.84
#
# --- Processing Store: 4, Department: 31 (257/3326) ---
#   WMAE: 661.77
#
# --- Processing Store: 4, Department: 32 (258/3326) ---
#   WMAE: 1287.41
#
# --- Processing Store: 4, Department: 33 (259/3326) ---
#   WMAE: 1521.17
#
# --- Processing Store: 4, Department: 34 (260/3326) ---
#   WMAE: 2307.58
#
# --- Processing Store: 4, Department: 35 (261/3326) ---
#   WMAE: 364.07
#
# --- Processing Store: 4, Department: 36 (262/3326) ---
#   WMAE: 1568.03
#
# --- Processing Store: 4, Department: 37 (263/3326) ---
#   WMAE: 1314.63
#
# --- Processing Store: 4, Department: 38 (264/3326) ---
#   WMAE: 11693.56
#
# --- Processing Store: 4, Department: 39 (265/3326) ---
#   Skipping (Store 4, Dept 39): Not enough training data points (1 < 131 required).
#
# --- Processing Store: 4, Department: 40 (266/3326) ---
#   WMAE: 3774.32
#
# --- Processing Store: 4, Department: 41 (267/3326) ---
#   WMAE: 495.88
#
# --- Processing Store: 4, Department: 42 (268/3326) ---
#   WMAE: 2264.49
#
# --- Processing Store: 4, Department: 44 (269/3326) ---
#   WMAE: 649.56
#
# --- Processing Store: 4, Department: 45 (270/3326) ---
#   Skipping (Store 4, Dept 45): Not enough training data points (46 < 131 required).
#
# --- Processing Store: 4, Department: 46 (271/3326) ---
#   WMAE: 1374.75
#
# --- Processing Store: 4, Department: 47 (272/3326) ---
#   Skipping (Store 4, Dept 47): Not enough training data points (13 < 131 required).
#
# --- Processing Store: 4, Department: 48 (273/3326) ---
#   Error fitting/predicting (Store 4, Dept 48): 'The `start` argument could not be matched to a location related to the index of the data.'
#
# --- Processing Store: 4, Department: 49 (274/3326) ---
#   WMAE: 799.57
#
# --- Processing Store: 4, Department: 51 (275/3326) ---
#   Skipping (Store 4, Dept 51): Not enough training data points (23 < 131 required).
#
# --- Processing Store: 4, Department: 52 (276/3326) ---
#   WMAE: 1011.45
#
# --- Processing Store: 4, Department: 54 (277/3326) ---
#   Error fitting/predicting (Store 4, Dept 54): 'The `start` argument could not be matched to a location related to the index of the data.'
#
# --- Processing Store: 4, Department: 55 (278/3326) ---
#   WMAE: 1510.76
#
# --- Processing Store: 4, Department: 56 (279/3326) ---
#   WMAE: 2402.05
#
# --- Processing Store: 4, Department: 58 (280/3326) ---
#   WMAE: 1599.04
#
# --- Processing Store: 4, Department: 59 (281/3326) ---
#   WMAE: 400.70
#
# --- Processing Store: 4, Department: 60 (282/3326) ---
#   WMAE: 66.19
#
# --- Processing Store: 4, Department: 67 (283/3326) ---
#   WMAE: 1531.75
#
# --- Processing Store: 4, Department: 71 (284/3326) ---
#   WMAE: 1466.70
#
# --- Processing Store: 4, Department: 72 (285/3326) ---
#   WMAE: 22706.86
#
# --- Processing Store: 4, Department: 74 (286/3326) ---
#   WMAE: 2507.82
#
# --- Processing Store: 4, Department: 77 (287/3326) ---
#   Skipping (Store 4, Dept 77): Not enough training data points (7 < 131 required).
#
# --- Processing Store: 4, Department: 78 (288/3326) ---
#   Skipping (Store 4, Dept 78): Not enough training data points (8 < 131 required).
#
# --- Processing Store: 4, Department: 79 (289/3326) ---
#   WMAE: 2092.32
#
# --- Processing Store: 4, Department: 80 (290/3326) ---
#   WMAE: 4301.74
#
# --- Processing Store: 4, Department: 81 (291/3326) ---
#   WMAE: 809.47
#
# --- Processing Store: 4, Department: 82 (292/3326) ---
#   WMAE: 1806.22
#
# --- Processing Store: 4, Department: 83 (293/3326) ---
#   WMAE: 1654.73
#
# --- Processing Store: 4, Department: 85 (294/3326) ---
#   WMAE: 491.63
#
# --- Processing Store: 4, Department: 87 (295/3326) ---
#   WMAE: 2283.90
#
# --- Processing Store: 4, Department: 90 (296/3326) ---
#   WMAE: 7084.58
#
# --- Processing Store: 4, Department: 91 (297/3326) ---
#   WMAE: 2228.49
#
# --- Processing Store: 4, Department: 92 (298/3326) ---
#   WMAE: 6979.88
#
# --- Processing Store: 4, Department: 93 (299/3326) ---
#   WMAE: 3173.52
#
# --- Processing Store: 4, Department: 94 (300/3326) ---
#   WMAE: 3780.68
#
# --- Processing Store: 4, Department: 95 (301/3326) ---
#   WMAE: 4198.05
#
# --- Processing Store: 4, Department: 96 (302/3326) ---
#   WMAE: 1652.53
#
# --- Processing Store: 4, Department: 97 (303/3326) ---
#   WMAE: 1122.63
#
# --- Processing Store: 4, Department: 98 (304/3326) ---
#   WMAE: 1129.41
#
# --- Processing Store: 4, Department: 99 (305/3326) ---
#   Skipping (Store 4, Dept 99): Not enough training data points (38 < 131 required).
#
# --- Processing Store: 5, Department: 1 (306/3326) ---
#   WMAE: 687.93
#
# --- Processing Store: 5, Department: 2 (307/3326) ---
#   WMAE: 1106.57
#
# --- Processing Store: 5, Department: 3 (308/3326) ---
#   WMAE: 953.99
#
# --- Processing Store: 5, Department: 4 (309/3326) ---
#   WMAE: 400.76
#
# --- Processing Store: 5, Department: 5 (310/3326) ---
#   WMAE: 524.38
#
# --- Processing Store: 5, Department: 6 (311/3326) ---
#   WMAE: 284.58
#
# --- Processing Store: 5, Department: 7 (312/3326) ---
#   WMAE: 2235.89
#
# --- Processing Store: 5, Department: 8 (313/3326) ---
#   WMAE: 845.89
#
# --- Processing Store: 5, Department: 9 (314/3326) ---
#   WMAE: 1417.52
#
# --- Processing Store: 5, Department: 10 (315/3326) ---
#   WMAE: 1129.99
#
# --- Processing Store: 5, Department: 11 (316/3326) ---
#   WMAE: 1916.39
#
# --- Processing Store: 5, Department: 12 (317/3326) ---
#   WMAE: 219.05
#
# --- Processing Store: 5, Department: 13 (318/3326) ---
#   WMAE: 440.54
#
# --- Processing Store: 5, Department: 14 (319/3326) ---
#   WMAE: 935.06
#
# --- Processing Store: 5, Department: 16 (320/3326) ---
#   WMAE: 1185.70
#
# --- Processing Store: 5, Department: 17 (321/3326) ---
#   WMAE: 442.47
#
# --- Processing Store: 5, Department: 18 (322/3326) ---
#   Skipping (Store 5, Dept 18): Not enough training data points (92 < 131 required).
#
# --- Processing Store: 5, Department: 19 (323/3326) ---
#   Skipping (Store 5, Dept 19): Not enough training data points (54 < 131 required).
#
# --- Processing Store: 5, Department: 20 (324/3326) ---
#   WMAE: 367.42
#
# --- Processing Store: 5, Department: 21 (325/3326) ---
#   WMAE: 170.82
#
# --- Processing Store: 5, Department: 22 (326/3326) ---
#   WMAE: 346.13
#
# --- Processing Store: 5, Department: 23 (327/3326) ---
#   WMAE: 1294.92
#
# --- Processing Store: 5, Department: 24 (328/3326) ---
#   WMAE: 249.17
#
# --- Processing Store: 5, Department: 25 (329/3326) ---
#   WMAE: 535.55
#
# --- Processing Store: 5, Department: 26 (330/3326) ---
#   WMAE: 334.67
#
# --- Processing Store: 5, Department: 27 (331/3326) ---
#   WMAE: 89.69
#
# --- Processing Store: 5, Department: 28 (332/3326) ---
#   WMAE: 27.34
#
# --- Processing Store: 5, Department: 29 (333/3326) ---
#   WMAE: 104.13
#
# --- Processing Store: 5, Department: 30 (334/3326) ---
#   WMAE: 348.41
#
# --- Processing Store: 5, Department: 31 (335/3326) ---
#   WMAE: 207.60
#
# --- Processing Store: 5, Department: 32 (336/3326) ---
#   WMAE: 984.36
#
# --- Processing Store: 5, Department: 33 (337/3326) ---
#   WMAE: 173.88
#
# --- Processing Store: 5, Department: 34 (338/3326) ---
#   WMAE: 467.11
#
# --- Processing Store: 5, Department: 35 (339/3326) ---
#   WMAE: 161.09
#
# --- Processing Store: 5, Department: 36 (340/3326) ---
#   WMAE: 157.40
#
# --- Processing Store: 5, Department: 38 (341/3326) ---
#   WMAE: 3055.60
#
# --- Processing Store: 5, Department: 40 (342/3326) ---
#   WMAE: 1049.23
#
# --- Processing Store: 5, Department: 41 (343/3326) ---
#   WMAE: 198.97
#
# --- Processing Store: 5, Department: 42 (344/3326) ---
#   WMAE: 613.70
#
# --- Processing Store: 5, Department: 44 (345/3326) ---
#   WMAE: 255.39
#
# --- Processing Store: 5, Department: 45 (346/3326) ---
#   Skipping (Store 5, Dept 45): Not enough training data points (69 < 131 required).
#
# --- Processing Store: 5, Department: 46 (347/3326) ---
#   WMAE: 591.20
#
# --- Processing Store: 5, Department: 47 (348/3326) ---
#   Skipping (Store 5, Dept 47): Not enough training data points (11 < 131 required).
#
# --- Processing Store: 5, Department: 49 (349/3326) ---
#   Skipping (Store 5, Dept 49): Not enough training data points (49 < 131 required).
#
# --- Processing Store: 5, Department: 51 (350/3326) ---
#   Skipping (Store 5, Dept 51): Not enough training data points (5 < 131 required).
#
# --- Processing Store: 5, Department: 52 (351/3326) ---
#   WMAE: 103.99
#
# --- Processing Store: 5, Department: 54 (352/3326) ---
#   Skipping (Store 5, Dept 54): Not enough training data points (94 < 131 required).
#
# --- Processing Store: 5, Department: 55 (353/3326) ---
#   WMAE: 376.10
#
# --- Processing Store: 5, Department: 56 (354/3326) ---
#   WMAE: 370.98
#
# --- Processing Store: 5, Department: 58 (355/3326) ---
#   Skipping (Store 5, Dept 58): Not enough training data points (114 < 131 required).
#
# --- Processing Store: 5, Department: 59 (356/3326) ---
#   Skipping (Store 5, Dept 59): Not enough training data points (102 < 131 required).
#
# --- Processing Store: 5, Department: 60 (357/3326) ---
#   WMAE: 68.34
#
# --- Processing Store: 5, Department: 67 (358/3326) ---
#   WMAE: 451.54
#
# --- Processing Store: 5, Department: 71 (359/3326) ---
#   WMAE: 91.48
#
# --- Processing Store: 5, Department: 72 (360/3326) ---
#   WMAE: 4234.65
#
# --- Processing Store: 5, Department: 74 (361/3326) ---
#   WMAE: 232.05
#
# --- Processing Store: 5, Department: 77 (362/3326) ---
#   Skipping (Store 5, Dept 77): Not enough training data points (2 < 131 required).
#
# --- Processing Store: 5, Department: 78 (363/3326) ---
#   Skipping (Store 5, Dept 78): Not enough training data points (1 < 131 required).
#
# --- Processing Store: 5, Department: 79 (364/3326) ---
#   WMAE: 272.87
#
# --- Processing Store: 5, Department: 80 (365/3326) ---
#   Skipping (Store 5, Dept 80): Not enough training data points (3 < 131 required).
#
# --- Processing Store: 5, Department: 81 (366/3326) ---
#   WMAE: 125.07
#
# --- Processing Store: 5, Department: 82 (367/3326) ---
#   WMAE: 690.69
#
# --- Processing Store: 5, Department: 85 (368/3326) ---
#   WMAE: 370.70
#
# --- Processing Store: 5, Department: 87 (369/3326) ---
#   WMAE: 2739.91
#
# --- Processing Store: 5, Department: 90 (370/3326) ---
#   WMAE: 284.13
#
# --- Processing Store: 5, Department: 91 (371/3326) ---
#   WMAE: 238.02
#
# --- Processing Store: 5, Department: 92 (372/3326) ---
#   WMAE: 538.32
#
# --- Processing Store: 5, Department: 94 (373/3326) ---
#   Skipping (Store 5, Dept 94): Not enough training data points (67 < 131 required).
#
# --- Processing Store: 5, Department: 95 (374/3326) ---
#   WMAE: 1581.26
#
# --- Processing Store: 5, Department: 96 (375/3326) ---
#   WMAE: 676.18
#
# --- Processing Store: 5, Department: 97 (376/3326) ---
#   Skipping (Store 5, Dept 97): Not enough training data points (119 < 131 required).
#
# --- Processing Store: 5, Department: 98 (377/3326) ---
#   Skipping (Store 5, Dept 98): Not enough training data points (23 < 131 required).
#
# --- Processing Store: 6, Department: 1 (378/3326) ---
#   WMAE: 4653.50
#
# --- Processing Store: 6, Department: 2 (379/3326) ---
#   WMAE: 1825.36
#
# --- Processing Store: 6, Department: 3 (380/3326) ---
#   WMAE: 7646.22
#
# --- Processing Store: 6, Department: 4 (381/3326) ---
#   WMAE: 1003.41
#
# --- Processing Store: 6, Department: 5 (382/3326) ---
#   WMAE: 4192.74
#
# --- Processing Store: 6, Department: 6 (383/3326) ---
#   WMAE: 1111.76
#
# --- Processing Store: 6, Department: 7 (384/3326) ---
#   WMAE: 7053.63
#
# --- Processing Store: 6, Department: 8 (385/3326) ---
#   WMAE: 3420.55
#
# --- Processing Store: 6, Department: 9 (386/3326) ---
#   WMAE: 10389.38
#
# --- Processing Store: 6, Department: 10 (387/3326) ---
#   WMAE: 6263.11
#
# --- Processing Store: 6, Department: 11 (388/3326) ---
#   WMAE: 6279.02
#
# --- Processing Store: 6, Department: 12 (389/3326) ---
#   WMAE: 187.09
#
# --- Processing Store: 6, Department: 13 (390/3326) ---
#   WMAE: 1630.99
#
# --- Processing Store: 6, Department: 14 (391/3326) ---
#   WMAE: 1508.88
#
# --- Processing Store: 6, Department: 16 (392/3326) ---
#   WMAE: 7187.41
#
# --- Processing Store: 6, Department: 17 (393/3326) ---
#   WMAE: 2381.39
#
# --- Processing Store: 6, Department: 18 (394/3326) ---
#   Skipping (Store 6, Dept 18): Not enough training data points (105 < 131 required).
#
# --- Processing Store: 6, Department: 19 (395/3326) ---
#   WMAE: 253.05
#
# --- Processing Store: 6, Department: 20 (396/3326) ---
#   WMAE: 606.37
#
# --- Processing Store: 6, Department: 21 (397/3326) ---
#   WMAE: 1003.96
#
# --- Processing Store: 6, Department: 22 (398/3326) ---
#   WMAE: 1227.58
#
# --- Processing Store: 6, Department: 23 (399/3326) ---
#   WMAE: 6130.08
#
# --- Processing Store: 6, Department: 24 (400/3326) ---
#   WMAE: 1029.82
#
# --- Processing Store: 6, Department: 25 (401/3326) ---
#   WMAE: 2247.18
#
# --- Processing Store: 6, Department: 26 (402/3326) ---
#   WMAE: 1287.59
#
# --- Processing Store: 6, Department: 27 (403/3326) ---
#   WMAE: 305.45
#
# --- Processing Store: 6, Department: 28 (404/3326) ---
#   WMAE: 107.34
#
# --- Processing Store: 6, Department: 29 (405/3326) ---
#   WMAE: 1205.59
#
# --- Processing Store: 6, Department: 30 (406/3326) ---
#   WMAE: 658.08
#
# --- Processing Store: 6, Department: 31 (407/3326) ---
#   WMAE: 387.14
#
# --- Processing Store: 6, Department: 32 (408/3326) ---
#   WMAE: 2230.19
#
# --- Processing Store: 6, Department: 33 (409/3326) ---
#   WMAE: 621.98
#
# --- Processing Store: 6, Department: 34 (410/3326) ---
#   WMAE: 1402.06
#
# --- Processing Store: 6, Department: 35 (411/3326) ---
#   WMAE: 374.98
#
# --- Processing Store: 6, Department: 36 (412/3326) ---
#   WMAE: 971.51
#
# --- Processing Store: 6, Department: 37 (413/3326) ---
#   WMAE: 486.84
#
# --- Processing Store: 6, Department: 38 (414/3326) ---
#   WMAE: 9928.71
#
# --- Processing Store: 6, Department: 40 (415/3326) ---
#   WMAE: 3194.80
#
# --- Processing Store: 6, Department: 41 (416/3326) ---
#   WMAE: 738.59
#
# --- Processing Store: 6, Department: 42 (417/3326) ---
#   WMAE: 510.03
#
# --- Processing Store: 6, Department: 44 (418/3326) ---
#   WMAE: 231.03
#
# --- Processing Store: 6, Department: 45 (419/3326) ---
#   Skipping (Store 6, Dept 45): Not enough training data points (67 < 131 required).
#
# --- Processing Store: 6, Department: 46 (420/3326) ---
#   WMAE: 2377.78
#
# --- Processing Store: 6, Department: 47 (421/3326) ---
#   Skipping (Store 6, Dept 47): Not enough training data points (16 < 131 required).
#
# --- Processing Store: 6, Department: 48 (422/3326) ---
#   Error fitting/predicting (Store 6, Dept 48): 'The `start` argument could not be matched to a location related to the index of the data.'
#
# --- Processing Store: 6, Department: 49 (423/3326) ---
#   WMAE: 1671.62
#
# --- Processing Store: 6, Department: 51 (424/3326) ---
#   Skipping (Store 6, Dept 51): Not enough training data points (8 < 131 required).
#
# --- Processing Store: 6, Department: 52 (425/3326) ---
#   WMAE: 652.97
#
# --- Processing Store: 6, Department: 54 (426/3326) ---
#   Error fitting/predicting (Store 6, Dept 54): 'The `start` argument could not be matched to a location related to the index of the data.'
#
# --- Processing Store: 6, Department: 55 (427/3326) ---
#   WMAE: 3390.98
#
# --- Processing Store: 6, Department: 56 (428/3326) ---
#   WMAE: 3790.90
#
# --- Processing Store: 6, Department: 58 (429/3326) ---
#   WMAE: 2384.04
#
# --- Processing Store: 6, Department: 59 (430/3326) ---
#   WMAE: 229.56
#
# --- Processing Store: 6, Department: 60 (431/3326) ---
#   Skipping (Store 6, Dept 60): Not enough training data points (83 < 131 required).
#
# --- Processing Store: 6, Department: 67 (432/3326) ---
#   WMAE: 1199.83
#
# --- Processing Store: 6, Department: 71 (433/3326) ---
#   WMAE: 636.29
#
# --- Processing Store: 6, Department: 72 (434/3326) ---
#   WMAE: 9879.45
#
# --- Processing Store: 6, Department: 74 (435/3326) ---
#   WMAE: 1875.75
#
# --- Processing Store: 6, Department: 77 (436/3326) ---
#   Skipping (Store 6, Dept 77): Not enough training data points (1 < 131 required).
#
# --- Processing Store: 6, Department: 78 (437/3326) ---
#   Skipping (Store 6, Dept 78): Not enough training data points (9 < 131 required).
#
# --- Processing Store: 6, Department: 79 (438/3326) ---
#   WMAE: 2025.82
#
# --- Processing Store: 6, Department: 80 (439/3326) ---
#   WMAE: 196.46
#
# --- Processing Store: 6, Department: 81 (440/3326) ---
#   WMAE: 867.93
#
# --- Processing Store: 6, Department: 82 (441/3326) ---
#   WMAE: 3606.97
#
# --- Processing Store: 6, Department: 83 (442/3326) ---
#   WMAE: 573.33
#
# --- Processing Store: 6, Department: 85 (443/3326) ---
#   WMAE: 323.29
#
# --- Processing Store: 6, Department: 87 (444/3326) ---
#   WMAE: 3228.08
#
# --- Processing Store: 6, Department: 90 (445/3326) ---
#   WMAE: 2212.01
#
# --- Processing Store: 6, Department: 91 (446/3326) ---
#   WMAE: 3021.94
#
# --- Processing Store: 6, Department: 92 (447/3326) ---
#   WMAE: 7610.82
#
# --- Processing Store: 6, Department: 93 (448/3326) ---
#   WMAE: 5451.59
#
# --- Processing Store: 6, Department: 94 (449/3326) ---
#   WMAE: 1702.56
#
# --- Processing Store: 6, Department: 95 (450/3326) ---
#   WMAE: 11170.82
#
# --- Processing Store: 6, Department: 96 (451/3326) ---
#   WMAE: 4557.39
#
# --- Processing Store: 6, Department: 97 (452/3326) ---
#   WMAE: 2120.22
#
# --- Processing Store: 6, Department: 98 (453/3326) ---
#   WMAE: 307.30
#
# --- Processing Store: 6, Department: 99 (454/3326) ---
#   Skipping (Store 6, Dept 99): Not enough training data points (36 < 131 required).
#
# --- Processing Store: 7, Department: 1 (455/3326) ---
#   WMAE: 1733.18
#
# --- Processing Store: 7, Department: 2 (456/3326) ---
#   WMAE: 1473.81
#
# --- Processing Store: 7, Department: 3 (457/3326) ---
#   WMAE: 2180.26
#
# --- Processing Store: 7, Department: 4 (458/3326) ---
#   WMAE: 1650.75
#
# --- Processing Store: 7, Department: 5 (459/3326) ---
#   WMAE: 2576.62
#
# --- Processing Store: 7, Department: 6 (460/3326) ---
#   WMAE: 1058.74
#
# --- Processing Store: 7, Department: 7 (461/3326) ---
#   WMAE: 2591.07
#
# --- Processing Store: 7, Department: 8 (462/3326) ---
#   WMAE: 819.82
#
# --- Processing Store: 7, Department: 9 (463/3326) ---
#   WMAE: 7808.95
#
# --- Processing Store: 7, Department: 10 (464/3326) ---
#   WMAE: 1191.90
#
# --- Processing Store: 7, Department: 11 (465/3326) ---
#   WMAE: 1302.81
#
# --- Processing Store: 7, Department: 12 (466/3326) ---
#   WMAE: 1798.13
#
# --- Processing Store: 7, Department: 13 (467/3326) ---
#   WMAE: 1119.21
#
# --- Processing Store: 7, Department: 14 (468/3326) ---
#   WMAE: 1652.80
#
# --- Processing Store: 7, Department: 16 (469/3326) ---
#   WMAE: 3775.81
#
# --- Processing Store: 7, Department: 17 (470/3326) ---
#   WMAE: 2068.06
#
# --- Processing Store: 7, Department: 18 (471/3326) ---
#   Skipping (Store 7, Dept 18): Not enough training data points (87 < 131 required).
#
# --- Processing Store: 7, Department: 19 (472/3326) ---
#   Skipping (Store 7, Dept 19): Not enough training data points (52 < 131 required).
#
# --- Processing Store: 7, Department: 20 (473/3326) ---
#   WMAE: 302.96
#
# --- Processing Store: 7, Department: 21 (474/3326) ---
#   WMAE: 504.99
#
# --- Processing Store: 7, Department: 22 (475/3326) ---
#   WMAE: 649.92
#
# --- Processing Store: 7, Department: 23 (476/3326) ---
#   WMAE: 1911.58
#
# --- Processing Store: 7, Department: 24 (477/3326) ---
#   WMAE: 522.18
#
# --- Processing Store: 7, Department: 25 (478/3326) ---
#   WMAE: 675.21
#
# --- Processing Store: 7, Department: 26 (479/3326) ---
#   WMAE: 294.14
#
# --- Processing Store: 7, Department: 27 (480/3326) ---
#   WMAE: 103.77
#
# --- Processing Store: 7, Department: 28 (481/3326) ---
#   WMAE: 190.46
#
# --- Processing Store: 7, Department: 29 (482/3326) ---
#   WMAE: 236.73
#
# --- Processing Store: 7, Department: 30 (483/3326) ---
#   WMAE: 117.92
#
# --- Processing Store: 7, Department: 31 (484/3326) ---
#   WMAE: 511.90
#
# --- Processing Store: 7, Department: 32 (485/3326) ---
#   WMAE: 924.22
#
# --- Processing Store: 7, Department: 33 (486/3326) ---
#   WMAE: 391.97
#
# --- Processing Store: 7, Department: 34 (487/3326) ---
#   WMAE: 754.75
#
# --- Processing Store: 7, Department: 35 (488/3326) ---
#   WMAE: 49.53
#
# --- Processing Store: 7, Department: 36 (489/3326) ---
#   WMAE: 581.82
#
# --- Processing Store: 7, Department: 38 (490/3326) ---
#   WMAE: 4048.28
#
# --- Processing Store: 7, Department: 40 (491/3326) ---
#   WMAE: 4288.28
#
# --- Processing Store: 7, Department: 41 (492/3326) ---
#   WMAE: 277.41
#
# --- Processing Store: 7, Department: 42 (493/3326) ---
#   WMAE: 955.23
#
# --- Processing Store: 7, Department: 44 (494/3326) ---
#   WMAE: 757.87
#
# --- Processing Store: 7, Department: 45 (495/3326) ---
#   Skipping (Store 7, Dept 45): Not enough training data points (81 < 131 required).
#
# --- Processing Store: 7, Department: 46 (496/3326) ---
#   WMAE: 649.38
#
# --- Processing Store: 7, Department: 47 (497/3326) ---
#   Skipping (Store 7, Dept 47): Not enough training data points (15 < 131 required).
#
# --- Processing Store: 7, Department: 48 (498/3326) ---
#   Skipping (Store 7, Dept 48): Not enough training data points (75 < 131 required).
#
# --- Processing Store: 7, Department: 49 (499/3326) ---
#   Skipping (Store 7, Dept 49): Not enough training data points (68 < 131 required).
#
# --- Processing Store: 7, Department: 51 (500/3326) ---
#   Skipping (Store 7, Dept 51): Not enough training data points (39 < 131 required).
#
# --- Processing Store: 7, Department: 52 (501/3326) ---
#   WMAE: 691.13
#
# --- Processing Store: 7, Department: 54 (502/3326) ---
#   Skipping (Store 7, Dept 54): Not enough training data points (119 < 131 required).
#
# --- Processing Store: 7, Department: 55 (503/3326) ---
#   WMAE: 1597.15
#
# --- Processing Store: 7, Department: 56 (504/3326) ---
#   WMAE: 1427.71
#
# --- Processing Store: 7, Department: 58 (505/3326) ---
#   Skipping (Store 7, Dept 58): Not enough training data points (93 < 131 required).
#
# --- Processing Store: 7, Department: 59 (506/3326) ---
#   Skipping (Store 7, Dept 59): Not enough training data points (111 < 131 required).
#
# --- Processing Store: 7, Department: 60 (507/3326) ---
#   WMAE: 24.25
#
# --- Processing Store: 7, Department: 67 (508/3326) ---
#   WMAE: 878.18
#
# --- Processing Store: 7, Department: 71 (509/3326) ---
#   WMAE: 343.07
#
# --- Processing Store: 7, Department: 72 (510/3326) ---
#   WMAE: 6021.72
#
# --- Processing Store: 7, Department: 74 (511/3326) ---
#   WMAE: 1139.61
#
# --- Processing Store: 7, Department: 77 (512/3326) ---
#   Skipping (Store 7, Dept 77): Not enough training data points (4 < 131 required).
#
# --- Processing Store: 7, Department: 78 (513/3326) ---
#   Skipping (Store 7, Dept 78): Not enough training data points (1 < 131 required).
#
# --- Processing Store: 7, Department: 79 (514/3326) ---
#   WMAE: 263.04
#
# --- Processing Store: 7, Department: 80 (515/3326) ---
#   Skipping (Store 7, Dept 80): Not enough training data points (127 < 131 required).
#
# --- Processing Store: 7, Department: 81 (516/3326) ---
#   WMAE: 182.70
#
# --- Processing Store: 7, Department: 82 (517/3326) ---
#   WMAE: 351.54
#
# --- Processing Store: 7, Department: 83 (518/3326) ---
#   Error fitting/predicting (Store 7, Dept 83): 'The `start` argument could not be matched to a location related to the index of the data.'
#
# --- Processing Store: 7, Department: 85 (519/3326) ---
#   WMAE: 108.07
#
# --- Processing Store: 7, Department: 87 (520/3326) ---
#   WMAE: 643.20
#
# --- Processing Store: 7, Department: 90 (521/3326) ---
#   WMAE: 507.15
#
# --- Processing Store: 7, Department: 91 (522/3326) ---
#   WMAE: 1066.51
#
# --- Processing Store: 7, Department: 92 (523/3326) ---
#   WMAE: 822.47
#
# --- Processing Store: 7, Department: 93 (524/3326) ---
#   WMAE: 337.78
#
# --- Processing Store: 7, Department: 94 (525/3326) ---
#   Skipping (Store 7, Dept 94): Not enough training data points (107 < 131 required).
#
# --- Processing Store: 7, Department: 95 (526/3326) ---
#   WMAE: 1158.78
#
# --- Processing Store: 7, Department: 96 (527/3326) ---
#   WMAE: 145.41
#
# --- Processing Store: 7, Department: 97 (528/3326) ---
#   WMAE: 296.86
#
# --- Processing Store: 7, Department: 98 (529/3326) ---
#   Error fitting/predicting (Store 7, Dept 98): 'The `start` argument could not be matched to a location related to the index of the data.'
#
# --- Processing Store: 7, Department: 99 (530/3326) ---
#   Skipping (Store 7, Dept 99): Not enough training data points (1 < 131 required).
#
# --- Processing Store: 8, Department: 1 (531/3326) ---
#   WMAE: 3041.81
#
# --- Processing Store: 8, Department: 2 (532/3326) ---
#   WMAE: 2278.25
#
# --- Processing Store: 8, Department: 3 (533/3326) ---
#   WMAE: 8761.88
#
# --- Processing Store: 8, Department: 4 (534/3326) ---
#   WMAE: 1322.92
#
# --- Processing Store: 8, Department: 5 (535/3326) ---
#   WMAE: 2162.89
#
# --- Processing Store: 8, Department: 6 (536/3326) ---
#   WMAE: 808.39
#
# --- Processing Store: 8, Department: 7 (537/3326) ---
#   WMAE: 8299.73
#
# --- Processing Store: 8, Department: 8 (538/3326) ---
#   WMAE: 1234.50
#
# --- Processing Store: 8, Department: 9 (539/3326) ---
#   WMAE: 2775.27
#
# --- Processing Store: 8, Department: 10 (540/3326) ---
#   WMAE: 3707.36
#
# --- Processing Store: 8, Department: 11 (541/3326) ---
#   WMAE: 6754.47
#
# --- Processing Store: 8, Department: 12 (542/3326) ---
#   WMAE: 1171.19
#
# --- Processing Store: 8, Department: 13 (543/3326) ---
#   WMAE: 1538.61
#
# --- Processing Store: 8, Department: 14 (544/3326) ---
#   WMAE: 917.26
#
# --- Processing Store: 8, Department: 16 (545/3326) ---
#   WMAE: 6218.98
#
# --- Processing Store: 8, Department: 17 (546/3326) ---
#   WMAE: 692.70
#
# --- Processing Store: 8, Department: 18 (547/3326) ---
#   Skipping (Store 8, Dept 18): Not enough training data points (108 < 131 required).
#
# --- Processing Store: 8, Department: 19 (548/3326) ---
#   WMAE: 398.56
#
# --- Processing Store: 8, Department: 20 (549/3326) ---
#   WMAE: 573.41
#
# --- Processing Store: 8, Department: 21 (550/3326) ---
#   WMAE: 426.43
#
# --- Processing Store: 8, Department: 22 (551/3326) ---
#   WMAE: 932.09
#
# --- Processing Store: 8, Department: 23 (552/3326) ---
#   WMAE: 1292.66
#
# --- Processing Store: 8, Department: 24 (553/3326) ---
#   WMAE: 1969.67
#
# --- Processing Store: 8, Department: 25 (554/3326) ---
#   WMAE: 1041.62
#
# --- Processing Store: 8, Department: 26 (555/3326) ---
#   WMAE: 1343.25
#
# --- Processing Store: 8, Department: 27 (556/3326) ---
#   WMAE: 90.79
#
# --- Processing Store: 8, Department: 28 (557/3326) ---
#   WMAE: 36.47
#
# --- Processing Store: 8, Department: 29 (558/3326) ---
#   WMAE: 311.49
#
# --- Processing Store: 8, Department: 30 (559/3326) ---
#   WMAE: 339.43
#
# --- Processing Store: 8, Department: 31 (560/3326) ---
#   WMAE: 188.52
#
# --- Processing Store: 8, Department: 32 (561/3326) ---
#   WMAE: 1552.55
#
# --- Processing Store: 8, Department: 33 (562/3326) ---
#   WMAE: 2483.29
#
# --- Processing Store: 8, Department: 34 (563/3326) ---
#   WMAE: 1726.88
#
# --- Processing Store: 8, Department: 35 (564/3326) ---
#   WMAE: 438.23
#
# --- Processing Store: 8, Department: 36 (565/3326) ---
#   WMAE: 512.02
#
# --- Processing Store: 8, Department: 37 (566/3326) ---
#   WMAE: 345.37
#
# --- Processing Store: 8, Department: 38 (567/3326) ---
#   WMAE: 5907.93
#
# --- Processing Store: 8, Department: 40 (568/3326) ---
#   WMAE: 3609.48
#
# --- Processing Store: 8, Department: 41 (569/3326) ---
#   WMAE: 325.98
#
# --- Processing Store: 8, Department: 42 (570/3326) ---
#   WMAE: 362.86
#
# --- Processing Store: 8, Department: 44 (571/3326) ---
#   WMAE: 687.05
#
# --- Processing Store: 8, Department: 45 (572/3326) ---
# ...
#
# --- Processing Store: 40, Department: 79 (2975/3326) ---
#   WMAE: 1063.94
#
# --- Processing Store: 40, Department: 80 (2976/3326) ---
#   WMAE: 1879.59
#
# --- Processing Store: 40, Department: 81 (2977/3326) ---
#   WMAE: 723.74
#
# --- Processing Store: 40, Department: 82 (2978/3326) ---
#   WMAE: 2007.13
#
# --- Processing Store: 40, Department: 83 (2979/3326) ---
#   WMAE: 306.16
#
# --- Processing Store: 40, Department: 85 (2980/3326) ---
#   WMAE: 290.83
#
# --- Processing Store: 40, Department: 87 (2981/3326) ---
#   WMAE: 3459.37
#
# --- Processing Store: 40, Department: 90 (2982/3326) ---
#   WMAE: 2999.40
#
# --- Processing Store: 40, Department: 91 (2983/3326) ---
#   WMAE: 4008.52
#
# --- Processing Store: 40, Department: 92 (2984/3326) ---
#   WMAE: 11311.41
#
# --- Processing Store: 40, Department: 93 (2985/3326) ---
#   WMAE: 3965.41
#
# --- Processing Store: 40, Department: 94 (2986/3326) ---
#   WMAE: 2025.11
#
# --- Processing Store: 40, Department: 95 (2987/3326) ---
#   WMAE: 5269.96
#
# --- Processing Store: 40, Department: 96 (2988/3326) ---
#   WMAE: 1028.38
#
# --- Processing Store: 40, Department: 97 (2989/3326) ---
#   WMAE: 1323.60
#
# --- Processing Store: 40, Department: 98 (2990/3326) ---
#   WMAE: 483.53
#
# --- Processing Store: 40, Department: 99 (2991/3326) ---
#   Skipping (Store 40, Dept 99): Not enough training data points (32 < 131 required).
#
# --- Processing Store: 41, Department: 1 (2992/3326) ---
#   WMAE: 3736.33
#
# --- Processing Store: 41, Department: 2 (2993/3326) ---
#   WMAE: 1963.84
#
# --- Processing Store: 41, Department: 3 (2994/3326) ---
#   WMAE: 5708.98
#
# --- Processing Store: 41, Department: 4 (2995/3326) ---
#   WMAE: 1049.37
#
# --- Processing Store: 41, Department: 5 (2996/3326) ---
#   WMAE: 1673.55
#
# --- Processing Store: 41, Department: 6 (2997/3326) ---
#   WMAE: 897.77
#
# --- Processing Store: 41, Department: 7 (2998/3326) ---
#   WMAE: 4563.54
#
# --- Processing Store: 41, Department: 8 (2999/3326) ---
#   WMAE: 1581.58
#
# --- Processing Store: 41, Department: 9 (3000/3326) ---
#   WMAE: 4591.04
#
# --- Processing Store: 41, Department: 10 (3001/3326) ---
#   WMAE: 1625.35
#
# --- Processing Store: 41, Department: 11 (3002/3326) ---
#   WMAE: 2219.94
#
# --- Processing Store: 41, Department: 12 (3003/3326) ---
#   WMAE: 499.27
#
# --- Processing Store: 41, Department: 13 (3004/3326) ---
#   WMAE: 1004.79
#
# --- Processing Store: 41, Department: 14 (3005/3326) ---
#   WMAE: 2584.59
#
# --- Processing Store: 41, Department: 16 (3006/3326) ---
#   WMAE: 2475.43
#
# --- Processing Store: 41, Department: 17 (3007/3326) ---
#   WMAE: 1427.73
#
# --- Processing Store: 41, Department: 18 (3008/3326) ---
#   Skipping (Store 41, Dept 18): Not enough training data points (101 < 131 required).
#
# --- Processing Store: 41, Department: 19 (3009/3326) ---
#   Skipping (Store 41, Dept 19): Not enough training data points (73 < 131 required).
#
# --- Processing Store: 41, Department: 20 (3010/3326) ---
#   WMAE: 610.62
#
# --- Processing Store: 41, Department: 21 (3011/3326) ---
#   WMAE: 447.45
#
# --- Processing Store: 41, Department: 22 (3012/3326) ---
#   WMAE: 1550.14
#
# --- Processing Store: 41, Department: 23 (3013/3326) ---
#   WMAE: 3062.60
#
# --- Processing Store: 41, Department: 24 (3014/3326) ---
#   WMAE: 538.60
#
# --- Processing Store: 41, Department: 25 (3015/3326) ---
#   WMAE: 783.18
#
# --- Processing Store: 41, Department: 26 (3016/3326) ---
#   WMAE: 1574.05
#
# --- Processing Store: 41, Department: 27 (3017/3326) ---
#   WMAE: 242.61
#
# --- Processing Store: 41, Department: 28 (3018/3326) ---
#   WMAE: 140.27
#
# --- Processing Store: 41, Department: 29 (3019/3326) ---
#   WMAE: 274.31
#
# --- Processing Store: 41, Department: 30 (3020/3326) ---
#   WMAE: 190.52
#
# --- Processing Store: 41, Department: 31 (3021/3326) ---
#   WMAE: 529.44
#
# --- Processing Store: 41, Department: 32 (3022/3326) ---
#   WMAE: 1031.51
#
# --- Processing Store: 41, Department: 33 (3023/3326) ---
#   WMAE: 1008.57
#
# --- Processing Store: 41, Department: 34 (3024/3326) ---
#   WMAE: 2183.27
#
# --- Processing Store: 41, Department: 35 (3025/3326) ---
#   WMAE: 277.95
#
# --- Processing Store: 41, Department: 36 (3026/3326) ---
#   WMAE: 840.30
#
# --- Processing Store: 41, Department: 37 (3027/3326) ---
#   Skipping (Store 41, Dept 37): Not enough training data points (2 < 131 required).
#
# --- Processing Store: 41, Department: 38 (3028/3326) ---
#   WMAE: 5900.99
#
# --- Processing Store: 41, Department: 40 (3029/3326) ---
#   WMAE: 6212.68
#
# --- Processing Store: 41, Department: 41 (3030/3326) ---
#   WMAE: 775.42
#
# --- Processing Store: 41, Department: 42 (3031/3326) ---
#   WMAE: 219.32
#
# --- Processing Store: 41, Department: 44 (3032/3326) ---
#   WMAE: 671.12
#
# --- Processing Store: 41, Department: 45 (3033/3326) ---
#   Skipping (Store 41, Dept 45): Not enough training data points (79 < 131 required).
#
# --- Processing Store: 41, Department: 46 (3034/3326) ---
#   WMAE: 1277.65
#
# --- Processing Store: 41, Department: 47 (3035/3326) ---
#   Skipping (Store 41, Dept 47): Not enough training data points (23 < 131 required).
#
# --- Processing Store: 41, Department: 48 (3036/3326) ---
#   Skipping (Store 41, Dept 48): Not enough training data points (78 < 131 required).
#
# --- Processing Store: 41, Department: 49 (3037/3326) ---
#   WMAE: 1940.41
#
# --- Processing Store: 41, Department: 51 (3038/3326) ---
#   Skipping (Store 41, Dept 51): Not enough training data points (75 < 131 required).
#
# --- Processing Store: 41, Department: 52 (3039/3326) ---
#   WMAE: 868.78
#
# --- Processing Store: 41, Department: 54 (3040/3326) ---
#   Skipping (Store 41, Dept 54): Not enough training data points (129 < 131 required).
#
# --- Processing Store: 41, Department: 55 (3041/3326) ---
#   WMAE: 2413.20
#
# --- Processing Store: 41, Department: 56 (3042/3326) ---
#   WMAE: 5048.12
#
# --- Processing Store: 41, Department: 58 (3043/3326) ---
#   WMAE: 3319.95
#
# --- Processing Store: 41, Department: 59 (3044/3326) ---
#   WMAE: 291.92
#
# --- Processing Store: 41, Department: 60 (3045/3326) ---
#   WMAE: 135.19
#
# --- Processing Store: 41, Department: 67 (3046/3326) ---
#   WMAE: 1265.71
#
# --- Processing Store: 41, Department: 71 (3047/3326) ---
#   WMAE: 680.13
#
# --- Processing Store: 41, Department: 72 (3048/3326) ---
#   WMAE: 6352.13
#
# --- Processing Store: 41, Department: 74 (3049/3326) ---
#   WMAE: 1454.17
#
# --- Processing Store: 41, Department: 77 (3050/3326) ---
#   Skipping (Store 41, Dept 77): Not enough training data points (6 < 131 required).
#
# --- Processing Store: 41, Department: 78 (3051/3326) ---
#   Skipping (Store 41, Dept 78): Not enough training data points (4 < 131 required).
#
# --- Processing Store: 41, Department: 79 (3052/3326) ---
#   WMAE: 2169.38
#
# --- Processing Store: 41, Department: 80 (3053/3326) ---
#   WMAE: 811.54
#
# --- Processing Store: 41, Department: 81 (3054/3326) ---
#   WMAE: 785.65
#
# --- Processing Store: 41, Department: 82 (3055/3326) ---
#   WMAE: 2276.23
#
# --- Processing Store: 41, Department: 83 (3056/3326) ---
#   WMAE: 207.14
#
# --- Processing Store: 41, Department: 85 (3057/3326) ---
#   WMAE: 269.79
#
# --- Processing Store: 41, Department: 87 (3058/3326) ---
#   WMAE: 1008.25
#
# --- Processing Store: 41, Department: 90 (3059/3326) ---
#   WMAE: 2074.46
#
# --- Processing Store: 41, Department: 91 (3060/3326) ---
#   WMAE: 3410.92
#
# --- Processing Store: 41, Department: 92 (3061/3326) ---
#   WMAE: 5439.12
#
# --- Processing Store: 41, Department: 93 (3062/3326) ---
#   WMAE: 4466.08
#
# --- Processing Store: 41, Department: 94 (3063/3326) ---
#   WMAE: 5967.73
#
# --- Processing Store: 41, Department: 95 (3064/3326) ---
#   WMAE: 6272.76
#
# --- Processing Store: 41, Department: 96 (3065/3326) ---
#   WMAE: 407.84
#
# --- Processing Store: 41, Department: 97 (3066/3326) ---
#   WMAE: 1079.21
#
# --- Processing Store: 41, Department: 98 (3067/3326) ---
#   WMAE: 1306.20
#
# --- Processing Store: 41, Department: 99 (3068/3326) ---
#   Skipping (Store 41, Dept 99): Not enough training data points (37 < 131 required).
#
# --- Processing Store: 42, Department: 1 (3069/3326) ---
#   WMAE: 1440.72
#
# --- Processing Store: 42, Department: 2 (3070/3326) ---
#   WMAE: 1818.37
#
# --- Processing Store: 42, Department: 3 (3071/3326) ---
#   WMAE: 145.77
#
# --- Processing Store: 42, Department: 4 (3072/3326) ---
#   WMAE: 1235.91
#
# --- Processing Store: 42, Department: 5 (3073/3326) ---
#   WMAE: 151.99
#
# --- Processing Store: 42, Department: 6 (3074/3326) ---
#   Skipping (Store 42, Dept 6): Not enough training data points (3 < 131 required).
#
# --- Processing Store: 42, Department: 7 (3075/3326) ---
#   WMAE: 240.41
#
# --- Processing Store: 42, Department: 8 (3076/3326) ---
#   WMAE: 1359.70
#
# --- Processing Store: 42, Department: 9 (3077/3326) ---
#   WMAE: 30.56
#
# --- Processing Store: 42, Department: 10 (3078/3326) ---
#   WMAE: 44.66
#
# --- Processing Store: 42, Department: 11 (3079/3326) ---
#   WMAE: 134.79
#
# --- Processing Store: 42, Department: 12 (3080/3326) ---
#   WMAE: 32.73
#
# --- Processing Store: 42, Department: 13 (3081/3326) ---
#   WMAE: 1198.93
#
# --- Processing Store: 42, Department: 14 (3082/3326) ---
#   WMAE: 118.64
#
# --- Processing Store: 42, Department: 16 (3083/3326) ---
#   WMAE: 178.67
#
# --- Processing Store: 42, Department: 17 (3084/3326) ---
#   WMAE: 85.34
#
# --- Processing Store: 42, Department: 18 (3085/3326) ---
#   Skipping (Store 42, Dept 18): Not enough training data points (99 < 131 required).
#
# --- Processing Store: 42, Department: 20 (3086/3326) ---
#   Skipping (Store 42, Dept 20): Not enough training data points (57 < 131 required).
#
# --- Processing Store: 42, Department: 21 (3087/3326) ---
#   WMAE: 123.88
#
# --- Processing Store: 42, Department: 22 (3088/3326) ---
#   Skipping (Store 42, Dept 22): Not enough training data points (20 < 131 required).
#
# --- Processing Store: 42, Department: 23 (3089/3326) ---
#   Skipping (Store 42, Dept 23): Not enough training data points (77 < 131 required).
#
# --- Processing Store: 42, Department: 25 (3090/3326) ---
#   WMAE: 20.94
#
# --- Processing Store: 42, Department: 26 (3091/3326) ---
#   Skipping (Store 42, Dept 26): Not enough training data points (7 < 131 required).
#
# --- Processing Store: 42, Department: 27 (3092/3326) ---
#   Skipping (Store 42, Dept 27): Not enough training data points (74 < 131 required).
#
# --- Processing Store: 42, Department: 28 (3093/3326) ---
#   WMAE: 28.82
#
# --- Processing Store: 42, Department: 31 (3094/3326) ---
#   Skipping (Store 42, Dept 31): Not enough training data points (121 < 131 required).
#
# --- Processing Store: 42, Department: 32 (3095/3326) ---
#   Error fitting/predicting (Store 42, Dept 32): 'The `start` argument could not be matched to a location related to the index of the data.'
#
# --- Processing Store: 42, Department: 33 (3096/3326) ---
#   Skipping (Store 42, Dept 33): Not enough training data points (4 < 131 required).
#
# --- Processing Store: 42, Department: 34 (3097/3326) ---
#   Skipping (Store 42, Dept 34): Not enough training data points (1 < 131 required).
#
# --- Processing Store: 42, Department: 38 (3098/3326) ---
#   WMAE: 5090.37
#
# --- Processing Store: 42, Department: 40 (3099/3326) ---
#   WMAE: 1511.56
#
# --- Processing Store: 42, Department: 41 (3100/3326) ---
#   Skipping (Store 42, Dept 41): Not enough training data points (2 < 131 required).
#
# --- Processing Store: 42, Department: 42 (3101/3326) ---
#   WMAE: 48.11
#
# --- Processing Store: 42, Department: 44 (3102/3326) ---
#   Skipping (Store 42, Dept 44): Not enough training data points (21 < 131 required).
#
# --- Processing Store: 42, Department: 46 (3103/3326) ---
#   WMAE: 668.15
#
# --- Processing Store: 42, Department: 49 (3104/3326) ---
#   Skipping (Store 42, Dept 49): Not enough training data points (30 < 131 required).
#
# --- Processing Store: 42, Department: 52 (3105/3326) ---
#   WMAE: 9.72
#
# --- Processing Store: 42, Department: 55 (3106/3326) ---
#   Skipping (Store 42, Dept 55): Not enough training data points (6 < 131 required).
#
# --- Processing Store: 42, Department: 56 (3107/3326) ---
#   Skipping (Store 42, Dept 56): Not enough training data points (61 < 131 required).
#
# --- Processing Store: 42, Department: 59 (3108/3326) ---
#   WMAE: 42.15
#
# --- Processing Store: 42, Department: 60 (3109/3326) ---
#   WMAE: 66.31
#
# --- Processing Store: 42, Department: 67 (3110/3326) ---
#   WMAE: 212.68
#
# --- Processing Store: 42, Department: 71 (3111/3326) ---
#   Skipping (Store 42, Dept 71): Not enough training data points (7 < 131 required).
#
# --- Processing Store: 42, Department: 72 (3112/3326) ---
#   Skipping (Store 42, Dept 72): Not enough training data points (27 < 131 required).
#
# --- Processing Store: 42, Department: 74 (3113/3326) ---
#   Skipping (Store 42, Dept 74): Not enough training data points (130 < 131 required).
#
# --- Processing Store: 42, Department: 79 (3114/3326) ---
#   WMAE: 1357.76
#
# --- Processing Store: 42, Department: 80 (3115/3326) ---
#   WMAE: 1405.69
#
# --- Processing Store: 42, Department: 81 (3116/3326) ---
#   WMAE: 1469.24
#
# --- Processing Store: 42, Department: 82 (3117/3326) ---
#   WMAE: 636.68
#
# --- Processing Store: 42, Department: 83 (3118/3326) ---
#   WMAE: 1155.77
#
# --- Processing Store: 42, Department: 85 (3119/3326) ---
#   Error fitting/predicting (Store 42, Dept 85): 'The `start` argument could not be matched to a location related to the index of the data.'
#
# --- Processing Store: 42, Department: 87 (3120/3326) ---
#   Error fitting/predicting (Store 42, Dept 87): 'The `start` argument could not be matched to a location related to the index of the data.'
#
# --- Processing Store: 42, Department: 90 (3121/3326) ---
#   WMAE: 7735.90
#
# --- Processing Store: 42, Department: 91 (3122/3326) ---
#   WMAE: 7724.78
#
# --- Processing Store: 42, Department: 92 (3123/3326) ---
#   WMAE: 14180.63
#
# --- Processing Store: 42, Department: 93 (3124/3326) ---
#   WMAE: 5981.75
#
# --- Processing Store: 42, Department: 94 (3125/3326) ---
#   WMAE: 3434.90
#
# --- Processing Store: 42, Department: 95 (3126/3326) ---
#   WMAE: 6726.46
#
# --- Processing Store: 42, Department: 96 (3127/3326) ---
#   WMAE: 633.18
#
# --- Processing Store: 42, Department: 97 (3128/3326) ---
#   WMAE: 3040.90
#
# --- Processing Store: 42, Department: 98 (3129/3326) ---
#   WMAE: 487.14
#
# --- Processing Store: 43, Department: 1 (3130/3326) ---
#   WMAE: 2754.45
#
# --- Processing Store: 43, Department: 2 (3131/3326) ---
#   WMAE: 726.12
#
# --- Processing Store: 43, Department: 3 (3132/3326) ---
#   WMAE: 434.97
#
# --- Processing Store: 43, Department: 4 (3133/3326) ---
#   WMAE: 1046.33
#
# --- Processing Store: 43, Department: 5 (3134/3326) ---
#   Skipping (Store 43, Dept 5): Not enough training data points (78 < 131 required).
#
# --- Processing Store: 43, Department: 6 (3135/3326) ---
#   Skipping (Store 43, Dept 6): Not enough training data points (106 < 131 required).
#
# --- Processing Store: 43, Department: 7 (3136/3326) ---
#   WMAE: 264.58
#
# --- Processing Store: 43, Department: 8 (3137/3326) ---
#   WMAE: 540.87
#
# --- Processing Store: 43, Department: 9 (3138/3326) ---
#   WMAE: 64.42
#
# --- Processing Store: 43, Department: 10 (3139/3326) ---
#   WMAE: 103.11
#
# --- Processing Store: 43, Department: 11 (3140/3326) ---
#   WMAE: 378.42
#
# --- Processing Store: 43, Department: 12 (3141/3326) ---
#   WMAE: 13.91
#
# --- Processing Store: 43, Department: 13 (3142/3326) ---
#   WMAE: 981.42
#
# --- Processing Store: 43, Department: 14 (3143/3326) ---
#   WMAE: 159.73
#
# --- Processing Store: 43, Department: 16 (3144/3326) ---
#   WMAE: 179.61
#
# --- Processing Store: 43, Department: 17 (3145/3326) ---
#   WMAE: 216.62
#
# --- Processing Store: 43, Department: 18 (3146/3326) ---
#   Skipping (Store 43, Dept 18): Not enough training data points (88 < 131 required).
#
# --- Processing Store: 43, Department: 20 (3147/3326) ---
#   Skipping (Store 43, Dept 20): Not enough training data points (86 < 131 required).
#
# --- Processing Store: 43, Department: 21 (3148/3326) ---
#   WMAE: 256.24
#
# --- Processing Store: 43, Department: 22 (3149/3326) ---
#   Skipping (Store 43, Dept 22): Not enough training data points (31 < 131 required).
#
# --- Processing Store: 43, Department: 23 (3150/3326) ---
#   Skipping (Store 43, Dept 23): Not enough training data points (23 < 131 required).
#
# --- Processing Store: 43, Department: 24 (3151/3326) ---
#   Skipping (Store 43, Dept 24): Not enough training data points (2 < 131 required).
#
# --- Processing Store: 43, Department: 25 (3152/3326) ---

# %%
# %pip install -q dagshub
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 261.0/261.0 kB 9.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.9/139.9 kB 9.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 92.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 203.4/203.4 kB 15.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.9/50.9 kB 3.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.2/85.2 kB 6.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.3/74.3 kB 5.0 MB/s eta 0:00:00

# %%
# !pip install mlflow==2.7.1
# Out:
# Collecting mlflow==2.7.1
#   Downloading mlflow-2.7.1-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: click<9,>=7.0 in /usr/local/lib/python3.11/dist-packages (from mlflow==2.7.1) (8.2.1)
# Collecting cloudpickle<3 (from mlflow==2.7.1)
#   Downloading cloudpickle-2.2.1-py3-none-any.whl.metadata (6.9 kB)
# Collecting databricks-cli<1,>=0.8.7 (from mlflow==2.7.1)
#   Downloading databricks_cli-0.18.0-py2.py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: entrypoints<1 in /usr/local/lib/python3.11/dist-packages (from mlflow==2.7.1) (0.4)
# Requirement already satisfied: gitpython<4,>=2.1.0 in /usr/local/lib/python3.11/dist-packages (from mlflow==2.7.1) (3.1.44)
# Requirement already satisfied: pyyaml<7,>=5.1 in /usr/local/lib/python3.11/dist-packages (from mlflow==2.7.1) (6.0.2)
# Collecting protobuf<5,>=3.12.0 (from mlflow==2.7.1)
#   Downloading protobuf-4.25.8-cp37-abi3-manylinux2014_x86_64.whl.metadata (541 bytes)
# Collecting pytz<2024 (from mlflow==2.7.1)
#   Downloading pytz-2023.4-py2.py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: requests<3,>=2.17.3 in /usr/local/lib/python3.11/dist-packages (from mlflow==2.7.1) (2.32.3)
# Collecting packaging<24 (from mlflow==2.7.1)
#   Downloading packaging-23.2-py3-none-any.whl.metadata (3.2 kB)
# Collecting importlib-metadata!=4.7.0,<7,>=3.7.0 (from mlflow==2.7.1)
#   Downloading importlib_metadata-6.11.0-py3-none-any.whl.metadata (4.9 kB)
# Requirement already satisfied: sqlparse<1,>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from mlflow==2.7.1) (0.5.3)
# Collecting alembic!=1.10.0,<2 (from mlflow==2.7.1)
#   Downloading alembic-1.16.2-py3-none-any.whl.metadata (7.3 kB)
# Collecting docker<7,>=4.0.0 (from mlflow==2.7.1)
#   Downloading docker-6.1.3-py3-none-any.whl.metadata (3.5 kB)
# Collecting Flask<3 (from mlflow==2.7.1)
#   Downloading flask-2.3.3-py3-none-any.whl.metadata (3.6 kB)
# Collecting numpy<2 (from mlflow==2.7.1)
#   Downloading numpy-1.26.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 3.5 MB/s eta 0:00:00
# Requirement already satisfied: scipy<2 in /usr/local/lib/python3.11/dist-packages (from mlflow==2.7.1) (1.15.3)
# Requirement already satisfied: pandas<3 in /usr/local/lib/python3.11/dist-packages (from mlflow==2.7.1) (2.2.2)
# Collecting querystring-parser<2 (from mlflow==2.7.1)
#   Downloading querystring_parser-1.2.4-py2.py3-none-any.whl.metadata (559 bytes)
# Requirement already satisfied: sqlalchemy<3,>=1.4.0 in /usr/local/lib/python3.11/dist-packages (from mlflow==2.7.1) (2.0.41)
# Requirement already satisfied: scikit-learn<2 in /usr/local/lib/python3.11/dist-packages (from mlflow==2.7.1) (1.6.1)
# Collecting pyarrow<14,>=4.0.0 (from mlflow==2.7.1)
#   Downloading pyarrow-13.0.0-cp311-cp311-manylinux_2_28_x86_64.whl.metadata (3.0 kB)
# Requirement already satisfied: markdown<4,>=3.3 in /usr/local/lib/python3.11/dist-packages (from mlflow==2.7.1) (3.8.2)
# Requirement already satisfied: matplotlib<4 in /usr/local/lib/python3.11/dist-packages (from mlflow==2.7.1) (3.10.0)
# Collecting gunicorn<22 (from mlflow==2.7.1)
#   Downloading gunicorn-21.2.0-py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: Jinja2<4,>=2.11 in /usr/local/lib/python3.11/dist-packages (from mlflow==2.7.1) (3.1.6)
# Requirement already satisfied: Mako in /usr/lib/python3/dist-packages (from alembic!=1.10.0,<2->mlflow==2.7.1) (1.1.3)
# Requirement already satisfied: typing-extensions>=4.12 in /usr/local/lib/python3.11/dist-packages (from alembic!=1.10.0,<2->mlflow==2.7.1) (4.14.0)
# Requirement already satisfied: pyjwt>=1.7.0 in /usr/local/lib/python3.11/dist-packages (from databricks-cli<1,>=0.8.7->mlflow==2.7.1) (2.10.1)
# Requirement already satisfied: oauthlib>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from databricks-cli<1,>=0.8.7->mlflow==2.7.1) (3.3.1)
# Requirement already satisfied: tabulate>=0.7.7 in /usr/local/lib/python3.11/dist-packages (from databricks-cli<1,>=0.8.7->mlflow==2.7.1) (0.9.0)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.11/dist-packages (from databricks-cli<1,>=0.8.7->mlflow==2.7.1) (1.17.0)
# Requirement already satisfied: urllib3<3,>=1.26.7 in /usr/local/lib/python3.11/dist-packages (from databricks-cli<1,>=0.8.7->mlflow==2.7.1) (2.4.0)
# Requirement already satisfied: websocket-client>=0.32.0 in /usr/local/lib/python3.11/dist-packages (from docker<7,>=4.0.0->mlflow==2.7.1) (1.8.0)
# Requirement already satisfied: Werkzeug>=2.3.7 in /usr/local/lib/python3.11/dist-packages (from Flask<3->mlflow==2.7.1) (3.1.3)
# Requirement already satisfied: itsdangerous>=2.1.2 in /usr/local/lib/python3.11/dist-packages (from Flask<3->mlflow==2.7.1) (2.2.0)
# Requirement already satisfied: blinker>=1.6.2 in /usr/local/lib/python3.11/dist-packages (from Flask<3->mlflow==2.7.1) (1.9.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.11/dist-packages (from gitpython<4,>=2.1.0->mlflow==2.7.1) (4.0.12)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.11/dist-packages (from importlib-metadata!=4.7.0,<7,>=3.7.0->mlflow==2.7.1) (3.23.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from Jinja2<4,>=2.11->mlflow==2.7.1) (3.0.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib<4->mlflow==2.7.1) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib<4->mlflow==2.7.1) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib<4->mlflow==2.7.1) (4.58.4)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib<4->mlflow==2.7.1) (1.4.8)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib<4->mlflow==2.7.1) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib<4->mlflow==2.7.1) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib<4->mlflow==2.7.1) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas<3->mlflow==2.7.1) (2025.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.17.3->mlflow==2.7.1) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.17.3->mlflow==2.7.1) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.17.3->mlflow==2.7.1) (2025.6.15)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn<2->mlflow==2.7.1) (1.5.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn<2->mlflow==2.7.1) (3.6.0)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.11/dist-packages (from sqlalchemy<3,>=1.4.0->mlflow==2.7.1) (3.2.3)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.11/dist-packages (from gitdb<5,>=4.0.1->gitpython<4,>=2.1.0->mlflow==2.7.1) (5.0.2)
# Downloading mlflow-2.7.1-py3-none-any.whl (18.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.5/18.5 MB 38.4 MB/s eta 0:00:00
# Downloading alembic-1.16.2-py3-none-any.whl (242 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 242.7/242.7 kB 13.6 MB/s eta 0:00:00
# Downloading cloudpickle-2.2.1-py3-none-any.whl (25 kB)
# Downloading databricks_cli-0.18.0-py2.py3-none-any.whl (150 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 150.3/150.3 kB 9.8 MB/s eta 0:00:00
# Downloading docker-6.1.3-py3-none-any.whl (148 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 148.1/148.1 kB 5.4 MB/s eta 0:00:00
# Downloading flask-2.3.3-py3-none-any.whl (96 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 96.1/96.1 kB 6.6 MB/s eta 0:00:00
# Downloading gunicorn-21.2.0-py3-none-any.whl (80 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.2/80.2 kB 3.7 MB/s eta 0:00:00
# Downloading importlib_metadata-6.11.0-py3-none-any.whl (23 kB)
# Downloading numpy-1.26.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.3/18.3 MB 47.6 MB/s eta 0:00:00
# Downloading packaging-23.2-py3-none-any.whl (53 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.0/53.0 kB 3.7 MB/s eta 0:00:00
# Downloading protobuf-4.25.8-cp37-abi3-manylinux2014_x86_64.whl (294 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.9/294.9 kB 13.5 MB/s eta 0:00:00
# Downloading pyarrow-13.0.0-cp311-cp311-manylinux_2_28_x86_64.whl (40.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.0/40.0 MB 23.1 MB/s eta 0:00:00
# Downloading pytz-2023.4-py2.py3-none-any.whl (506 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 506.5/506.5 kB 29.6 MB/s eta 0:00:00
# Downloading querystring_parser-1.2.4-py2.py3-none-any.whl (7.9 kB)
# Installing collected packages: pytz, querystring-parser, protobuf, packaging, numpy, importlib-metadata, cloudpickle, pyarrow, gunicorn, Flask, docker, databricks-cli, alembic, mlflow
#   Attempting uninstall: pytz
#     Found existing installation: pytz 2025.2
#     Uninstalling pytz-2025.2:
#       Successfully uninstalled pytz-2025.2
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 5.29.5
#     Uninstalling protobuf-5.29.5:
#       Successfully uninstalled protobuf-5.29.5
#   Attempting uninstall: packaging
#     Found existing installation: packaging 24.2
#     Uninstalling packaging-24.2:
#       Successfully uninstalled packaging-24.2
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.0.2
#     Uninstalling numpy-2.0.2:
#       Successfully uninstalled numpy-2.0.2
#   Attempting uninstall: importlib-metadata
#     Found existing installation: importlib_metadata 8.7.0
#     Uninstalling importlib_metadata-8.7.0:
#       Successfully uninstalled importlib_metadata-8.7.0
#   Attempting uninstall: cloudpickle
#     Found existing installation: cloudpickle 3.1.1
#     Uninstalling cloudpickle-3.1.1:
#       Successfully uninstalled cloudpickle-3.1.1
#   Attempting uninstall: pyarrow
#     Found existing installation: pyarrow 18.1.0
#     Uninstalling pyarrow-18.1.0:
#       Successfully uninstalled pyarrow-18.1.0
#   Attempting uninstall: Flask
#     Found existing installation: Flask 3.1.1
#     Uninstalling Flask-3.1.1:
#       Successfully uninstalled Flask-3.1.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# thinc 8.3.6 requires numpy<3.0.0,>=2.0.0, but you have numpy 1.26.4 which is incompatible.
# pylibcudf-cu12 25.2.1 requires pyarrow<20.0.0a0,>=14.0.0; platform_machine == "x86_64", but you have pyarrow 13.0.0 which is incompatible.
# distributed 2024.12.1 requires cloudpickle>=3.0.0, but you have cloudpickle 2.2.1 which is incompatible.
# ydf 0.12.0 requires protobuf<6.0.0,>=5.29.1, but you have protobuf 4.25.8 which is incompatible.
# dask-expr 1.1.21 requires pyarrow>=14.0.1, but you have pyarrow 13.0.0 which is incompatible.
# bigframes 2.8.0 requires pyarrow>=15.0.2, but you have pyarrow 13.0.0 which is incompatible.
# dask 2024.12.1 requires cloudpickle>=3.0.0, but you have cloudpickle 2.2.1 which is incompatible.
# google-cloud-bigquery 3.34.0 requires packaging>=24.2.0, but you have packaging 23.2 which is incompatible.
# db-dtypes 1.4.3 requires packaging>=24.2.0, but you have packaging 23.2 which is incompatible.
# cudf-cu12 25.2.1 requires pyarrow<20.0.0a0,>=14.0.0; platform_machine == "x86_64", but you have pyarrow 13.0.0 which is incompatible.
# grpcio-status 1.71.2 requires protobuf<6.0dev,>=5.26.1, but you have protobuf 4.25.8 which is incompatible.
# Successfully installed Flask-2.3.3 alembic-1.16.2 cloudpickle-2.2.1 databricks-cli-0.18.0 docker-6.1.3 gunicorn-21.2.0 importlib-metadata-6.11.0 mlflow-2.7.1 numpy-1.26.4 packaging-23.2 protobuf-4.25.8 pyarrow-13.0.0 pytz-2023.4 querystring-parser-1.2.4

# %%
import dagshub
# Try to get credentials from environment first
dagshub.init(
    repo_owner='abarb22',
    repo_name='Walmart-Recruiting---Store-Sales-Forecasting',
    mlflow=True
)
# Out:
# Initialized MLflow to track repo "abarb22/Walmart-Recruiting---Store-Sales-Forecasting"
# Repository abarb22/Walmart-Recruiting---Store-Sales-Forecasting initialized!

# %%
import mlflow
import mlflow.lightgbm  # Use sklearn logging instead
from datetime import datetime

mlflow.set_experiment("LightGBM_Training")
# Out:
# <Experiment: artifact_location='mlflow-artifacts:/d44fa10e33c34452b1f57e1d7b550038', creation_time=1751542655791, experiment_id='0', last_update_time=1751542655791, lifecycle_stage='active', name='LightGBM_Training', tags={}>

# %%
with mlflow.start_run(run_name="LightGBM_Data_Cleaning"):
    # Log data cleaning parameters
    mlflow.log_param("missing_value_strategy", "MarkDowns->0, others->ffill/bfill/mean")
    mlflow.log_param("date_features_extracted", True)


    # After cleaning, log metrics about data quality
    mlflow.log_metric("train_samples", len(train_df))
    mlflow.log_metric("missing_values_filled", train_df.isna().sum().sum())
# Out:
# 🏃 View run LightGBM_Data_Cleaning at: https://dagshub.com/abarb22/Walmart-Recruiting---Store-Sales-Forecasting.mlflow/#/experiments/0/runs/00101f5024ba48a6babbe257b51d7453
# 🧪 View experiment at: https://dagshub.com/abarb22/Walmart-Recruiting---Store-Sales-Forecasting.mlflow/#/experiments/0
